# %% [markdown]
# # Info
#
# 현 예측은 아무런 EDA 과정 없이 추측만을 가지고 Feature를 선택하고 진행하며 모델 선택 및 적용 과정에서도 미흡한 부분이 다수 있을 가능성이 높음.
#
# ---------------------------------------
# 본 파일은 로스트아크의 캐릭터 스펙(Feature: 각인, 보석, 카드 등)에 따른 아이템 레벨을 예측하고
#
# 현재 아이템 레벨에 비해 스펙이 낮을 경우 스펙을 높일 것을 추천하고
#
# 아이템 레벨에 비해 스펙이 높을 경우 아이템 레벨을 높일 것을 추천하는 것을 목표로 함.
#
# ---------------------------------------
# 더 나아가 어떤 스펙을 어느 정도로 올리면 좋은지도 추천해주고자 함.

# %% [markdown]
# 1. profile_table: expeditionLevel, totalSkillPoint, characterLevel, itemMaxLevel
# 2. accessory_table: accessory_quality, accessory_grade, accessory_tier, 팔찌_효과, AS_setLevel
# 3. avatar_table: avatar_grade
# 4. card_table: setName, setPoint
# 5. engraving_table: grantName, grantPoint, engraving_name, engraving_level
# 6. equipment_table: equipment_quality, equipment_grade, equipment_setLevel
# 7. gem_table: gem_grade, gem_level, gem_tier
# 8. skill_table: skill_tripod_point
# 9. stats_table: stat_값

# %%
import sys
sys.path.append('./package')
import lostark as lok

# %%
import pandas as pd
import numpy as np
import joblib
from pprint import pprint
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
tables = ['profile_table','accessory_table', 'avatar_table', 'card_table', 'engraving_table', 
         'equipment_table', 'gem_table', 'skill_table', 'stats_table']
accessories = ['목걸이', '귀걸이1', '귀걸이2', '반지1', '반지2']
accessory_column = ['_quality', '_grade', '_tier']
avatars = ['무기1', '무기2', '상의1', '상의2', '하의1', '하의2']
avatar_column = ['_grade']
equipments = ['무기', '투구', '어깨', '상의', '하의', '장갑']
equipment_column = ['_quality', '_grade', '_setLevel']
gem_column = ['_grade', '_level', '_tier']
stat_column = ['치명', '특화', '신속', '제압', '인내', '숙련']

sql = f"""SELECT profile_table.characterCode, profile_table.expeditionLevel, profile_table.totalSkillPoint,
profile_table.characterLevel, profile_table.itemMaxLevel,

{', '.join(f"accessory_table.{accessory}{column}" for accessory in accessories for column in accessory_column)},

{', '.join(f"avatar_table.{avatar}{column}" for avatar in avatars for column in avatar_column)},

{', '.join(f"card_table.setName{i}, card_table.setPoint{i}" for i in range(1, 5))},

{', '.join(f"engraving_table.grantName{i}, engraving_table.grantPoint{i}" for i in range(1, 3))},
{', '.join(f"engraving_table.engraving{i}_name, engraving_table.engraving{i}_level" for i in range(1, 12))},

{', '.join(f"equipment_table.{equipment}{column}" for equipment in equipments for column in equipment_column)},

{', '.join(f"gem_table.gem{i}{column}" for i in range(1, 12) for column in gem_column)},

{', '.join(f"skill_table.skill{i}_tripod{j}_point" for i in range(1, 17) for j in range(1, 4))},

{', '.join(f"stats_table.{column}_값" for column in stat_column)}

FROM profile_table
{' '.join(f"INNER JOIN {tables[i+1]} ON {tables[i]}.characterCode = {tables[i+1]}.characterCode"
for i in range(len(tables)-1))};
"""
db, cursor = lok.get_db_cursor()
cursor.execute(sql)
df = pd.DataFrame(cursor.fetchall())
db.close()

# %%
columns = ["characterCode", "expeditionLevel", "totalSkillPoint", "characterLevel", "itemMaxLevel"]
for accessory in accessories:
    for column in accessory_column:
        columns.append(f"{accessory}{column}")
for avatar in avatars :
    for column in avatar_column:
        columns.append(f"avatar_{avatar}{column}") 
for i in range(1, 5):
    columns.append(f"card_setName{i}")
    columns.append(f"card_setPoint{i}")
for i in range(1, 3):
    columns.append(f"engraving_grantName{i}")
    columns.append(f"engraving_grantPoint{i}")
for i in range(1, 12):
    columns.append(f"engraving{i}_name")
    columns.append(f"engraving{i}_level")
for equipment in equipments:
    for column in equipment_column:
        columns.append(f"equipment_{equipment}{column}")
for i in range(1, 12):
    for column in gem_column:
        columns.append(f"gem{i}{column}")
for i in range(1, 17):
    for j in range(1, 4):
        columns.append(f"skill{i}_tripod{j}_point")
for column in stat_column:
    columns.append(f"{column}_값")

df.columns = columns

# %%
# 라벨 인코딩
from sklearn.preprocessing import LabelEncoder
grade_le = LabelEncoder()
uniqueGrade = ['고급', '전설', '영웅', '희귀', '유물', '고대', '에스더', 'None']
grade_le_fit = grade_le.fit(uniqueGrade)

uniqueCardSet = []
for i in range(1, 5):
    uniqueCardSet = list(set(uniqueCardSet + list(df[f"card_setName{i}"].fillna('None').unique())))
cardSet_le = LabelEncoder()
cardSet_le_fit = cardSet_le.fit(uniqueCardSet)

uniqueEngraving = []
for i in range(1, 3):
    uniqueEngraving = list(set(uniqueEngraving + list(df[f"engraving_grantName{i}"].fillna('None').unique())))
for i in range(1, 12):
    uniqueEngraving = list(set(uniqueEngraving + list(df[f"engraving{i}_name"].fillna('None').unique())))
engraving_le = LabelEncoder()
engraving_le_fit = engraving_le.fit(uniqueEngraving)

joblib.dump(grade_le_fit, './label/grade_label.pkl')
joblib.dump(cardSet_le_fit, './label/card_label.pkl')
joblib.dump(engraving_le_fit, './label/engraving_label.pkl')
# Out:
# ['./label/engraving_label.pkl']

# %%
# 결측치 처리, 라벨 인코딩, 데이터타입 수정
df['itemMaxLevel'] = df['itemMaxLevel'].astype('float64')
for accessory in accessories:
    df[f'{accessory}_quality'] = df[f'{accessory}_quality'].fillna(-1).astype('int64')
    df[f'{accessory}_grade'] = grade_le_fit.transform(df[f'{accessory}_grade'].fillna('None'))
    df[f'{accessory}_tier'] = df[f'{accessory}_tier'].fillna(-1).astype('int64')
for avatar in avatars :
    df[f"avatar_{avatar}_grade"] =  grade_le_fit.transform(df[f"avatar_{avatar}_grade"].fillna('None'))
for i in range(1, 5):
    df[f"card_setName{i}"] = cardSet_le_fit.transform(df[f"card_setName{i}"].fillna('None'))
    df[f"card_setPoint{i}"] = df[f"card_setPoint{i}"].fillna(-1).astype('int64')
for i in range(1, 3):
    df[f"engraving_grantName{i}"] = engraving_le_fit.transform(df[f"engraving_grantName{i}"].fillna('None'))
    df[f"engraving_grantPoint{i}"] = df[f"engraving_grantPoint{i}"].fillna('-1').astype('int64')
for i in range(1, 12):
    df[f"engraving{i}_name"] = engraving_le_fit.transform(df[f"engraving{i}_name"].fillna('None'))
    df[f"engraving{i}_level"] = df[f"engraving{i}_level"].fillna(-1).astype('int64')
for equipment in equipments:
    df[f"equipment_{equipment}_grade"] = grade_le_fit.transform(df[f"equipment_{equipment}_grade"].fillna('None'))  
    df[f"equipment_{equipment}_setLevel"] = df[f"equipment_{equipment}_setLevel"].fillna(-1).astype('int64')
    df[f"equipment_{equipment}_quality"] = df[f"equipment_{equipment}_quality"].fillna(-1).astype('int64')
for i in range(1, 12):
    df[f"gem{i}_grade"] = grade_le_fit.transform(df[f"gem{i}_grade"].fillna('None'))
    df[f"gem{i}_level"] = df[f"gem{i}_level"].fillna(-1).astype('int64')
    df[f"gem{i}_tier"] = df[f"gem{i}_tier"].fillna(-1).astype('int64')
for i in range(1, 17):
    for j in range(1, 4):
        df[f"skill{i}_tripod{j}_point"] = df[f"skill{i}_tripod{j}_point"].fillna(-1).astype('int64')

# %%
dfc = df.corr().unstack()

# %%
# 다중공선성?
dfc[((dfc.values>0.5) | (dfc.values<-0.5)) & (dfc.values!=1)].to_frame('corr').drop_duplicates()
# Out:
#                                                  corr
# expeditionLevel       totalSkillPoint        0.629655
#                       card_setPoint1         0.553895
# totalSkillPoint       characterLevel         0.780030
# itemMaxLevel          목걸이_grade             -0.673422
#                       귀걸이1_grade            -0.706656
#                       귀걸이2_grade            -0.692028
#                       반지1_grade             -0.707763
#                       반지2_grade             -0.680008
#                       engraving4_level       0.534136
#                       engraving5_level       0.621041
#                       engraving6_level       0.527317
#                       equipment_무기_grade    -0.751324
#                       equipment_무기_setLevel  0.613738
#                       equipment_투구_grade    -0.755882
#                       equipment_어깨_grade    -0.754428
#                       equipment_상의_grade    -0.760451
#                       equipment_하의_grade    -0.758104
#                       equipment_장갑_grade    -0.753705
#                       gem1_level             0.690501
#                       gem2_level             0.670799
#                       gem3_level             0.599271
#                       gem4_level             0.587502
#                       gem5_level             0.604980
#                       gem6_level             0.606772
#                       gem7_level             0.606606
#                       gem8_level             0.579778
#                       gem9_level             0.527477
#                       gem10_level            0.502635
# 목걸이_quality           귀걸이1_quality           0.537100
#                       귀걸이2_quality           0.548090
# 목걸이_grade             귀걸이1_grade             0.883924
#                       귀걸이2_grade             0.880912
#                       반지1_grade              0.874687
#                       반지2_grade              0.858720
#                       engraving6_level      -0.553926
#                       equipment_무기_grade     0.604897
#                       equipment_투구_grade     0.588270
#                       equipment_어깨_grade     0.586046
#                       equipment_상의_grade     0.585023
#                       equipment_하의_grade     0.592310
#                       equipment_장갑_grade     0.577610
#                       gem1_level            -0.507061
# 목걸이_tier              귀걸이1_tier              0.771359
#                       귀걸이2_tier              0.801050
#                       반지1_tier               0.769386
#                       반지2_tier               0.785531
# 귀걸이1_quality          귀걸이2_quality           0.566016
# 귀걸이1_grade            귀걸이2_grade             0.902675
#                       반지1_grade              0.905897
#                       반지2_grade              0.877207
#                       engraving6_name       -0.509222
#                       engraving6_level      -0.578589
#                       equipment_무기_grade     0.635740
#                       equipment_투구_grade     0.619861
#                       equipment_어깨_grade     0.617348
#                       equipment_상의_grade     0.617697
#                       equipment_하의_grade     0.624522
#                       equipment_장갑_grade     0.608932
#                       gem6_level             0.736244
#                       gem6_tier              0.672029
#                       gem7_grade             0.774107
#                       gem7_level             0.714027
#                       gem7_tier              0.652006
#                       gem8_grade             0.770035
#                       gem8_level             0.707899
#                       gem8_tier              0.626542
#                       gem9_grade             0.687819
#                       gem9_level             0.631380
#                       gem9_tier              0.548263
#                       gem10_grade            0.646875
#                       gem10_level            0.594895
#                       gem10_tier             0.516631
#                       gem11_grade            0.613934
#                       gem11_level            0.566826
# gem3_level            gem3_tier              0.765842
#                       gem4_grade             0.807161
#                       gem4_level             0.926956
#                       gem4_tier              0.730129
#                       gem5_grade             0.759005
#                       gem5_level             0.865316
#                       gem5_tier              0.708208
#                       gem6_grade             0.747180
#                       gem6_level             0.849152
#                       gem6_tier              0.694232
#                       gem7_grade             0.740175
#                       gem7_level             0.833964
#                       gem7_tier              0.680038
#                       gem8_grade             0.747830
#                       gem8_level             0.827027
#                       gem8_tier              0.659200
#                       gem9_grade             0.682370
#                       gem9_level             0.750633
#                       gem9_tier              0.589264
#                       gem10_grade            0.652340
#                       gem10_level            0.714870
#                       gem10_tier             0.563329
#                       gem11_grade            0.631510
#                       gem11_level            0.683154
#                       gem11_tier             0.544847
# gem3_tier             gem4_grade             0.721507
#                       gem4_level             0.733891
#                       gem4_tier              0.905655
#                       gem5_grade             0.696848
#                       gem5_level             0.688607
#                       gem5_tier              0.850309
#                       gem6_grade             0.675962
#                       gem6_level             0.661271
#                       gem6_tier              0.809748
#                       gem7_grade             0.656397
#                       gem7_level             0.649664
#                       gem7_tier              0.772735
#                       gem8_grade             0.628831
#                       gem8_level             0.638129
#                       gem8_tier              0.728937
#                       gem9_grade             0.552054
#                       gem9_level             0.557638
#                       gem9_tier              0.618928
#                       gem10_grade            0.515187
#                       gem10_level            0.519128
#                       gem10_tier             0.568091
#                       gem11_tier             0.532077
# gem4_grade            gem4_level             0.871962
#                       gem4_tier              0.796185
#                       gem5_grade             0.863810
#                       gem5_level             0.800600
#                       gem5_tier              0.762186
#                       gem6_grade             0.837730
#                       gem6_level             0.786856
#                       gem6_tier              0.738980
#                       gem7_grade             0.817406
#                       gem7_level             0.763689
#                       gem7_tier              0.714455
#                       gem8_grade             0.816565
#                       gem8_level             0.757475
#                       gem8_tier              0.684906
#                       gem9_grade             0.724073
#                       gem9_level             0.671860
#                       gem9_tier              0.595503
#                       gem10_grade            0.678562
#                       gem10_level            0.630796
#                       gem10_tier             0.558643
#                       gem11_grade            0.650411
#                       gem11_level            0.603844
#                       gem11_tier             0.532429
# gem4_level            gem4_tier              0.808431
#                       gem5_grade             0.807769
#                       gem5_level             0.903079
#                       gem5_tier              0.780824
#                       gem6_grade             0.793234
#                       gem6_level             0.883443
#                       gem6_tier              0.761501
#                       gem7_grade             0.782529
#                       gem7_level             0.866640
#                       gem7_tier              0.742292
#                       gem8_grade             0.787413
#                       gem8_level             0.865115
#                       gem8_tier              0.717500
#                       gem9_grade             0.711139
#                       gem9_level             0.776910
#                       gem9_tier              0.633848
#                       gem10_grade            0.676096
#                       gem10_level            0.735063
#                       gem10_tier             0.601624
#                       gem11_grade            0.655814
#                       gem11_level            0.708475
#                       gem11_tier             0.579108
# gem4_tier             gem5_grade             0.768658
#                       gem5_level             0.758272
#                       gem5_tier              0.937117
#                       gem6_grade             0.744560
#                       gem6_level             0.727352
#                       gem6_tier              0.891182
#                       gem7_grade             0.722205
#                       gem7_level             0.714103
#                       gem7_tier              0.849601
#                       gem8_grade             0.691231
#                       gem8_level             0.700882
#                       gem8_tier              0.800793
#                       gem9_grade             0.606582
#                       gem9_level             0.612317
#                       gem9_tier              0.679715
#                       gem10_grade            0.565603
#                       gem10_level            0.569657
#                       gem10_tier             0.623425
#                       gem11_grade            0.534117
#                       gem11_level            0.539464
#                       gem11_tier             0.583678
# gem5_grade            gem5_level             0.871120
#                       gem5_tier              0.818573
#                       gem6_grade             0.900838
#                       gem6_level             0.825904
#                       gem6_tier              0.792250
#                       gem7_grade             0.892928
#                       gem7_level             0.814968
#                       gem7_tier              0.766379
#                       gem8_grade             0.820062
#                       gem8_level             0.769726
#                       gem8_tier              0.731219
#                       gem9_grade             0.728436
#                       gem9_level             0.681671
#                       gem9_tier              0.633608
#                       gem10_grade            0.682341
#                       gem10_level            0.639939
#                       gem10_tier             0.593534
#                       gem11_grade            0.648068
#                       gem11_level            0.609622
#                       gem11_tier             0.563495
# gem5_level            gem5_tier              0.806106
#                       gem6_grade             0.825080
#                       gem6_level             0.933521
#                       gem6_tier              0.786090
#                       gem7_grade             0.830351
#                       gem7_level             0.934734
#                       gem7_tier              0.767268
#                       gem8_grade             0.793626
#                       gem8_level             0.861981
#                       gem8_tier              0.739935
#                       gem9_grade             0.722038
#                       gem9_level             0.781652
#                       gem9_tier              0.657143
#                       gem10_grade            0.686317
#                       gem10_level            0.739323
#                       gem10_tier             0.623052
#                       gem11_grade            0.662404
#                       gem11_level            0.706729
#                       gem11_tier             0.598137
# gem5_tier             gem6_grade             0.792025
#                       gem6_level             0.772520
#                       gem6_tier              0.948717
#                       gem7_grade             0.768341
#                       gem7_level             0.758573
#                       gem7_tier              0.904374
#                       gem8_grade             0.733941
#                       gem8_level             0.743807
#                       gem8_tier              0.850318
#                       gem9_grade             0.643455
#                       gem9_level             0.649417
#                       gem9_tier              0.721382
#                       gem10_grade            0.600047
#                       gem10_level            0.604225
#                       gem10_tier             0.661645
#                       gem11_grade            0.566607
#                       gem11_level            0.572242
#                       gem11_tier             0.619429
# gem6_grade            gem6_level             0.873047
#                       gem6_tier              0.833742
#                       gem7_grade             0.906585
#                       gem7_level             0.829126
#                       gem7_tier              0.805293
#                       gem8_grade             0.850608
#                       gem8_level             0.801702
#                       gem8_tier              0.769634
#                       gem9_grade             0.755814
#                       gem9_level             0.709437
#                       gem9_tier              0.666391
#                       gem10_grade            0.705533
#                       gem10_level            0.664517
#                       gem10_tier             0.621830
#                       gem11_grade            0.669281
#                       gem11_level            0.632489
#                       gem11_tier             0.589359
# gem6_level            gem6_tier              0.811792
#                       gem7_grade             0.844702
#                       gem7_level             0.934811
#                       gem7_tier              0.792169
#                       gem8_grade             0.823554
#                       gem8_level             0.886100
#                       gem8_tier              0.765688
#                       gem9_grade             0.750733
#                       gem9_level             0.804857
#                       gem9_tier              0.681106
#                       gem10_grade            0.714299
#                       gem10_level            0.762158
#                       gem10_tier             0.646021
#                       gem11_grade            0.688322
#                       gem11_level            0.728314
#                       gem11_tier             0.619528
# gem6_tier             gem7_grade             0.807736
#                       gem7_level             0.797042
#                       gem7_tier              0.950673
#                       gem8_grade             0.771910
#                       gem8_level             0.781938
#                       gem8_tier              0.894092
#                       gem9_grade             0.676565
#                       gem9_level             0.682495
#                       gem9_tier              0.758227
#                       gem10_grade            0.630230
#                       gem10_level            0.634357
#                       gem10_tier             0.694637
#                       gem11_grade            0.594989
#                       gem11_level            0.600667
#                       gem11_tier             0.650138
# gem7_grade            gem7_level             0.892688
#                       gem7_tier              0.849334
#                       gem8_grade             0.888806
#                       gem8_level             0.838475
#                       gem8_tier              0.811313
#                       gem9_grade             0.787902
#                       gem9_level             0.742493
#                       gem9_tier              0.702857
#                       gem10_grade            0.735935
#                       gem10_level            0.695203
#                       gem10_tier             0.655300
#                       gem11_grade            0.698128
#                       gem11_level            0.661637
#                       gem11_tier             0.621222
# gem7_level            gem7_tier              0.837770
#                       gem8_grade             0.845905
#                       gem8_level             0.912538
#                       gem8_tier              0.807285
#                       gem9_grade             0.767731
#                       gem9_level             0.825878
#                       gem9_tier              0.714485
#                       gem10_grade            0.728723
#                       gem10_level            0.780478
#                       gem10_tier             0.675259
#                       gem11_grade            0.702704
#                       gem11_level            0.746386
#                       gem11_tier             0.647732
# gem7_tier             gem8_grade             0.810898
#                       gem8_level             0.821345
#                       gem8_tier              0.939307
#                       gem9_grade             0.710683
#                       gem9_level             0.716975
#                       gem9_tier              0.796611
#                       gem10_grade            0.661991
#                       gem10_level            0.666354
#                       gem10_tier             0.729644
#                       gem11_grade            0.624617
#                       gem11_level            0.630680
#                       gem11_tier             0.682644
# gem8_grade            gem8_level             0.916908
#                       gem8_tier              0.863233
#                       gem9_grade             0.854870
#                       gem9_level             0.803675
#                       gem9_tier              0.748704
#                       gem10_grade            0.796935
#                       gem10_level            0.752967
#                       gem10_tier             0.699658
#                       gem11_grade            0.760410
#                       gem11_level            0.718958
#                       gem11_tier             0.663989
# gem8_level            gem8_tier              0.873699
#                       gem9_grade             0.815385
#                       gem9_level             0.878189
#                       gem9_tier              0.766314
#                       gem10_grade            0.771692
#                       gem10_level            0.827626
#                       gem10_tier             0.722099
#                       gem11_grade            0.744058
#                       gem11_level            0.793623
#                       gem11_tier             0.690699
# gem8_tier             gem9_grade             0.756754
#                       gem9_level             0.762962
#                       gem9_tier              0.847803
#                       gem10_grade            0.704625
#                       gem10_level            0.708974
#                       gem10_tier             0.776194
#                       gem11_grade            0.664774
#                       gem11_level            0.670915
#                       gem11_tier             0.726084
# gem9_grade            gem9_level             0.933100
#                       gem9_tier              0.892584
#                       gem10_grade            0.909750
#                       gem10_level            0.867026
#                       gem10_tier             0.830565
#                       gem11_grade            0.860503
#                       gem11_level            0.823801
#                       gem11_tier             0.786206
# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scale = scaler.fit_transform(df)
df_scale = pd.DataFrame(df_scale, columns=df.columns)

# %%
dfc = df.copy()
from sklearn.decomposition import PCA
# gem grade
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'gem{i}_grade' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_grade_PCA1', 'gem_grade_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# gem tier
n_components = 3
pca = PCA(n_components=n_components)
columns = [f'gem{i}_tier' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_tier_PCA1', 'gem_tier_PCA2', 'gem_tier_PCA3'])
dfc = pd.concat([dfc, df_pca], axis=1)

# gem level
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'gem{i}_level' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_level_PCA1', 'gem_level_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# skill tripod point
n_components = 4
pca = PCA(n_components=n_components)
columns = [f'skill{i}_tripod{j}_point' for i in range(9, 17) for j in range(1, 4)]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['skill_tripod_point_PCA1', 'skill_tripod_point_PCA2',
    'skill_tripod_point_PCA3', 'skill_tripod_point_PCA4'])
dfc = pd.concat([dfc, df_pca], axis=1)

# euqipment grade
n_components = 1
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_grade' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
df.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_grade_PCA1'])
df = pd.concat([df, df_pca], axis=1)

# euqipment setLevel
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_setLevel' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_setLevel_PCA1', 'equipment_setLevel_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# euqipment quality
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_quality' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_quality_PCA1', 'equipment_quality_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)


# explained_variance_ratio = pca.explained_variance_ratio_
# print("Explained Variance Ratio:", explained_variance_ratio)
# print("Total Explained Variance:", np.sum(explained_variance_ratio))

# cumulative_explained_variance_ratio = np.cumsum(explained_variance_ratio)
# print("Cumulative Explained Variance Ratio:", cumulative_explained_variance_ratio)

# import matplotlib.pyplot as plt
# plt.plot(pca.explained_variance_ratio_)

# %%
dfc.head(2)
# Out:
#    characterCode  expeditionLevel  totalSkillPoint  characterLevel  \
# 0              1              300              420              60
# 1              4              300              420              60
#
#    itemMaxLevel  목걸이_quality  목걸이_grade  목걸이_tier  귀걸이1_quality  귀걸이1_grade  \
# 0       1385.00           76          4         3           100           6
# 1       1605.83           94          5         3            93           2
#
#    귀걸이1_tier  귀걸이2_quality  귀걸이2_grade  귀걸이2_tier  반지1_quality  반지1_grade  \
# 0          3            89           4          3           30          6
# 1          3            98           5          3           90          2
#
#    반지1_tier  반지2_quality  반지2_grade  반지2_tier  avatar_무기1_grade  \
# 0         3           74          6         3                 4
# 1         3           90          2         3                 6
#
#    avatar_무기2_grade  avatar_상의1_grade  avatar_상의2_grade  avatar_하의1_grade  \
# 0                 0                 4                 0                 4
# 1                 4                 6                 4                 6
#
#    avatar_하의2_grade  card_setName1  card_setPoint1  card_setName2  \
# 0                 0             46              30              3
# 1                 4             78              18              3
#
#    card_setPoint2  card_setName3  card_setPoint3  card_setName4  \
# 0              -1              3              -1              3
# 1              -1              3              -1              3
#
#    card_setPoint4  engraving_grantName1  engraving_grantPoint1  \
# 0              -1                    57                     12
# 1              -1                    62                     12
#
#    engraving_grantName2  engraving_grantPoint2  engraving1_name  \
# 0                    63                     12               57
# 1                    41                     12               57
#
#    engraving1_level  engraving2_name  engraving2_level  engraving3_name  \
# 0                 3               63                 3                9
# 1                 3               41                 3               63
#
#    engraving3_level  engraving4_name  engraving4_level  engraving5_name  \
# 0                 1                8                 1                0
# 1                 3               17                 3               62
#
#    engraving5_level  engraving6_name  engraving6_level  engraving7_name  \
# 0                -1                0                -1                0
# 1                 3               46                 1                0
#
#    engraving7_level  engraving8_name  engraving8_level  engraving9_name  \
# 0                -1                0                -1                0
# 1                -1                0                -1                0
#
#    engraving9_level  engraving10_name  engraving10_level  engraving11_name  \
# 0                -1                 0                 -1                 0
# 1                -1                 0                 -1                 0
#
#    engraving11_level  equipment_무기_grade  equipment_투구_grade  \
# 0                 -1                   6                   6
# 1                 -1                   2                   2
#
#    equipment_어깨_grade  equipment_상의_grade  equipment_하의_grade  \
# 0                   6                   6                   6
# 1                   2                   2                   2
#
#    equipment_장갑_grade  skill1_tripod1_point  skill1_tripod2_point  \
# 0                   6                     1                     1
# 1                   2                     1                     5
#
#    skill1_tripod3_point  skill2_tripod1_point  skill2_tripod2_point  \
# 0                    -1                     1                     1
# 1                     1                     5                     1
#
#    skill2_tripod3_point  skill3_tripod1_point  skill3_tripod2_point  \
# 0                     1                     1                     1
# 1                     1                     5                     5
#
#    skill3_tripod3_point  skill4_tripod1_point  skill4_tripod2_point  \
# 0                     1                     1                     1
# 1                     5                     1                     5
#
#    skill4_tripod3_point  skill5_tripod1_point  skill5_tripod2_point  \
# 0                     1                     1                     1
# 1                     5                     5                     5
#
#    skill5_tripod3_point  skill6_tripod1_point  skill6_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                     5                     1
#
#    skill6_tripod3_point  skill7_tripod1_point  skill7_tripod2_point  \
# 0                     1                     1                     1
# 1                     5                     5                     5
#
#    skill7_tripod3_point  skill8_tripod1_point  skill8_tripod2_point  \
# 0                     1                     1                     1
# 1                     5                     5                     5
#
#    skill8_tripod3_point  치명_값  특화_값  신속_값  제압_값  인내_값  숙련_값  gem_grade_PCA1  \
# 0                     1   977    60   745    70    66    66        5.577777
# 1                     5   648  1818    63    70    66    66       -2.534516
#
#    gem_grade_PCA2  gem_tier_PCA1  gem_tier_PCA2  gem_tier_PCA3  \
# 0        2.295992       0.981536      -2.724547       1.024957
# 1       -0.146981      -1.256543       0.268505      -0.127129
#
#    gem_level_PCA1  gem_level_PCA2  skill_tripod_point_PCA1  \
# 0        5.196017       -1.655556                -0.995203
# 1       -2.777703       -0.198544                -0.995203
#
#    skill_tripod_point_PCA2  skill_tripod_point_PCA3  skill_tripod_point_PCA4  \
# 0                 0.303625                -0.153999                 0.124141
# 1                 0.303625                -0.153999                 0.124141
#
#    equipment_setLevel_PCA1  equipment_setLevel_PCA2  equipment_quality_PCA1  \
# 0                 0.423958                 0.397790               -3.247865
# 1                 3.183604                -1.978565               -1.403668
#
#    equipment_quality_PCA2
# 0                0.059219
# 1               -0.653396

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
x = df.drop(columns=['itemMaxLevel'])
y = df['itemMaxLevel'].astype('float64')

xtr, xt, ytr, yt = train_test_split(x, y, train_size=0.7, random_state=42)

# %%
x = dfc.drop(columns=['itemMaxLevel'])
y = dfc['itemMaxLevel'].astype('float64')

xtrP, xtP, ytrP, ytP = train_test_split(x, y, train_size=0.7, random_state=42)

# %% [markdown]
# 모델 학습

# %%
# 학습에 시간이 오래 걸림
rf = RandomForestRegressor(random_state=23)
rf.fit(xtr, ytr)

joblib.dump(rf, './model/rf.pkl')
# Out:
# ['./model/rf.pkl']

# %%
rfPCA = RandomForestRegressor(random_state=23)
rfPCA.fit(xtrP, ytrP)

joblib.dump(rfPCA, './model/rfPCA.pkl')
# Out:
# ['./model/rfPCA.pkl']

# %%
# !pip install auto-sklearn
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.15.0.tar.gz (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 51.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [17 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\user\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 351, in <module>
#       main()
#     File "C:\Users\user\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 333, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "C:\Users\user\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-wh6uvjje\overlay\Lib\site-packages\setuptools\build_meta.py", line 325, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-wh6uvjje\overlay\Lib\site-packages\setuptools\build_meta.py", line 295, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-wh6uvjje\overlay\Lib\site-packages\setuptools\build_meta.py", line 480, in run_setup
#       super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#     File "C:\Users\user\AppData\Local\Temp\pip-build-env-wh6uvjje\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#       exec(code, locals())
#     File "<string>", line 10, in <module>
#   ValueError: Detected unsupported operating system: win32. Please check the compability information of auto-sklearn: https://automl.github.io/auto-sklearn/master/installation.html#windows-osx-compatibility
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import autosklearn.regression
automl = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=120, per_run_time_limit=30)
automl.fit(xtr, ytr)
joblib.dump(rf, './model/automl.pkl')

automlPCA = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=120, per_run_time_limit=30)
automlPCA.fit(xtrPCA, ytrPCA)
joblib.dump(rfPCA, './model/automlPCA.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import autosklearn.regression
#       2 automl = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=120, per_run_time_limit=30)
#       3 automl.fit(xtr, ytr)
#
# ModuleNotFoundError: No module named 'autosklearn'

# %% [markdown]
# 모델 로드

# %%
import joblib
rf = joblib.load('./model/rf.pkl')
rfPCA = joblib.load('./model/rfPCA.pkl')
automl = joblib.load('./model/automl.pkl')
automlPCA = joblin.load('./model/automlPCA.pkl')

# %% [markdown]
# 성능 평가

# %%
predict_train = rf.predict(xtr)
print(mean_squared_error(ytr, predict_train))
print(mean_absolute_error(ytr, predict_train))
print(r2_score(ytr, predict_train))

# %%
predict_train = rfPCA.predict(xtr)
print(mean_squared_error(ytrP, predict_train))
print(mean_absolute_error(ytrP, predict_train))
print(r2_score(ytrP, predict_train))

# %%
predict_train = automl.predict(xtr)
print(mean_squared_error(ytr, predict_train))
print(mean_absolute_error(ytr, predict_train))
print(r2_score(ytr, predict_train))

# %%
predict_train = automlPCA.predict(xtr)
print(mean_squared_error(ytrP, predict_train))
print(mean_absolute_error(ytrP, predict_train))
print(r2_score(ytrP, predict_train))

# %%
predict_test = rf.predict(xt)
print(mean_squared_error(yt, predict_test))
print(mean_absolute_error(yt, predict_test))
print(r2_score(yt, predict_test))

# %%
predict_test = rfPCA.predict(xt)
print(mean_squared_error(ytP, predict_test))
print(mean_absolute_error(ytP, predict_test))
print(r2_score(ytP, predict_test))

# %%
predict_test = automl.predict(xt)
print(mean_squared_error(yt, predict_test))
print(mean_absolute_error(yt, predict_test))
print(r2_score(yt, predict_test))

# %%
predict_test = automlPCA.predict(xt)
print(mean_squared_error(ytP, predict_test))
print(mean_absolute_error(ytP, predict_test))
print(r2_score(ytP, predict_test))

# %%
import lostark as lok
profile_responses = lok.get_total_profile_responses('roxy0')
if profile_responses != None:
    lok.insert_character_data('roxy0')

# %%
lok.get_df_all_raw_table('roxy0')
# Out:
#    characterCode characterName  \
# 0         570279         Roxy0
#
#                                        ArmoryProfile  \
# 0  {'CharacterImage': 'https://img.lostark.co.kr/...
#
#                                      ArmoryEquipment  \
# 0  [{'Type': '무기', 'Name': '+17 굳건한 지배의 균형 롱 스태프'...
#
#                                        ArmoryAvatars  \
# 0  [{'Type': '무기 아바타', 'Name': '고결한 귀공녀 롱 스태프', '...
#
#                                         ArmorySkills  \
# 0  [{'Name': '블레이즈', 'Icon': 'https://cdn-lostark...
#
#                                      ArmoryEngraving  \
# 0  {'Engravings': [{'Slot': 0, 'Name': '점화', 'Ico...
#
#                                           ArmoryCard  \
# 0  {'Cards': [{'Slot': 0, 'Name': '원포', 'Icon': '...
#
#                                            ArmoryGem  \
# 0  {'Gems': [{'Slot': 0, 'Name': '7레벨 멸화의 보석', 'I...
#
#                                        ColosseumInfo  \
# 0  {'Rank': 0, 'PreRank': 0, 'Exp': 0, 'Colosseum...
#
#                                         Collectibles
# 0  [{'Type': '모코코 씨앗', 'Icon': 'https://cdn-losta...

# %%
lok.get_table_df('profile_table', 'Eris0')
# Out:
#    characterCode  expeditionLevel pvpGradeName  townLevel title  \
# 0         570283              240          19급         70    거친
#
#   guildMemberGrade guildName  usingSkillPoint  totalSkillPoint   지성   담력   매력  \
# 0               임원    Rudius              414              414  606  619  547
#
#     친절 serverName characterName  characterLevel characterClassName  \
# 0  524      아브렐슈드         Eris0              60               블레이드
#
#   itemAvgLevel itemMaxLevel
# 0      1551.67      1551.67

# %%
cdf = lok.get_predict_df('Eris0')
x = cdf.drop(columns=['itemMaxLevel'])
y = cdf['itemMaxLevel'].astype('float64')
predict_data = rf.predict(x)
predict_data
# Out:
# array([1535.6002])
