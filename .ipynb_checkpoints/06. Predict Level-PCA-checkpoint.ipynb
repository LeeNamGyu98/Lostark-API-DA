# %% [markdown]
# # Info
# 본 파일은 로스트아크의 캐릭터 스펙(Feature: 각인, 보석, 카드 등)에 따른 아이템 레벨을 예측하고
#
# 현재 아이템 레벨에 비해 스펙이 낮을 경우 스펙을 높일 것을 추천하고
#
# 아이템 레벨에 비해 스펙이 높을 경우 아이템 레벨을 높일 것을 추천하는 것을 목표로 함.
#
# ---------------------------------------
# 더 나아가 어떤 스펙을 어느 정도로 올리면 좋은지도 추천해주고자 함.
#
# ----------------------------
# 현재 MAE 9~10
#
# 목표 MAE 5

# %% [markdown]
# 1. profile_table: expeditionLevel, totalSkillPoint, characterLevel, itemMaxLevel(Target)
# 2. accessory_table: accessory_quality, accessory_grade, accessory_tier
# 3. avatar_table: avatar_grade
# 4. card_table: setName, setPoint
# 5. engraving_table: grantName, grantPoint, engraving_name, engraving_level
# 6. equipment_table: equipment_quality, equipment_grade, equipment_setLevel
# 7. gem_table: gem_grade, gem_level, gem_tier
# 8. skill_table: skill_tripod_point
# 9. stats_table: stat_값

# %% [markdown]
# 추가 고려 변수
# ACC: 팔찌_effect, AS_setLevel
# EQP: 장비_alchemyName, 장비_alchemyPoint
#
# PCA
# tripod, stat
#
# ----------------
# 딜러, 서폿간의 구분으로 2개의 모델 개발?

# %%
import sys
sys.path.append('./package')
import lostark as lok

# %%
import pandas as pd
import numpy as np
import joblib
from pprint import pprint
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
tables = ['profile_table','accessory_table', 'avatar_table', 'card_table', 'engraving_table', 
         'equipment_table', 'gem_table', 'skill_table', 'stats_table']
accessories = ['목걸이', '귀걸이1', '귀걸이2', '반지1', '반지2']
accessory_column = ['_quality', '_grade', '_tier']
avatars = ['무기1', '무기2', '상의1', '상의2', '하의1', '하의2']
avatar_column = ['_grade']
equipments = ['무기', '투구', '어깨', '상의', '하의', '장갑']
equipment_column = ['_quality', '_grade', '_setLevel']
gem_column = ['_grade', '_level', '_tier']
stat_column = ['치명', '특화', '신속', '제압', '인내', '숙련']

sql = f"""SELECT profile_table.characterCode, profile_table.expeditionLevel, profile_table.totalSkillPoint,
profile_table.characterLevel, profile_table.itemMaxLevel,

{', '.join(f"accessory_table.{accessory}{column}" for accessory in accessories for column in accessory_column)},

{', '.join(f"avatar_table.{avatar}{column}" for avatar in avatars for column in avatar_column)},

{', '.join(f"card_table.setName{i}, card_table.setPoint{i}" for i in range(1, 5))},

{', '.join(f"engraving_table.grantName{i}, engraving_table.grantPoint{i}" for i in range(1, 3))},
{', '.join(f"engraving_table.engraving{i}_name, engraving_table.engraving{i}_level" for i in range(1, 12))},

{', '.join(f"equipment_table.{equipment}{column}" for equipment in equipments for column in equipment_column)},

{', '.join(f"gem_table.gem{i}{column}" for i in range(1, 12) for column in gem_column)},

{', '.join(f"skill_table.skill{i}_tripod{j}_point" for i in range(1, 17) for j in range(1, 4))},

{', '.join(f"stats_table.{column}_값" for column in stat_column)}

FROM profile_table
{' '.join(f"LEFT JOIN {tables[i+1]} ON {tables[i]}.characterCode = {tables[i+1]}.characterCode"
for i in range(len(tables)-1))};
"""
db, cursor = lok.get_db_cursor()
cursor.execute(sql)
df = pd.DataFrame(cursor.fetchall())
db.close()

# %%
columns = ["characterCode", "expeditionLevel", "totalSkillPoint", "characterLevel", "itemMaxLevel"]
for accessory in accessories:
    for column in accessory_column:
        columns.append(f"{accessory}{column}")
for avatar in avatars :
    for column in avatar_column:
        columns.append(f"avatar_{avatar}{column}") 
for i in range(1, 5):
    columns.append(f"card_setName{i}")
    columns.append(f"card_setPoint{i}")
for i in range(1, 3):
    columns.append(f"engraving_grantName{i}")
    columns.append(f"engraving_grantPoint{i}")
for i in range(1, 12):
    columns.append(f"engraving{i}_name")
    columns.append(f"engraving{i}_level")
for equipment in equipments:
    for column in equipment_column:
        columns.append(f"equipment_{equipment}{column}")
for i in range(1, 12):
    for column in gem_column:
        columns.append(f"gem{i}{column}")
for i in range(1, 17):
    for j in range(1, 4):
        columns.append(f"skill{i}_tripod{j}_point")
for column in stat_column:
    columns.append(f"{column}_값")

df.columns = columns

# %%
df.to_csv('orgin_df.csv', index=False)

# %%
# 라벨 인코딩
from sklearn.preprocessing import LabelEncoder
grade_le = LabelEncoder()
uniqueGrade = ['일반', '고급', '전설', '영웅', '희귀', '유물', '고대', '에스더', 'None']
grade_le_fit = grade_le.fit(uniqueGrade)

uniqueCardSet = []
for i in range(1, 5):
    uniqueCardSet = list(set(uniqueCardSet + list(df[f"card_setName{i}"].fillna('None').unique())))
cardSet_le = LabelEncoder()
cardSet_le_fit = cardSet_le.fit(uniqueCardSet)

uniqueEngraving = []
for i in range(1, 3):
    uniqueEngraving = list(set(uniqueEngraving + list(df[f"engraving_grantName{i}"].fillna('None').unique())))
for i in range(1, 12):
    uniqueEngraving = list(set(uniqueEngraving + list(df[f"engraving{i}_name"].fillna('None').unique())))
engraving_le = LabelEncoder()
engraving_le_fit = engraving_le.fit(uniqueEngraving)

joblib.dump(grade_le_fit, './label/grade_label.pkl')
joblib.dump(cardSet_le_fit, './label/card_label.pkl')
joblib.dump(engraving_le_fit, './label/engraving_label.pkl')
# Out:
# ['./label/engraving_label.pkl']

# %%
# 결측치 처리, 라벨 인코딩, 데이터타입 수정
df['itemMaxLevel'] = df['itemMaxLevel'].astype('float64')
for accessory in accessories:
    df[f'{accessory}_quality'] = df[f'{accessory}_quality'].fillna(-1).astype('int64')
    df[f'{accessory}_grade'] = grade_le_fit.transform(df[f'{accessory}_grade'].fillna('None'))
    df[f'{accessory}_tier'] = df[f'{accessory}_tier'].fillna(-1).astype('int64')
for avatar in avatars :
    df[f"avatar_{avatar}_grade"] =  grade_le_fit.transform(df[f"avatar_{avatar}_grade"].fillna('None'))
for i in range(1, 5):
    df[f"card_setName{i}"] = cardSet_le_fit.transform(df[f"card_setName{i}"].fillna('None'))
    df[f"card_setPoint{i}"] = df[f"card_setPoint{i}"].fillna(-1).astype('int64')
for i in range(1, 3):
    df[f"engraving_grantName{i}"] = engraving_le_fit.transform(df[f"engraving_grantName{i}"].fillna('None'))
    df[f"engraving_grantPoint{i}"] = df[f"engraving_grantPoint{i}"].fillna('-1').astype('int64')
for i in range(1, 12):
    df[f"engraving{i}_name"] = engraving_le_fit.transform(df[f"engraving{i}_name"].fillna('None'))
    df[f"engraving{i}_level"] = df[f"engraving{i}_level"].fillna(-1).astype('int64')
for equipment in equipments:
    df[f"equipment_{equipment}_grade"] = grade_le_fit.transform(df[f"equipment_{equipment}_grade"].fillna('None'))  
    df[f"equipment_{equipment}_setLevel"] = df[f"equipment_{equipment}_setLevel"].fillna(-1).astype('int64')
    df[f"equipment_{equipment}_quality"] = df[f"equipment_{equipment}_quality"].fillna(-1).astype('int64')
for i in range(1, 12):
    df[f"gem{i}_grade"] = grade_le_fit.transform(df[f"gem{i}_grade"].fillna('None'))
    df[f"gem{i}_level"] = df[f"gem{i}_level"].fillna(-1).astype('int64')
    df[f"gem{i}_tier"] = df[f"gem{i}_tier"].fillna(-1).astype('int64')
for i in range(1, 17):
    for j in range(1, 4):
        df[f"skill{i}_tripod{j}_point"] = df[f"skill{i}_tripod{j}_point"].fillna(-1).astype('int64')

# %%
df.to_csv('df.csv', index=False)

# %% [markdown]
# 아래는 다중공선성을 고려하여 PCA를 적용한 데이터

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scale = scaler.fit_transform(df)
df_scale = pd.DataFrame(df_scale, columns=df.columns)
joblib.dump(scaler, './Scaler/Scaler.pkl')
# Out:
# ['./Scaler/Scaler.pkl']

# %%
dfc = df.copy()
from sklearn.decomposition import PCA
# gem grade
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'gem{i}_grade' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/gem_grade_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_grade_PCA1', 'gem_grade_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# gem tier
n_components = 3
pca = PCA(n_components=n_components)
columns = [f'gem{i}_tier' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/gem_tier_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_tier_PCA1', 'gem_tier_PCA2', 'gem_tier_PCA3'])
dfc = pd.concat([dfc, df_pca], axis=1)

# gem level
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'gem{i}_level' for i in range(1, 12)]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/gem_level_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['gem_level_PCA1', 'gem_level_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# skill tripod point
n_components = 4
pca = PCA(n_components=n_components)
columns = [f'skill{i}_tripod{j}_point' for i in range(9, 17) for j in range(1, 4)]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/skill_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['skill_tripod_point_PCA1', 'skill_tripod_point_PCA2',
    'skill_tripod_point_PCA3', 'skill_tripod_point_PCA4'])
dfc = pd.concat([dfc, df_pca], axis=1)

# equipment grade
n_components = 1
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_grade' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/equipment_grade_PCA.pkl')
df.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_grade_PCA1'])
df = pd.concat([df, df_pca], axis=1)

# euqipment setLevel
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_setLevel' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/equipment_setLevel_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_setLevel_PCA1', 'equipment_setLevel_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)

# euqipment quality
n_components = 2
pca = PCA(n_components=n_components)
columns = [f'equipment_{e}_quality' for e in equipments]
df_pca = pca.fit_transform(df_scale[columns])
joblib.dump(pca, './PCA/equipment_quality_PCA.pkl')
dfc.drop(columns, axis=1, inplace=True)
df_pca = pd.DataFrame(df_pca, columns=['equipment_quality_PCA1', 'equipment_quality_PCA2'])
dfc = pd.concat([dfc, df_pca], axis=1)


# explained_variance_ratio = pca.explained_variance_ratio_
# print("Explained Variance Ratio:", explained_variance_ratio)
# print("Total Explained Variance:", np.sum(explained_variance_ratio))

# cumulative_explained_variance_ratio = np.cumsum(explained_variance_ratio)
# print("Cumulative Explained Variance Ratio:", cumulative_explained_variance_ratio)

# import matplotlib.pyplot as plt
# plt.plot(pca.explained_variance_ratio_)

# %%
dfc.head(2)
# Out:
#    characterCode  expeditionLevel  totalSkillPoint  characterLevel  \
# 0              1              300              420              60
# 1              2                0                0               1
#
#    itemMaxLevel  목걸이_quality  목걸이_grade  목걸이_tier  귀걸이1_quality  귀걸이1_grade  \
# 0        1385.0           76          4         3           100           7
# 1           0.0           -1          0        -1            -1           0
#
#    귀걸이1_tier  귀걸이2_quality  귀걸이2_grade  귀걸이2_tier  반지1_quality  반지1_grade  \
# 0          3            89           4          3           30          7
# 1         -1            -1           0         -1           -1          0
#
#    반지1_tier  반지2_quality  반지2_grade  반지2_tier  avatar_무기1_grade  \
# 0         3           74          7         3                 4
# 1        -1           -1          0        -1                 0
#
#    avatar_무기2_grade  avatar_상의1_grade  avatar_상의2_grade  avatar_하의1_grade  \
# 0                 0                 4                 0                 4
# 1                 0                 0                 0                 0
#
#    avatar_하의2_grade  card_setName1  card_setPoint1  card_setName2  \
# 0                 0             48              30              3
# 1                 0              3              -1              3
#
#    card_setPoint2  card_setName3  card_setPoint3  card_setName4  \
# 0              -1              3              -1              3
# 1              -1              3              -1              3
#
#    card_setPoint4  engraving_grantName1  engraving_grantPoint1  \
# 0              -1                    58                     12
# 1              -1                     0                     -1
#
#    engraving_grantName2  engraving_grantPoint2  engraving1_name  \
# 0                    64                     12               58
# 1                     0                     -1                0
#
#    engraving1_level  engraving2_name  engraving2_level  engraving3_name  \
# 0                 3               64                 3                9
# 1                -1                0                -1                0
#
#    engraving3_level  engraving4_name  engraving4_level  engraving5_name  \
# 0                 1                8                 1                0
# 1                -1                0                -1                0
#
#    engraving5_level  engraving6_name  engraving6_level  engraving7_name  \
# 0                -1                0                -1                0
# 1                -1                0                -1                0
#
#    engraving7_level  engraving8_name  engraving8_level  engraving9_name  \
# 0                -1                0                -1                0
# 1                -1                0                -1                0
#
#    engraving9_level  engraving10_name  engraving10_level  engraving11_name  \
# 0                -1                 0                 -1                 0
# 1                -1                 0                 -1                 0
#
#    engraving11_level  equipment_무기_grade  equipment_투구_grade  \
# 0                 -1                   7                   7
# 1                 -1                   0                   0
#
#    equipment_어깨_grade  equipment_상의_grade  equipment_하의_grade  \
# 0                   7                   7                   7
# 1                   0                   0                   0
#
#    equipment_장갑_grade  skill1_tripod1_point  skill1_tripod2_point  \
# 0                   7                     1                     1
# 1                   0                    -1                    -1
#
#    skill1_tripod3_point  skill2_tripod1_point  skill2_tripod2_point  \
# 0                    -1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill2_tripod3_point  skill3_tripod1_point  skill3_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill3_tripod3_point  skill4_tripod1_point  skill4_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill4_tripod3_point  skill5_tripod1_point  skill5_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill5_tripod3_point  skill6_tripod1_point  skill6_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill6_tripod3_point  skill7_tripod1_point  skill7_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill7_tripod3_point  skill8_tripod1_point  skill8_tripod2_point  \
# 0                     1                     1                     1
# 1                    -1                    -1                    -1
#
#    skill8_tripod3_point   치명_값  특화_값   신속_값  제압_값  인내_값  숙련_값  gem_grade_PCA1  \
# 0                     1  977.0  60.0  745.0  70.0  66.0  66.0       -0.687281
# 1                    -1    NaN   NaN    NaN   NaN   NaN   NaN       -2.307297
#
#    gem_grade_PCA2  gem_tier_PCA1  gem_tier_PCA2  gem_tier_PCA3  \
# 0        0.100378       2.614000       2.505860      -1.266337
# 1       -0.119824      -2.450812      -0.135185      -0.066015
#
#    gem_level_PCA1  gem_level_PCA2  skill_tripod_point_PCA1  \
# 0       -0.381986        0.635057                 -0.61873
# 1       -2.359670       -0.123886                 -0.61873
#
#    skill_tripod_point_PCA2  skill_tripod_point_PCA3  skill_tripod_point_PCA4  \
# 0                 0.180154                -0.090794                 0.071865
# 1                 0.180154                -0.090794                 0.071865
#
#    equipment_setLevel_PCA1  equipment_setLevel_PCA2  equipment_quality_PCA1  \
# 0                 0.786934                 0.068493                3.419260
# 1                -2.491830                 0.237591               -3.182018
#
#    equipment_quality_PCA2
# 0                0.111737
# 1                0.041192

# %%
dfc.to_csv('dfPCA.csv', index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
x = df.drop(columns=['itemMaxLevel'])
y = df['itemMaxLevel'].astype('float64')

xtr, xt, ytr, yt = train_test_split(x, y, train_size=0.7, random_state=42)

# %%
x = dfc.drop(columns=['itemMaxLevel'])
y = dfc['itemMaxLevel'].astype('float64')

xtrP, xtP, ytrP, ytP = train_test_split(x, y, train_size=0.7, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x = dfc.drop(columns=['itemMaxLevel'])
#       2 y = dfc['itemMaxLevel'].astype('float64')
#       4 xtrP, xtP, ytrP, ytP = train_test_split(x, y, train_size=0.7, random_state=42)
#
# NameError: name 'dfc' is not defined

# %% [markdown]
# 모델 학습

# %%
# 학습에 시간이 오래 걸림
rf = RandomForestRegressor(random_state=23)
rf.fit(xtr, ytr)

joblib.dump(rf, './model/rf.pkl')
# Out:
# ['./model/rf.pkl']

# %%
rfPCA = RandomForestRegressor(random_state=23)
rfPCA.fit(xtrP, ytrP)

joblib.dump(rfPCA, './model/rfPCA.pkl')
# Out:
# ['./model/rfPCA.pkl']

# %% [markdown]
# 모델 로드

# %%
import joblib
model = joblib.load('./model/Auto.pkl')
modelPCA = joblib.load('./model/AutoPCA.pkl')

# %% [markdown]
# 성능 평가

# %%
predict_train = model.predict(xtr)
print(mean_squared_error(ytr, predict_train))
print(mean_absolute_error(ytr, predict_train))
print(r2_score(ytr, predict_train))
# Out:
# 183.48156038850962
# 10.016712048876864
# 0.9634976697266031

# %%
predict_train = modelPCA.predict(xtrP)
print(mean_squared_error(ytrP, predict_train))
print(mean_absolute_error(ytrP, predict_train))
print(r2_score(ytrP, predict_train))
# Out:
# 175.8329985817211
# 9.81693471950053
# 0.9650192958158773

# %% [markdown]
# ---

# %%
predict_test = model.predict(xt)
print(mean_squared_error(yt, predict_test))
print(mean_absolute_error(yt, predict_test))
print(r2_score(yt, predict_test))
# Out:
# 184.49732150095295
# 10.028431709412569
# 0.9630768522567383

# %%
predict_test = modelPCA.predict(xtP)
print(mean_squared_error(ytP, predict_test))
print(mean_absolute_error(ytP, predict_test))
print(r2_score(ytP, predict_test))
# Out:
# 175.90177204801654
# 9.824259420690016
# 0.9647970655357352

# %%
import lostark as lok
profile_responses = lok.get_total_profile_responses('roxy0')
if profile_responses != None:
    lok.insert_character_data('roxy0')

# %%
lok.get_df_all_raw_table('roxy0')
# Out:
#    characterCode characterName  \
# 0         570279         Roxy0
#
#                                        ArmoryProfile  \
# 0  {'CharacterImage': 'https://img.lostark.co.kr/...
#
#                                      ArmoryEquipment  \
# 0  [{'Type': '무기', 'Name': '+17 굳건한 지배의 균형 롱 스태프'...
#
#                                        ArmoryAvatars  \
# 0  [{'Type': '무기 아바타', 'Name': '고결한 귀공녀 롱 스태프', '...
#
#                                         ArmorySkills  \
# 0  [{'Name': '블레이즈', 'Icon': 'https://cdn-lostark...
#
#                                      ArmoryEngraving  \
# 0  {'Engravings': [{'Slot': 0, 'Name': '점화', 'Ico...
#
#                                           ArmoryCard  \
# 0  {'Cards': [{'Slot': 0, 'Name': '원포', 'Icon': '...
#
#                                            ArmoryGem  \
# 0  {'Gems': [{'Slot': 0, 'Name': '7레벨 멸화의 보석', 'I...
#
#                                        ColosseumInfo  \
# 0  {'Rank': 0, 'PreRank': 0, 'Exp': 0, 'Colosseum...
#
#                                         Collectibles
# 0  [{'Type': '모코코 씨앗', 'Icon': 'https://cdn-losta...

# %%
lok.get_table_df('profile_table', 'Eris0')
# Out:
#    characterCode  expeditionLevel pvpGradeName  townLevel title  \
# 0         570283              240          19급         70    거친
#
#   guildMemberGrade guildName  usingSkillPoint  totalSkillPoint   지성   담력   매력  \
# 0               임원    Rudius              414              414  606  619  547
#
#     친절 serverName characterName  characterLevel characterClassName  \
# 0  524      아브렐슈드         Eris0              60               블레이드
#
#   itemAvgLevel itemMaxLevel
# 0      1551.67      1551.67

# %%
import sys
sys.path.append('./package')
import lostark as lok

# %%
import joblib
model = joblib.load('./model/Auto.pkl')
modelPCA = joblib.load('./model/AutoPCA.pkl')

# %%
cdf = lok.get_predict_df('연료전지')
x = cdf.drop(columns=['itemMaxLevel'])
y = cdf['itemMaxLevel'].astype('float64')
predict_data = model.predict(x)
predict_data
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[3], line 4
#       2 x = cdf.drop(columns=['itemMaxLevel'])
#       3 y = cdf['itemMaxLevel'].astype('float64')
# ----> 4 predict_data = model.predict(x)
#       5 predict_data
#
# File ~\anaconda3\lib\site-packages\catboost\core.py:5748, in CatBoostRegressor.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5746 if prediction_type is None:
#    5747     prediction_type = self._get_default_prediction_type()
# -> 5748 return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File ~\anaconda3\lib\site-packages\catboost\core.py:2508, in CatBoost._predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name, task_type)
#    2505 data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2506 self._validate_prediction_type(prediction_type)
# -> 2508 predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    2509 return predictions[0] if data_is_single_object else predictions
#
# File ~\anaconda3\lib\site-packages\catboost\core.py:1775, in _CatBoostBase._base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    1774 def _base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type):
# -> 1775     return self._object._base_predict(pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#
# File _catboost.pyx:4781, in _catboost._CatBoost._base_predict()
#
# File _catboost.pyx:4788, in _catboost._CatBoost._base_predict()
#
# CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 60 should be feature with name equipment_무기_setLevel (found equipment_무기_grade).

# %%
# !pip install pycaret[notebook]
# Out:
# Collecting pycaret[notebook]
#   Using cached pycaret-3.2.0-py3-none-any.whl (484 kB)
# Requirement already satisfied: cloudpickle in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (2.0.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (5.9.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (3.1.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (1.5.3)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (2.1.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (1.23.5)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting matplotlib<=3.6,>=3.3.0
#   Using cached matplotlib-3.6.0-cp310-cp310-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numba>=0.55.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (0.56.4)
# Collecting importlib-metadata>=4.12.0
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (8.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (0.13.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (4.64.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (7.6.5)
# Collecting tbats>=1.1.3
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (0.2.1)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (0.10.1)
# Collecting schemdraw==0.15
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (2.28.1)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1
#   Using cached sktime-0.21.1-py3-none-any.whl (17.1 MB)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Using cached pmdarima-2.0.4-cp310-cp310-win_amd64.whl (613 kB)
# Collecting pyod>=1.0.8
#   Using cached pyod-1.1.3-py3-none-any.whl
# Requirement already satisfied: plotly>=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (5.9.0)
# Collecting deprecation>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting plotly-resampler>=0.8.3.1
#   Using cached plotly_resampler-0.9.2-py3-none-any.whl (81 kB)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (1.2.1)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-4.3.0-py3-none-win_amd64.whl (1.3 MB)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (5.7.0)
# Requirement already satisfied: xxhash in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (3.4.1)
# Requirement already satisfied: scipy~=1.10.1 in c:\users\user\anaconda3\lib\site-packages (from pycaret[notebook]) (1.10.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\user\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret[notebook]) (0.5.3)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret[notebook]) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret[notebook]) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret[notebook]) (3.11.0)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (5.7.1)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (3.0.36)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.1.6)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.18.1)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.2.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret[notebook]) (2.11.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret[notebook]) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret[notebook]) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret[notebook]) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret[notebook]) (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret[notebook]) (3.0.9)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret[notebook]) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret[notebook]) (5.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret[notebook]) (2.16.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\user\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret[notebook]) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret[notebook]) (65.6.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret[notebook]) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret[notebook]) (8.0.1)
# Collecting orjson<4.0.0,>=3.8.0
#   Using cached orjson-3.9.13-cp310-none-win_amd64.whl (134 kB)
# Collecting dash>=2.9.0
#   Using cached dash-2.15.0-py3-none-any.whl (10.2 MB)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\user\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret[notebook]) (0.1.2)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[notebook]) (1.26.14)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Using cached Cython-3.0.8-cp310-cp310-win_amd64.whl (2.8 MB)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret[notebook]) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret[notebook]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret[notebook]) (2022.12.7)
# Collecting scikit-base<0.6.0
#   Using cached scikit_base-0.5.2-py3-none-any.whl (118 kB)
# Collecting deprecated>=1.2.13
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (2.2.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (4.4.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (2.0.0)
# Collecting retrying
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (2.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (1.5.6)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (5.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\user\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret[notebook]) (1.14.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[notebook]) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[notebook]) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[notebook]) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret[notebook]) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\user\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[notebook]) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[notebook]) (305.1)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[notebook]) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[notebook]) (2.0.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[notebook]) (0.8.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\user\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\user\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[notebook]) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[notebook]) (0.4)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (21.3.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.23.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (4.11.1)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (4.9.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.2.1)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\user\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret[notebook]) (2.21)
# Installing collected packages: scikit-base, schemdraw, retrying, orjson, joblib, importlib-metadata, deprecation, deprecated, Cython, matplotlib, lightgbm, yellowbrick, sktime, scikit-plot, pyod, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.0
#     Uninstalling matplotlib-3.7.0:
#       Successfully uninstalled matplotlib-3.7.0
# Successfully installed Cython-3.0.8 category-encoders-2.6.3 dash-2.15.0 deprecated-1.2.14 deprecation-2.1.0 importlib-metadata-7.0.1 joblib-1.3.2 lightgbm-4.3.0 matplotlib-3.6.0 orjson-3.9.13 plotly-resampler-0.9.2 pmdarima-2.0.4 pycaret-3.2.0 pyod-1.1.3 retrying-1.3.4 schemdraw-0.15 scikit-base-0.5.2 scikit-plot-0.3.7 sktime-0.21.1 tbats-1.1.3 yellowbrick-1.5
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: pycaret 3.2.0 does not provide the extra 'notebook'
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\user\anaconda3\lib\site-packages)

# %%
from pycaret.regression import *
