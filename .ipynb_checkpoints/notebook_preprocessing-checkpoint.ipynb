# %%
import pandas as pd
from pprint import pprint
import traceback

# %%
import re
float_pattern = re.compile(r'\d+\.\d+')
int_pattern = re.compile(r'\d+')
# armory skill
resource_pattern = re.compile(r'마나|배터리|버블|충격|기공|기력|내공')
# armory equipment
archemy_pattern = re.compile(r'\](.*?)Lv\.(\d+)')
plus_pattern = re.compile(r'([^\s]+)\s*\+([\d]+)')
bracelet_pattern = re.compile(r'\[.*?\[')

# %%
def flatten_dict(d, parent_key='', sep='_'):
    items={}
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        try:
            v = eval(v)
        except:
            pass
        
        if isinstance(v, dict):
            items.update(flatten_dict(v, new_key, sep))
        else:
            items[new_key] = v
    return items

# %%
def print_exception(fd, sk, sv, e):
    traceback.print_exc()
    pprint(fd)
    print(sk, sv)
    print(e)

# %%
def print_exception_db(value, e):
    traceback.print_exc()
    print("Error inserting record:", e)
    print("characterCode:", value['characterCode'])
    print(value)
    print("Current time:", datetime.datetime.now())

# %%
def return_value(value, table):
    return table + "['" + value + "']"

# %% [markdown]
# # ArmoryProfile

# %%
df = pd.read_csv('./data/ArmoryProfile.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
# profile table
sql = """
INSERT INTO Profile (
expeditionLevel, pvpGradeName, townLevel, title, guildMemberGrade, guildName, 
usingSkillPoint, totalSkillPoint,
지성, 담력, 매력, 친절,
severName, characterName, characterLevel, characterClassName, itemAvgLevel, itemMaxLevel)
VALUES (%s, %s, %s, %s, %s, %s, 
# %s, %s, 
# %s, %s, %s, %s, 
# %s, %s, %s, %s, %s, %s);
"""

# %%
# stats table
sql2 = """ INSERT INTO Stats(
치명_값, 치명_내실증가량, 치명_치명타_적중률(%),
특화_값, 특화_내실증가량, 특화_각성스킬_피해량(%), 특화_효과1, 특화_효과2, 특화_효과3,
제압_값, 제압_내실증가량, 제압_피해증가량(%),
신속_값, 신속_내실증가량, 신속_공격속도(%), 신속_이동속도(%), 신속_스킬_재사용대기시간_감소율(%),
인내_값, 인내_내실증가량, 인내_물리방어력(%), 인내_마법방어력(%), 인내_보호막효과(%), 인내_생명력_회복효과(%),
숙련_값, 숙련_내실증가량, 숙련_상태이상_공격_지속시간(%), 숙련_상태이상_피해_지속시간(%), 숙련_무력화_피해량(%),
최대생명력_값, 최대생명력_체력, 최대생명력_생명활성력(%),
공격력_값, 공격력_기본공격력, 공격력_증감량)
VALUES (
# %s, %s, %s, 
# %s, %s, %s, %s, %s, %s,
# %s, %s, %s, 
# %s, %s, %s, %s, %s, 
# %s, %s, %s, %s, %s, %s, 
# %s, %s, %s, %s, %s, 
# %s, %s, %s, 
# %s, %s, %s)
"""

# %%
stats = {'characterCode' : df['characterCode'][i],
            '치명_값':None, '치명_내실증가량':None, '치명_치명타_적중률(%)':None,
            '특화_값':None, '특화_내실증가량':None, '특화_각성스킬_피해량(%)':None, '특화_효과1':None,
            '특화_효과2':None, '특화_효과3':None,
            '제압_값':None, '제압_내실증가량':None, '제압_피해증가량(%)':None,
            '신속_값':None, '신속_내실증가량':None, '신속_공격속도(%)':None, '신속_이동속도(%)':None,
            '신속_스킬_재사용대기시간_감소율(%)':None,
            '인내_값':None, '인내_내실증가량': None, '인내_물리방어력(%)':None, '인내_마법방어력(%)':None,
            '인내_보호막효과(%)':None, '인내_생명력_회복효과(%)':None,
            '숙련_값':None, '숙련_내실증가량':None, '숙련_상태이상_공격_지속시간(%)':None,
            '숙련_상태이상_피해_지속시간(%)':None, '숙련_무력화_피해량(%)':None,
            '최대생명력_값':None, '최대생명력_체력':None, '최대생명력_생명활성력(%)':None,
            '공격력_값':None, '공격력_기본공격력':None, '공격력_증감량':None}

# %%
for i in range(10000):
    cdf = eval(df['data'][i])
    del cdf['CharacterImage']
    
    # 1. profile
    profile = cdf.copy()
    profile['characterCode'] = df['characterCode'][i]
    profile['지성'] = profile['Tendencies'][0]['Point']
    profile['담력'] = profile['Tendencies'][1]['Point']
    profile['매력'] = profile['Tendencies'][2]['Point']
    profile['친절'] = profile['Tendencies'][3]['Point']
    
    del profile['Tendencies']
    del profile['Stats']
    
    # 2. stats
    for k, v in cdf.items():
        if (k == 'Stats') & (v != None):
            stats['치명_값'] = int(v[0]['Value'])
            stats['치명_내실증가량'] = int(int_pattern.findall(v[0]['Tooltip'][1])[0])
            stats['치명_치명타_적중률(%)'] = float(float_pattern.search(v[0]['Tooltip'][0]).group())

            stats['특화_값'] = int(v[1]['Value'])
            stats['특화_내실증가량'] = int(int_pattern.findall(v[1]['Tooltip'][-2])[0])
            try: # 전직 했을 경우
                stats['특화_각성스킬_피해량(%)'] = float(float_pattern.search(v[1]['Tooltip'][-3]).group())
                stats['특화_효과1'] = v[1]['Tooltip'][0]
                stats['특화_효과2'] =  v[1]['Tooltip'][1]
                stats['특화_효과3'] = None if len(v[1]['Tooltip']) == 5 else v[1]['Tooltip'][2]
            except: # 전직 안했을 경우
                stats['특화_각성스킬_피해량(%)'] = None
                stats['특화_효과1'] = None
                stats['특화_효과2'] =  None
                stats['특화_효과3'] = None
            

            stats['제압_값'] = int(v[2]['Value'])
            stats['제압_내실증가량'] = int(int_pattern.findall(v[2]['Tooltip'][2])[0])
            stats['제압_피해증가량(%)'] = float(float_pattern.search(v[2]['Tooltip'][0]).group())

            stats['신속_값'] = int(v[3]['Value'])
            stats['신속_내실증가량'] =  int(int_pattern.findall(v[3]['Tooltip'][-2])[0])
            stats['신속_공격속도(%)'] = float(float_pattern.search(v[3]['Tooltip'][0]).group())
            stats['신속_이동속도(%)'] = float(float_pattern.search(v[3]['Tooltip'][1]).group())
            stats['신속_스킬_재사용대기시간_감소율(%)'] = float(float_pattern.search(v[3]['Tooltip'][2]).group())

            stats['인내_값'] = int(v[4]['Value'])
            stats['인내_내실증가량'] = int(int_pattern.findall(v[4]['Tooltip'][-2])[0])
            stats['인내_물리방어력(%)'] = float(float_pattern.search(v[4]['Tooltip'][0]).group())
            stats['인내_마법방어력(%)'] = float(float_pattern.search(v[4]['Tooltip'][1]).group())
            stats['인내_보호막효과(%)'] =  float(float_pattern.search(v[4]['Tooltip'][2]).group())
            stats['인내_생명력_회복효과(%)'] = float(float_pattern.search(v[4]['Tooltip'][3]).group())

            stats['숙련_값'] =  int(v[5]['Value'])
            stats['숙련_내실증가량'] = int(re.findall(r'\d+', v[5]['Tooltip'][-2])[0])
            stats['숙련_상태이상_공격_지속시간(%)'] = float(float_pattern.search(v[5]['Tooltip'][0]).group())
            stats['숙련_상태이상_피해_지속시간(%)'] =  float(float_pattern.search(v[5]['Tooltip'][1]).group())
            stats['숙련_무력화_피해량(%)'] = float(float_pattern.search(v[5]['Tooltip'][2]).group())

            stats['최대생명력_값'] = int(v[6]['Value'])
            stats['최대생명력_체력'] = int(int_pattern.findall(v[6]['Tooltip'][1])[0])
            stats['최대생명력_생명활성력(%)'] = float(float_pattern.search(v[6]['Tooltip'][2]).group())

            stats['공격력_값'] = int(v[7]['Value'])
            stats['공격력_기본공격력'] =  int(int_pattern.findall(v[7]['Tooltip'][1])[0])
            stats['공격력_증감량'] = int(int_pattern.findall(v[7]['Tooltip'][2])[0])

# %% [markdown]
# # ArmoryAvatars

# %%
df = pd.read_csv('./data/ArmoryAvatars.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
avatar_parts = ['무기1', '무기2', '머리', '상의1', '상의2', '하의1', '하의2', '얼굴1', '얼굴2', '악기', '이동효과'] 
dic_keys = ['grade', 'isInner', 'isSet', 'name', 'avatarType', 'avatarType2', 'availableClass', 
            'availableTrade', 'attribution', 'statEffect(%)', '매력', '지성', '담력', '친절', 'availableSale', 
            'dyeable', 'decomposable']
avatars = {
    'characterCode': None,
}
for part in avatar_parts:
    for key in dic_keys:
        avatars[f'{part}_{key}'] = None

# %%
def return_tendency(text, tendency):
    try:
        # "tendency : " 다음의 숫자 위치를 찾습니다
        start_idx = text.find(f'{tendency} : ') + len(f'{tendency} : ')
        # 숫자가 시작하는 인덱스부터 숫자가 끝나는 인덱스까지 슬라이싱합니다
        number = text[start_idx:].split()[0]
        return int(number)
    except:
        return None

# %%
def set_avatar(avatar, fd, parts):
    avatar[f'{parts}_grade'] = fd['Grade']
    avatar[f'{parts}_isInner'] = fd['IsInner']
    avatar[f'{parts}_isSet'] = fd['IsSet']
    avatar[f'{parts}_name'] = fd['Name']
    avatar[f'{parts}_avatarType'] = fd['Type']
    
    for k, v in fd.items():
        sv = str(v)
        if (('희귀' in sv) | ('영웅' in sv) | ('전설' in sv)) & ('아바타' in sv): 
            avatar[f'{parts}_avatarType2'] = v
        elif ('전용' in sv) or ('계열' in sv):
            avatar[f'{parts}_availableClass'] = v
        elif '귀속' in sv:
            if (sv == '원정대 귀속됨 ') or (sv == '캐릭터 귀속됨') or ('(귀속)' in sv):
                avatar[f'{parts}_attribution'] = True
                avatar[f'{parts}_availableTrade'] = 0
            else:
                avatar[f'{parts}_attribution'] = False
                avatar[f'{parts}_availableTrade'] = int(int_pattern.findall(sv)[0])
        elif '+' in sv:
            avatar[f'{parts}_statEffect(%)'] = float(float_pattern.search(sv).group())
        elif ('매력' in sv) or ('지성' in sv) or ('담력' in sv) or ('친절' in sv):
            if ('매력' in sv):
                avatar[f'{parts}_매력'] = return_tendency(sv, '매력')
            if ('지성' in sv):
                avatar[f'{parts}_지성'] = return_tendency(sv, '지성')
            if ('담력' in sv):
                avatar[f'{parts}_담력'] = return_tendency(sv, '담력')
            if ('친절' in sv):
                avatar[f'{parts}_친절'] = return_tendency(sv, '친절')
        elif ('판매' in sv) or ('분해' in sv) or ('염색' in sv):
            avatar[f'{parts}_availableSale'] = '판매불가' not in sv
            avatar[f'{parts}_dyeable'] = '염색불가' not in sv
            avatar[f'{parts}_decomposable'] = '분해불가' not in sv
    return avatar

# %%
# CREATE TABLE `lostark`.`avatar_table` (
#   `characterCode` MEDIUMINT NOT NULL,
#   PRIMARY KEY (`characterCode`),
#   UNIQUE INDEX `characterCode_UNIQUE` (`characterCode` ASC) VISIBLE,
#   CONSTRAINT `avatar_characterCode`
#     FOREIGN KEY (`characterCode`)
#     REFERENCES `lostark`.`profile_table` (`characterCode`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION);

# %%
# ALTER TABLE `lostark`.`avatar_table` 
# ADD COLUMN `무기1_grade` VARCHAR(4) NULL AFTER `characterCode`,
# ADD COLUMN `무기1_isInner` TINYINT NULL AFTER `무기1_grade`,
# ADD COLUMN `무기1_isSet` TINYINT NULL AFTER `무기1_isInner`,
# ADD COLUMN `무기1_name` VARCHAR(16) NULL AFTER `무기1_isSet`,
# ADD COLUMN `무기1_avatarType` VARCHAR(12) NULL AFTER `무기1_name`,
# ADD COLUMN `무기1_avatarType2` VARCHAR(16) NULL AFTER `무기1_avatarType`,
# ADD COLUMN `무기1_abvailableClass` VARCHAR(12) NULL AFTER `무기1_avatarType2`,
# ADD COLUMN `무기1_availableTrade` TINYINT NULL AFTER `무기1_abvailableClass`,
# ADD COLUMN `무기1_attribution` TINYINT NULL AFTER `무기1_availableTrade`,
# ADD COLUMN `무기1_statEffect(%)` DECIMAL(2,1) NULL AFTER `무기1_attribution`,
# ADD COLUMN `무기1_매력` TINYINT NULL AFTER `무기1_statEffect(%)`,
# ADD COLUMN `무기1_지성` TINYINT NULL AFTER `무기1_매력`,
# ADD COLUMN `무기1_담력` TINYINT NULL AFTER `무기1_지성`,
# ADD COLUMN `무기1_친절` TINYINT NULL AFTER `무기1_담력`,
# ADD COLUMN `무기1_availableSale` TINYINT NULL AFTER `무기1_친절`,
# ADD COLUMN `무기1_dyeable` TINYINT NULL AFTER `무기1_availableSale`,
# ADD COLUMN `무기1_decomposable` TINYINT NULL AFTER `무기1_dyeable`,
# ADD COLUMN `무기2_grade` VARCHAR(4) NULL AFTER `무기1_decomposable`,
# ADD COLUMN `무기2_isInner` TINYINT NULL AFTER `무기2_grade`,
# ADD COLUMN `무기2_isSet` TINYINT NULL AFTER `무기2_isInner`,
# ADD COLUMN `무기2_name` VARCHAR(16) NULL AFTER `무기2_isSet`,
# ADD COLUMN `무기2_avatarType` VARCHAR(12) NULL AFTER `무기2_name`,
# ADD COLUMN `무기2_avatarType2` VARCHAR(16) NULL AFTER `무기2_avatarType`,
# ADD COLUMN `무기2_abvailableClass` VARCHAR(12) NULL AFTER `무기2_avatarType2`,
# ADD COLUMN `무기2_availableTrade` TINYINT NULL AFTER `무기2_abvailableClass`,
# ADD COLUMN `무기2_attribution` TINYINT NULL AFTER `무기2_availableTrade`,
# ADD COLUMN `무기2_statEffect(%)` DECIMAL(2,1) NULL AFTER `무기2_attribution`,
# ADD COLUMN `무기2_매력` TINYINT NULL AFTER `무기2_statEffect(%)`,
# ADD COLUMN `무기2_지성` TINYINT NULL AFTER `무기2_매력`,
# ADD COLUMN `무기2_담력` TINYINT NULL AFTER `무기2_지성`,
# ADD COLUMN `무기2_친절` TINYINT NULL AFTER `무기2_담력`,
# ADD COLUMN `무기2_availableSale` TINYINT NULL AFTER `무기2_친절`,
# ADD COLUMN `무기2_dyeable` TINYINT NULL AFTER `무기2_availableSale`,
# ADD COLUMN `무기2_decomposable` TINYINT NULL AFTER `무기2_dyeable`,
# ADD COLUMN `상의1_grade` VARCHAR(4) NULL AFTER `무기2_decomposable`,
# ADD COLUMN `상의1_isInner` TINYINT NULL AFTER `상의1_grade`,
# ADD COLUMN `상의1_isSet` TINYINT NULL AFTER `상의1_isInner`,
# ADD COLUMN `상의1_name` VARCHAR(16) NULL AFTER `상의1_isSet`,
# ADD COLUMN `상의1_avatarType` VARCHAR(12) NULL AFTER `상의1_name`,
# ADD COLUMN `상의1_avatarType2` VARCHAR(16) NULL AFTER `상의1_avatarType`,
# ADD COLUMN `상의1_abvailableClass` VARCHAR(12) NULL AFTER `상의1_avatarType2`,
# ADD COLUMN `상의1_availableTrade` TINYINT NULL AFTER `상의1_abvailableClass`,
# ADD COLUMN `상의1_attribution` TINYINT NULL AFTER `상의1_availableTrade`,
# ADD COLUMN `상의1_statEffect(%)` DECIMAL(2,1) NULL AFTER `상의1_attribution`,
# ADD COLUMN `상의1_매력` TINYINT NULL AFTER `상의1_statEffect(%)`,
# ADD COLUMN `상의1_지성` TINYINT NULL AFTER `상의1_매력`,
# ADD COLUMN `상의1_담력` TINYINT NULL AFTER `상의1_지성`,
# ADD COLUMN `상의1_친절` TINYINT NULL AFTER `상의1_담력`,
# ADD COLUMN `상의1_availableSale` TINYINT NULL AFTER `상의1_친절`,
# ADD COLUMN `상의1_dyeable` TINYINT NULL AFTER `상의1_availableSale`,
# ADD COLUMN `상의1_decomposable` TINYINT NULL AFTER `상의1_dyeable`,
# ADD COLUMN `상의2_grade` VARCHAR(4) NULL AFTER `상의1_decomposable`,
# ADD COLUMN `상의2_isInner` TINYINT NULL AFTER `상의2_grade`,
# ADD COLUMN `상의2_isSet` TINYINT NULL AFTER `상의2_isInner`,
# ADD COLUMN `상의2_name` VARCHAR(16) NULL AFTER `상의2_isSet`,
# ADD COLUMN `상의2_avatarType` VARCHAR(12) NULL AFTER `상의2_name`,
# ADD COLUMN `상의2_avatarType2` VARCHAR(16) NULL AFTER `상의2_avatarType`,
# ADD COLUMN `상의2_abvailableClass` VARCHAR(12) NULL AFTER `상의2_avatarType2`,
# ADD COLUMN `상의2_availableTrade` TINYINT NULL AFTER `상의2_abvailableClass`,
# ADD COLUMN `상의2_attribution` TINYINT NULL AFTER `상의2_availableTrade`,
# ADD COLUMN `상의2_statEffect(%)` DECIMAL(2,1) NULL AFTER `상의2_attribution`,
# ADD COLUMN `상의2_매력` TINYINT NULL AFTER `상의2_statEffect(%)`,
# ADD COLUMN `상의2_지성` TINYINT NULL AFTER `상의2_매력`,
# ADD COLUMN `상의2_담력` TINYINT NULL AFTER `상의2_지성`,
# ADD COLUMN `상의2_친절` TINYINT NULL AFTER `상의2_담력`,
# ADD COLUMN `상의2_availableSale` TINYINT NULL AFTER `상의2_친절`,
# ADD COLUMN `상의2_dyeable` TINYINT NULL AFTER `상의2_availableSale`,
# ADD COLUMN `상의2_decomposable` TINYINT NULL AFTER `상의2_dyeable`,
# ADD COLUMN `하의1_grade` VARCHAR(4) NULL AFTER `상의2_decomposable`,
# ADD COLUMN `하의1_isInner` TINYINT NULL AFTER `하의1_grade`,
# ADD COLUMN `하의1_isSet` TINYINT NULL AFTER `하의1_isInner`,
# ADD COLUMN `하의1_name` VARCHAR(16) NULL AFTER `하의1_isSet`,
# ADD COLUMN `하의1_avatarType` VARCHAR(12) NULL AFTER `하의1_name`,
# ADD COLUMN `하의1_avatarType2` VARCHAR(16) NULL AFTER `하의1_avatarType`,
# ADD COLUMN `하의1_abvailableClass` VARCHAR(12) NULL AFTER `하의1_avatarType2`,
# ADD COLUMN `하의1_availableTrade` TINYINT NULL AFTER `하의1_abvailableClass`,
# ADD COLUMN `하의1_attribution` TINYINT NULL AFTER `하의1_availableTrade`,
# ADD COLUMN `하의1_statEffect(%)` DECIMAL(2,1) NULL AFTER `하의1_attribution`,
# ADD COLUMN `하의1_매력` TINYINT NULL AFTER `하의1_statEffect(%)`,
# ADD COLUMN `하의1_지성` TINYINT NULL AFTER `하의1_매력`,
# ADD COLUMN `하의1_담력` TINYINT NULL AFTER `하의1_지성`,
# ADD COLUMN `하의1_친절` TINYINT NULL AFTER `하의1_담력`,
# ADD COLUMN `하의1_availableSale` TINYINT NULL AFTER `하의1_친절`,
# ADD COLUMN `하의1_dyeable` TINYINT NULL AFTER `하의1_availableSale`,
# ADD COLUMN `하의1_decomposable` TINYINT NULL AFTER `하의1_dyeable`,
# ADD COLUMN `하의2_grade` VARCHAR(4) NULL AFTER `하의1_decomposable`,
# ADD COLUMN `하의2_isInner` TINYINT NULL AFTER `하의2_grade`,
# ADD COLUMN `하의2_isSet` TINYINT NULL AFTER `하의2_isInner`,
# ADD COLUMN `하의2_name` VARCHAR(16) NULL AFTER `하의2_isSet`,
# ADD COLUMN `하의2_avatarType` VARCHAR(12) NULL AFTER `하의2_name`,
# ADD COLUMN `하의2_avatarType2` VARCHAR(16) NULL AFTER `하의2_avatarType`,
# ADD COLUMN `하의2_abvailableClass` VARCHAR(12) NULL AFTER `하의2_avatarType2`,
# ADD COLUMN `하의2_availableTrade` TINYINT NULL AFTER `하의2_abvailableClass`,
# ADD COLUMN `하의2_attribution` TINYINT NULL AFTER `하의2_availableTrade`,
# ADD COLUMN `하의2_statEffect(%)` DECIMAL(2,1) NULL AFTER `하의2_attribution`,
# ADD COLUMN `하의2_매력` TINYINT NULL AFTER `하의2_statEffect(%)`,
# ADD COLUMN `하의2_지성` TINYINT NULL AFTER `하의2_매력`,
# ADD COLUMN `하의2_담력` TINYINT NULL AFTER `하의2_지성`,
# ADD COLUMN `하의2_친절` TINYINT NULL AFTER `하의2_담력`,
# ADD COLUMN `하의2_availableSale` TINYINT NULL AFTER `하의2_친절`,
# ADD COLUMN `하의2_dyeable` TINYINT NULL AFTER `하의2_availableSale`,
# ADD COLUMN `하의2_decomposable` TINYINT NULL AFTER `하의2_dyeable`,
# ADD COLUMN `얼굴1_grade` VARCHAR(4) NULL AFTER `하의2_decomposable`,
# ADD COLUMN `얼굴1_isInner` TINYINT NULL AFTER `얼굴1_grade`,
# ADD COLUMN `얼굴1_isSet` TINYINT NULL AFTER `얼굴1_isInner`,
# ADD COLUMN `얼굴1_name` VARCHAR(16) NULL AFTER `얼굴1_isSet`,
# ADD COLUMN `얼굴1_avatarType` VARCHAR(12) NULL AFTER `얼굴1_name`,
# ADD COLUMN `얼굴1_avatarType2` VARCHAR(16) NULL AFTER `얼굴1_avatarType`,
# ADD COLUMN `얼굴1_abvailableClass` VARCHAR(12) NULL AFTER `얼굴1_avatarType2`,
# ADD COLUMN `얼굴1_availableTrade` TINYINT NULL AFTER `얼굴1_abvailableClass`,
# ADD COLUMN `얼굴1_attribution` TINYINT NULL AFTER `얼굴1_availableTrade`,
# ADD COLUMN `얼굴1_statEffect(%)` DECIMAL(2,1) NULL AFTER `얼굴1_attribution`,
# ADD COLUMN `얼굴1_매력` TINYINT NULL AFTER `얼굴1_statEffect(%)`,
# ADD COLUMN `얼굴1_지성` TINYINT NULL AFTER `얼굴1_매력`,
# ADD COLUMN `얼굴1_담력` TINYINT NULL AFTER `얼굴1_지성`,
# ADD COLUMN `얼굴1_친절` TINYINT NULL AFTER `얼굴1_담력`,
# ADD COLUMN `얼굴1_availableSale` TINYINT NULL AFTER `얼굴1_친절`,
# ADD COLUMN `얼굴1_dyeable` TINYINT NULL AFTER `얼굴1_availableSale`,
# ADD COLUMN `얼굴1_decomposable` TINYINT NULL AFTER `얼굴1_dyeable`,
# ADD COLUMN `얼굴2_grade` VARCHAR(4) NULL AFTER `얼굴1_decomposable`,
# ADD COLUMN `얼굴2_isInner` TINYINT NULL AFTER `얼굴2_grade`,
# ADD COLUMN `얼굴2_isSet` TINYINT NULL AFTER `얼굴2_isInner`,
# ADD COLUMN `얼굴2_name` VARCHAR(16) NULL AFTER `얼굴2_isSet`,
# ADD COLUMN `얼굴2_avatarType` VARCHAR(12) NULL AFTER `얼굴2_name`,
# ADD COLUMN `얼굴2_avatarType2` VARCHAR(16) NULL AFTER `얼굴2_avatarType`,
# ADD COLUMN `얼굴2_abvailableClass` VARCHAR(12) NULL AFTER `얼굴2_avatarType2`,
# ADD COLUMN `얼굴2_availableTrade` TINYINT NULL AFTER `얼굴2_abvailableClass`,
# ADD COLUMN `얼굴2_attribution` TINYINT NULL AFTER `얼굴2_availableTrade`,
# ADD COLUMN `얼굴2_statEffect(%)` DECIMAL(2,1) NULL AFTER `얼굴2_attribution`,
# ADD COLUMN `얼굴2_매력` TINYINT NULL AFTER `얼굴2_statEffect(%)`,
# ADD COLUMN `얼굴2_지성` TINYINT NULL AFTER `얼굴2_매력`,
# ADD COLUMN `얼굴2_담력` TINYINT NULL AFTER `얼굴2_지성`,
# ADD COLUMN `얼굴2_친절` TINYINT NULL AFTER `얼굴2_담력`,
# ADD COLUMN `얼굴2_availableSale` TINYINT NULL AFTER `얼굴2_친절`,
# ADD COLUMN `얼굴2_dyeable` TINYINT NULL AFTER `얼굴2_availableSale`,
# ADD COLUMN `얼굴2_decomposable` TINYINT NULL AFTER `얼굴2_dyeable`,
# ADD COLUMN `악기_grade` VARCHAR(4) NULL AFTER `얼굴2_decomposable`,
# ADD COLUMN `악기_isInner` TINYINT NULL AFTER `악기_grade`,
# ADD COLUMN `악기_isSet` TINYINT NULL AFTER `악기_isInner`,
# ADD COLUMN `악기_name` VARCHAR(16) NULL AFTER `악기_isSet`,
# ADD COLUMN `악기_avatarType` VARCHAR(12) NULL AFTER `악기_name`,
# ADD COLUMN `악기_avatarType2` VARCHAR(16) NULL AFTER `악기_avatarType`,
# ADD COLUMN `악기_abvailableClass` VARCHAR(12) NULL AFTER `악기_avatarType2`,
# ADD COLUMN `악기_availableTrade` TINYINT NULL AFTER `악기_abvailableClass`,
# ADD COLUMN `악기_attribution` TINYINT NULL AFTER `악기_availableTrade`,
# ADD COLUMN `악기_statEffect(%)` DECIMAL(2,1) NULL AFTER `악기_attribution`,
# ADD COLUMN `악기_매력` TINYINT NULL AFTER `악기_statEffect(%)`,
# ADD COLUMN `악기_지성` TINYINT NULL AFTER `악기_매력`,
# ADD COLUMN `악기_담력` TINYINT NULL AFTER `악기_지성`,
# ADD COLUMN `악기_친절` TINYINT NULL AFTER `악기_담력`,
# ADD COLUMN `악기_availableSale` TINYINT NULL AFTER `악기_친절`,
# ADD COLUMN `악기_dyeable` TINYINT NULL AFTER `악기_availableSale`,
# ADD COLUMN `악기_decomposable` TINYINT NULL AFTER `악기_dyeable`,
# ADD COLUMN `이동효과_grade` VARCHAR(4) NULL AFTER `악기_decomposable`,
# ADD COLUMN `이동효과_isInner` TINYINT NULL AFTER `이동효과_grade`,
# ADD COLUMN `이동효과_isSet` TINYINT NULL AFTER `이동효과_isInner`,
# ADD COLUMN `이동효과_name` VARCHAR(16) NULL AFTER `이동효과_isSet`,
# ADD COLUMN `이동효과_avatarType` VARCHAR(12) NULL AFTER `이동효과_name`,
# ADD COLUMN `이동효과_avatarType2` VARCHAR(16) NULL AFTER `이동효과_avatarType`,
# ADD COLUMN `이동효과_abvailableClass` VARCHAR(12) NULL AFTER `이동효과_avatarType2`,
# ADD COLUMN `이동효과_availableTrade` TINYINT NULL AFTER `이동효과_abvailableClass`,
# ADD COLUMN `이동효과_attribution` TINYINT NULL AFTER `이동효과_availableTrade`,
# ADD COLUMN `이동효과_statEffect(%)` DECIMAL(2,1) NULL AFTER `이동효과_attribution`,
# ADD COLUMN `이동효과_매력` TINYINT NULL AFTER `이동효과_statEffect(%)`,
# ADD COLUMN `이동효과_지성` TINYINT NULL AFTER `이동효과_매력`,
# ADD COLUMN `이동효과_담력` TINYINT NULL AFTER `이동효과_지성`,
# ADD COLUMN `이동효과_친절` TINYINT NULL AFTER `이동효과_담력`,
# ADD COLUMN `이동효과_availableSale` TINYINT NULL AFTER `이동효과_친절`,
# ADD COLUMN `이동효과_dyeable` TINYINT NULL AFTER `이동효과_availableSale`,
# ADD COLUMN `이동효과_decomposable` TINYINT NULL AFTER `이동효과_dyeable`;

# %%
# isInner가 True이다 == 2개 이상의 아바타를 끼고 있다? => 덧입기 중에는 효과가 발동되지 않음
for i in range(10000):
    avatar = avatars.copy()
    avatar['characterCode'] = df['characterCode'][i]
    cdf = eval(df['data'][i])
    if cdf == None: continue
        
    weapon_num = 0
    top_num = 0
    bottom_num = 0

    try:
        for j in range(len(cdf)):
            fd = flatten_dict(cdf[j])
            avatar_type = fd['Type']
            if avatar_type == '무기 아바타':
                weapon_num += 1
                avatar = set_avatar(avatar, fd, f'무기{weapon_num}')
            elif avatar_type == '상의 아바타':
                top_num += 1
                avatar = set_avatar(avatar, fd, f'상의{top_num}')
            elif avatar_type == '하의 아바타':
                bottom_num += 1
                avatar = set_avatar(avatar, fd, f'하의{bottom_num}')
            elif avatar_type =='머리 아바타':
                avatar = set_avatar(avatar, fd, '머리')
            elif avatar_type =='얼굴1 아바타':
                avatar = set_avatar(avatar, fd, '얼굴1')
            elif avatar_type =='얼굴2 아바타':
                avatar = set_avatar(avatar, fd, '얼굴2')
            elif avatar_type =='악기 아바타':
                avatar = set_avatar(avatar, fd, '악기')
            elif avatar_type == '':
                avatar = set_avatar(avatar, fd, '이동효과') 
    except Exception as e:
        print_exception(fd, sk, sv, e)
        break
        
### Insert DB ###
    # avatar table
    try:  
        sql = f"""
            INSERT INTO lostark.avatar_table (
                {''.join(f'{key}, ' for key in avatars.keys())[:-2]})
            VALUES ({''.join('%s, ' for _ in range(len(avatars.keys())))[:-2]});
            """
        values = [avatar['characterCode'], avatar['무기1_grade'], avatar['무기1_isInner'], avatar['무기1_isSet'], avatar['무기1_name'], avatar['무기1_avatarType'], avatar['무기1_avatarType2'], avatar['무기1_availableClass'], avatar['무기1_availableTrade'], avatar['무기1_attribution'], avatar['무기1_statEffect(%)'], avatar['무기1_매력'], avatar['무기1_지성'], avatar['무기1_담력'], avatar['무기1_친절'], avatar['무기1_availableSale'], avatar['무기1_dyeable'], avatar['무기1_decomposable'], avatar['무기2_grade'], avatar['무기2_isInner'], avatar['무기2_isSet'], avatar['무기2_name'], avatar['무기2_avatarType'], avatar['무기2_avatarType2'], avatar['무기2_availableClass'], avatar['무기2_availableTrade'], avatar['무기2_attribution'], avatar['무기2_statEffect(%)'], avatar['무기2_매력'], avatar['무기2_지성'], avatar['무기2_담력'], avatar['무기2_친절'], avatar['무기2_availableSale'], avatar['무기2_dyeable'], avatar['무기2_decomposable'], avatar['머리_grade'], avatar['머리_isInner'], avatar['머리_isSet'], avatar['머리_name'], avatar['머리_avatarType'], avatar['머리_avatarType2'], avatar['머리_availableClass'], avatar['머리_availableTrade'], avatar['머리_attribution'], avatar['머리_statEffect(%)'], avatar['머리_매력'], avatar['머리_지성'], avatar['머리_담력'], avatar['머리_친절'], avatar['머리_availableSale'], avatar['머리_dyeable'], avatar['머리_decomposable'], avatar['상의1_grade'], avatar['상의1_isInner'], avatar['상의1_isSet'], avatar['상의1_name'], avatar['상의1_avatarType'], avatar['상의1_avatarType2'], avatar['상의1_availableClass'], avatar['상의1_availableTrade'], avatar['상의1_attribution'], avatar['상의1_statEffect(%)'], avatar['상의1_매력'], avatar['상의1_지성'], avatar['상의1_담력'], avatar['상의1_친절'], avatar['상의1_availableSale'], avatar['상의1_dyeable'], avatar['상의1_decomposable'], avatar['상의2_grade'], avatar['상의2_isInner'], avatar['상의2_isSet'], avatar['상의2_name'], avatar['상의2_avatarType'], avatar['상의2_avatarType2'], avatar['상의2_availableClass'], avatar['상의2_availableTrade'], avatar['상의2_attribution'], avatar['상의2_statEffect(%)'], avatar['상의2_매력'], avatar['상의2_지성'], avatar['상의2_담력'], avatar['상의2_친절'], avatar['상의2_availableSale'], avatar['상의2_dyeable'], avatar['상의2_decomposable'], avatar['하의1_grade'], avatar['하의1_isInner'], avatar['하의1_isSet'], avatar['하의1_name'], avatar['하의1_avatarType'], avatar['하의1_avatarType2'], avatar['하의1_availableClass'], avatar['하의1_availableTrade'], avatar['하의1_attribution'], avatar['하의1_statEffect(%)'], avatar['하의1_매력'], avatar['하의1_지성'], avatar['하의1_담력'], avatar['하의1_친절'], avatar['하의1_availableSale'], avatar['하의1_dyeable'], avatar['하의1_decomposable'], avatar['하의2_grade'], avatar['하의2_isInner'], avatar['하의2_isSet'], avatar['하의2_name'], avatar['하의2_avatarType'], avatar['하의2_avatarType2'], avatar['하의2_availableClass'], avatar['하의2_availableTrade'], avatar['하의2_attribution'], avatar['하의2_statEffect(%)'], avatar['하의2_매력'], avatar['하의2_지성'], avatar['하의2_담력'], avatar['하의2_친절'], avatar['하의2_availableSale'], avatar['하의2_dyeable'], avatar['하의2_decomposable'], avatar['얼굴1_grade'], avatar['얼굴1_isInner'], avatar['얼굴1_isSet'], avatar['얼굴1_name'], avatar['얼굴1_avatarType'], avatar['얼굴1_avatarType2'], avatar['얼굴1_availableClass'], avatar['얼굴1_availableTrade'], avatar['얼굴1_attribution'], avatar['얼굴1_statEffect(%)'], avatar['얼굴1_매력'], avatar['얼굴1_지성'], avatar['얼굴1_담력'], avatar['얼굴1_친절'], avatar['얼굴1_availableSale'], avatar['얼굴1_dyeable'], avatar['얼굴1_decomposable'], avatar['얼굴2_grade'], avatar['얼굴2_isInner'], avatar['얼굴2_isSet'], avatar['얼굴2_name'], avatar['얼굴2_avatarType'], avatar['얼굴2_avatarType2'], avatar['얼굴2_availableClass'], avatar['얼굴2_availableTrade'], avatar['얼굴2_attribution'], avatar['얼굴2_statEffect(%)'], avatar['얼굴2_매력'], avatar['얼굴2_지성'], avatar['얼굴2_담력'], avatar['얼굴2_친절'], avatar['얼굴2_availableSale'], avatar['얼굴2_dyeable'], avatar['얼굴2_decomposable'], avatar['악기_grade'], avatar['악기_isInner'], avatar['악기_isSet'], avatar['악기_name'], avatar['악기_avatarType'], avatar['악기_avatarType2'], avatar['악기_availableClass'], avatar['악기_availableTrade'], avatar['악기_attribution'], avatar['악기_statEffect(%)'], avatar['악기_매력'], avatar['악기_지성'], avatar['악기_담력'], avatar['악기_친절'], avatar['악기_availableSale'], avatar['악기_dyeable'], avatar['악기_decomposable'], avatar['이동효과_grade'], avatar['이동효과_isInner'], avatar['이동효과_isSet'], avatar['이동효과_name'], avatar['이동효과_avatarType'], avatar['이동효과_avatarType2'], avatar['이동효과_availableClass'], avatar['이동효과_availableTrade'], avatar['이동효과_attribution'], avatar['이동효과_statEffect(%)'], avatar['이동효과_매력'], avatar['이동효과_지성'], avatar['이동효과_담력'], avatar['이동효과_친절'], avatar['이동효과_availableSale'], avatar['이동효과_dyeable'], avatar['이동효과_decomposable']]       
        cursor.execute(sql, values)
        db.commit()
    except Exception as e:
        # Rollback if there is any error
        db.rollback()
        print_exception_db(avatar, e)
        break
# Out:
# {'characterCode': 0,
#  '머리_attribution': True,
#  '머리_availableClass': '헌터(남)계열',
#  '머리_availableSale': False,
#  '머리_availableTrade': 0,
#  '머리_avatarType': '머리 아바타',
#  '머리_avatarType2': '영웅 머리 아바타',
#  '머리_decomposable': False,
#  '머리_dyeable': False,
#  '머리_grade': '영웅',
#  '머리_isInner': False,
#  '머리_isSet': False,
#  '머리_name': '경계의 관찰자 머리',
#  '머리_statEffect': 1.0,
#  '머리_담력': 5,
#  '머리_매력': 5,
#  '머리_지성': 5,
#  '머리_친절': None,
#  '무기1_attribution': True,
#  '무기1_availableClass': '스카우터 전용',
#  '무기1_availableSale': False,
#  '무기1_availableTrade': 0,
#  '무기1_avatarType': '무기 아바타',
#  '무기1_avatarType2': '영웅 서브 머신건 아바타',
#  '무기1_decomposable': False,
#  '무기1_dyeable': False,
#  '무기1_grade': '영웅',
#  '무기1_isInner': False,
#  '무기1_isSet': False,
#  '무기1_name': '하이엔드 서브 머신건',
#  '무기1_statEffect': 1.0,
#  '무기1_담력': 5,
#  '무기1_매력': None,
#  '무기1_지성': 10,
#  '무기1_친절': None,
#  '무기2_attribution': None,
#  '무기2_availableClass': None,
#  '무기2_availableSale': None,
# ...

# %% [markdown]
# # Armory Equipement

# %%
df = pd.read_csv(f'./data/ArmoryEquipment1.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
for i in range(2, 11):
    df2 = pd.read_csv(f'./data/ArmoryEquipment{i}.csv', usecols=[1, 2])
    df2 = df2.rename(columns={'0':'characterCode', '1':'data'})
    df = pd.concat([df, df2], axis=0)

# %%
df = df.reset_index(drop=True)

# %%
equipment_parts = ['무기', '투구', '상의', '하의', '어깨', '장갑']
accessory_parts = ['목걸이', '귀걸이1', '귀걸이2', '반지1', '반지2'] # + 팔찌, 어빌리티 스톤
sequipment_parts = ['나침반','부적','문장']
# 무기 장비
aedic_keys = ['grade', 'name', 'type', 'quality', 'tier', 'itemLevel', 'ATK', 'AD(%)', 
              'setName', 'setLevel', 'REXP', 'esther', 'estherEffect','ella', 'reinforcementStep']
# 방어구 장비
dedic_keys = ['grade', 'name', 'type', 'quality', 'tier', 'itemLevel', 
              'SAI', 'BDEF', 'BMDEF', 'BHP', 'ADEF', 'AMDEF', 'AHP', 'AHPP',
              'setName', 'setLevel', 'REXP', 'reinforcementStep',
             'alchemyName1', 'alchemyName2', 'alchemyPoint1', 'alchemyPoint2']
# 악세서리 장비
adic_keys = ['grade', 'name', 'quality', 'tier', 'limitLevel', 'availableTrade', 
             'SAI', 'HP', '치명', '특화', '신속', '제압', '인내', '숙련',
             'engraving1_name', 'engraving1_point', 'engraving2_name', 'engraving2_point', 
             'dengraving_name', 'dengraving_point', 'acquirablePlace']

# 특수장비
sedic_keys = ['grade', 'name']

# 장비
equipments = {
    'characterCode': None,
}
# 악세서리
accessories = {
    'characterCode': None,
    '팔찌_grade':None, '팔찌_name':None, '팔찌_tier':None, '팔찌_effect1':None, '팔찌_effect2':None,
    '팔찌_effect3':None, '팔찌_effect4':None, '팔찌_effect5':None, '팔찌_canRerollNum':None, '팔찌_canGivenNum':None,
    'AS_grade':None, 'AS_name':None, 'AS_tier':None, 'AS_HP': None, 'AS_BHP':None, 'AS_engraving1_name':None, 
    'AS_engraving1_point':None, 'AS_engraving2_name':None, 'AS_engraving2_point':None,
    'AS_dengraving_name':None, 'AS_dengraving_point':None, 'AS_setLevel' :None
}
# 특수 장비
sequipments = {
    'characterCode':None, 
}
for part in equipment_parts:
    if part == '무기':
        for key in aedic_keys:
            equipments[f'{part}_{key}'] = None
    else:
        for key in dedic_keys:
            equipments[f'{part}_{key}'] = None
for part in accessory_parts:
    for key in adic_keys:
        accessories[f'{part}_{key}'] = None
for part in sequipment_parts:
    for key in sedic_keys:
        sequipments[f'{part}_{key}'] = None

# %%
print(''.join(f'{return_value(k, "sequipment")}, ' for k in sequipments.keys()))
# Out:
# sequipment['characterCode'], sequipment['나침반_grade'], sequipment['나침반_name'], sequipment['부적_grade'], sequipment['부적_name'], sequipment['문장_grade'], sequipment['문장_name'],

# %%
# CREATE TABLE `lostark`.`equipment_table` (
#   `characterCode` MEDIUMINT NOT NULL,
#   PRIMARY KEY (`characterCode`),
#   UNIQUE INDEX `characterCode_UNIQUE` (`characterCode` ASC) VISIBLE,
#   CONSTRAINT `equipment_characterCode`
#     FOREIGN KEY (`characterCode`)
#     REFERENCES `lostark`.`profile_table` (`characterCode`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION);

# %%
# ALTER TABLE `lostark`.`equipment_table` 
# ADD COLUMN `무기_grade` VARCHAR(4) NULL AFTER `characterCode`,
# ADD COLUMN `무기_name` VARCHAR(16) NULL AFTER `무기_grade`,
# ADD COLUMN `무기_type` VARCHAR(12) NULL AFTER `무기_name`,
# ADD COLUMN `무기_quality` TINYINT(3) NULL AFTER `무기_type`,
# ADD COLUMN `무기_tier` TINYINT(1) NULL AFTER `무기_quality`,
# ADD COLUMN `무기_itemLevel` SMALLINT(4) NULL AFTER `무기_tier`,
# ADD COLUMN `무기_ATK` MEDIUMINT(6) NULL AFTER `무기_itemLevel`,
# ADD COLUMN `무기_AD(%)` DECIMAL(4,2) NULL AFTER `무기_ATK`,
# ADD COLUMN `무기_setName` VARCHAR(12) NULL AFTER `무기_AD(%)`,
# ADD COLUMN `무기_setLevel` TINYINT(1) NULL AFTER `무기_setName`,
# ADD COLUMN `무기_REXP` MEDIUMINT NULL AFTER `무기_setLevel`,
# ADD COLUMN `무기_esther` TINYINT(1) NULL AFTER `무기_REXP`,
# ADD COLUMN `무기_estherEffect` VARCHAR(8) NULL AFTER `무기_esther`,
# ADD COLUMN `무기_ella` TINYINT(1) NULL AFTER `무기_estherEffect`,
# ADD COLUMN `무기_reinforcementStep` TINYINT(2) NULL AFTER `무기_ella`,
# ADD COLUMN `투구_grade` VARCHAR(4) NULL AFTER `무기_reinforcementStep`,
# ADD COLUMN `투구_name` VARCHAR(16) NULL AFTER `투구_grade`,
# ADD COLUMN `투구_type` VARCHAR(12) NULL AFTER `투구_name`,
# ADD COLUMN `투구_quality` TINYINT NULL AFTER `투구_type`,
# ADD COLUMN `투구_tier` TINYINT(1) NULL AFTER `투구_quality`,
# ADD COLUMN `투구_itemLevel` SMALLINT(4) NULL AFTER `투구_tier`,
# ADD COLUMN `투구_SAI` MEDIUMINT(6) NULL AFTER `투구_itemLevel`,
# ADD COLUMN `투구_BDEF` SMALLINT NULL AFTER `투구_SAI`,
# ADD COLUMN `투구_BMDEF` SMALLINT NULL AFTER `투구_BDEF`,
# ADD COLUMN `투구_BHP` SMALLINT NULL AFTER `투구_BMDEF`,
# ADD COLUMN `투구_ADEF` SMALLINT(4) NULL AFTER `투구_BHP`,
# ADD COLUMN `투구_AMDEF` SMALLINT(4) NULL AFTER `투구_ADEF`,
# ADD COLUMN `투구_AHP` SMALLINT(4) NULL AFTER `투구_AMDEF`,
# ADD COLUMN `투구_AHPP` SMALLINT(4) NULL AFTER `투구_AHP`,
# ADD COLUMN `투구_setName` VARCHAR(12) NULL AFTER `투구_AHPP`,
# ADD COLUMN `투구_setLevel` TINYINT(1) NULL AFTER `투구_setName`,
# ADD COLUMN `투구_REXP` MEDIUMINT NULL AFTER `투구_setLevel`,
# ADD COLUMN `투구_reinforcementStep` TINYINT(2) NULL AFTER `투구_REXP`,
# ADD COLUMN `투구_alchemyName1` VARCHAR(12) NULL AFTER `투구_reinforcementStep`,
# ADD COLUMN `투구_alchemyPoint1` TINYINT(1) NULL AFTER `투구_alchemyName1`,
# ADD COLUMN `투구_alchemyName2` VARCHAR(12) NULL AFTER `투구_alchemyPoint1`,
# ADD COLUMN `어깨_grade` VARCHAR(4) NULL AFTER `투구_alchemyName2`,
# ADD COLUMN `어깨_name` VARCHAR(16) NULL AFTER `어깨_grade`,
# ADD COLUMN `어깨_type` VARCHAR(12) NULL AFTER `어깨_name`,
# ADD COLUMN `어깨_quality` TINYINT NULL AFTER `어깨_type`,
# ADD COLUMN `어깨_tier` TINYINT(1) NULL AFTER `어깨_quality`,
# ADD COLUMN `어깨_itemLevel` SMALLINT(4) NULL AFTER `어깨_tier`,
# ADD COLUMN `어깨_SAI` MEDIUMINT(6) NULL AFTER `어깨_itemLevel`,
# ADD COLUMN `어깨_BDEF` SMALLINT NULL AFTER `어깨_SAI`,
# ADD COLUMN `어깨_BMDEF` SMALLINT NULL AFTER `어깨_BDEF`,
# ADD COLUMN `어깨_BHP` SMALLINT NULL AFTER `어깨_BMDEF`,
# ADD COLUMN `어깨_ADEF` SMALLINT(4) NULL AFTER `어깨_BHP`,
# ADD COLUMN `어깨_AMDEF` SMALLINT(4) NULL AFTER `어깨_ADEF`,
# ADD COLUMN `어깨_AHP` SMALLINT(4) NULL AFTER `어깨_AMDEF`,
# ADD COLUMN `어깨_AHPP` SMALLINT(4) NULL AFTER `어깨_AHP`,
# ADD COLUMN `어깨_setName` VARCHAR(12) NULL AFTER `어깨_AHPP`,
# ADD COLUMN `어깨_setLevel` TINYINT(1) NULL AFTER `어깨_setName`,
# ADD COLUMN `어깨_REXP` MEDIUMINT NULL AFTER `어깨_setLevel`,
# ADD COLUMN `어깨_reinforcementStep` TINYINT(2) NULL AFTER `어깨_REXP`,
# ADD COLUMN `어깨_alchemyName1` VARCHAR(12) NULL AFTER `어깨_reinforcementStep`,
# ADD COLUMN `어깨_alchemyPoint1` TINYINT(1) NULL AFTER `어깨_alchemyName1`,
# ADD COLUMN `어깨_alchemyName2` VARCHAR(12) NULL AFTER `어깨_alchemyPoint1`,
# ADD COLUMN `상의_grade` VARCHAR(4) NULL AFTER `어깨_alchemyName2`,
# ADD COLUMN `상의_name` VARCHAR(16) NULL AFTER `상의_grade`,
# ADD COLUMN `상의_type` VARCHAR(12) NULL AFTER `상의_name`,
# ADD COLUMN `상의_quality` TINYINT NULL AFTER `상의_type`,
# ADD COLUMN `상의_tier` TINYINT(1) NULL AFTER `상의_quality`,
# ADD COLUMN `상의_itemLevel` SMALLINT(4) NULL AFTER `상의_tier`,
# ADD COLUMN `상의_SAI` MEDIUMINT(6) NULL AFTER `상의_itemLevel`,
# ADD COLUMN `상의_BDEF` SMALLINT NULL AFTER `상의_SAI`,
# ADD COLUMN `상의_BMDEF` SMALLINT NULL AFTER `상의_BDEF`,
# ADD COLUMN `상의_BHP` SMALLINT NULL AFTER `상의_BMDEF`,
# ADD COLUMN `상의_ADEF` SMALLINT(4) NULL AFTER `상의_BHP`,
# ADD COLUMN `상의_AMDEF` SMALLINT(4) NULL AFTER `상의_ADEF`,
# ADD COLUMN `상의_AHP` SMALLINT(4) NULL AFTER `상의_AMDEF`,
# ADD COLUMN `상의_AHPP` SMALLINT(4) NULL AFTER `상의_AHP`,
# ADD COLUMN `상의_setName` VARCHAR(12) NULL AFTER `상의_AHPP`,
# ADD COLUMN `상의_setLevel` TINYINT(1) NULL AFTER `상의_setName`,
# ADD COLUMN `상의_REXP` MEDIUMINT NULL AFTER `상의_setLevel`,
# ADD COLUMN `상의_reinforcementStep` TINYINT(2) NULL AFTER `상의_REXP`,
# ADD COLUMN `상의_alchemyName1` VARCHAR(12) NULL AFTER `상의_reinforcementStep`,
# ADD COLUMN `상의_alchemyPoint1` TINYINT(1) NULL AFTER `상의_alchemyName1`,
# ADD COLUMN `상의_alchemyName2` VARCHAR(12) NULL AFTER `상의_alchemyPoint1`,
# ADD COLUMN `하의_grade` VARCHAR(4) NULL AFTER `상의_alchemyName2`,
# ADD COLUMN `하의_name` VARCHAR(16) NULL AFTER `하의_grade`,
# ADD COLUMN `하의_type` VARCHAR(12) NULL AFTER `하의_name`,
# ADD COLUMN `하의_quality` TINYINT NULL AFTER `하의_type`,
# ADD COLUMN `하의_tier` TINYINT(1) NULL AFTER `하의_quality`,
# ADD COLUMN `하의_itemLevel` SMALLINT(4) NULL AFTER `하의_tier`,
# ADD COLUMN `하의_SAI` MEDIUMINT(6) NULL AFTER `하의_itemLevel`,
# ADD COLUMN `하의_BDEF` SMALLINT NULL AFTER `하의_SAI`,
# ADD COLUMN `하의_BMDEF` SMALLINT NULL AFTER `하의_BDEF`,
# ADD COLUMN `하의_BHP` SMALLINT NULL AFTER `하의_BMDEF`,
# ADD COLUMN `하의_ADEF` SMALLINT(4) NULL AFTER `하의_BHP`,
# ADD COLUMN `하의_AMDEF` SMALLINT(4) NULL AFTER `하의_ADEF`,
# ADD COLUMN `하의_AHP` SMALLINT(4) NULL AFTER `하의_AMDEF`,
# ADD COLUMN `하의_AHPP` SMALLINT(4) NULL AFTER `하의_AHP`,
# ADD COLUMN `하의_setName` VARCHAR(12) NULL AFTER `하의_AHPP`,
# ADD COLUMN `하의_setLevel` TINYINT(1) NULL AFTER `하의_setName`,
# ADD COLUMN `하의_REXP` MEDIUMINT NULL AFTER `하의_setLevel`,
# ADD COLUMN `하의_reinforcementStep` TINYINT(2) NULL AFTER `하의_REXP`,
# ADD COLUMN `하의_alchemyName1` VARCHAR(12) NULL AFTER `하의_reinforcementStep`,
# ADD COLUMN `하의_alchemyPoint1` TINYINT(1) NULL AFTER `하의_alchemyName1`,
# ADD COLUMN `하의_alchemyName2` VARCHAR(12) NULL AFTER `하의_alchemyPoint1`,
# ADD COLUMN `장갑_grade` VARCHAR(4) NULL AFTER `하의_alchemyName2`,
# ADD COLUMN `장갑_name` VARCHAR(16) NULL AFTER `장갑_grade`,
# ADD COLUMN `장갑_type` VARCHAR(12) NULL AFTER `장갑_name`,
# ADD COLUMN `장갑_quality` TINYINT NULL AFTER `장갑_type`,
# ADD COLUMN `장갑_tier` TINYINT(1) NULL AFTER `장갑_quality`,
# ADD COLUMN `장갑_itemLevel` SMALLINT(4) NULL AFTER `장갑_tier`,
# ADD COLUMN `장갑_SAI` MEDIUMINT(6) NULL AFTER `장갑_itemLevel`,
# ADD COLUMN `장갑_BDEF` SMALLINT NULL AFTER `장갑_SAI`,
# ADD COLUMN `장갑_BMDEF` SMALLINT NULL AFTER `장갑_BDEF`,
# ADD COLUMN `장갑_BHP` SMALLINT NULL AFTER `장갑_BMDEF`,
# ADD COLUMN `장갑_ADEF` SMALLINT(4) NULL AFTER `장갑_BHP`,
# ADD COLUMN `장갑_AMDEF` SMALLINT(4) NULL AFTER `장갑_ADEF`,
# ADD COLUMN `장갑_AHP` SMALLINT(4) NULL AFTER `장갑_AMDEF`,
# ADD COLUMN `장갑_AHPP` SMALLINT(4) NULL AFTER `장갑_AHP`,
# ADD COLUMN `장갑_setName` VARCHAR(12) NULL AFTER `장갑_AHPP`,
# ADD COLUMN `장갑_setLevel` TINYINT(1) NULL AFTER `장갑_setName`,
# ADD COLUMN `장갑_REXP` MEDIUMINT NULL AFTER `장갑_setLevel`,
# ADD COLUMN `장갑_reinforcementStep` TINYINT(2) NULL AFTER `장갑_REXP`,
# ADD COLUMN `장갑_alchemyName1` VARCHAR(12) NULL AFTER `장갑_reinforcementStep`,
# ADD COLUMN `장갑_alchemyPoint1` TINYINT(1) NULL AFTER `장갑_alchemyName1`,
# ADD COLUMN `장갑_alchemyName2` VARCHAR(12) NULL AFTER `장갑_alchemyPoint1`;

# %%
# CREATE TABLE `lostark`.`accessory_table` (
#   `characterCode` MEDIUMINT NOT NULL,
#   PRIMARY KEY (`characterCode`),
#   UNIQUE INDEX `characterCode_UNIQUE` (`characterCode` ASC) VISIBLE,
#   CONSTRAINT `accessory_characterCode`
#     FOREIGN KEY (`characterCode`)
#     REFERENCES `lostark`.`profile_table` (`characterCode`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION);

# %%
# ALTER TABLE `lostark`.`accessory_table` 
# ADD COLUMN `목걸이_grade` VARCHAR(4) NULL AFTER `characterCode`,
# ADD COLUMN `목걸이_name` VARCHAR(16) NULL AFTER `목걸이_grade`,
# ADD COLUMN `목걸이_quality` TINYINT NULL AFTER `목걸이_name`,
# ADD COLUMN `목걸이_tier` TINYINT NULL AFTER `목걸이_quality`,
# ADD COLUMN `목걸이_limitLevel` SMALLINT NULL AFTER `목걸이_tier`,
# ADD COLUMN `목걸이_availableTrade` TINYINT NULL AFTER `목걸이_limitLevel`,
# ADD COLUMN `목걸이_SAI` SMALLINT NULL AFTER `목걸이_availableTrade`,
# ADD COLUMN `목걸이_HP` SMALLINT NULL AFTER `목걸이_SAI`,
# ADD COLUMN `목걸이_치명` SMALLINT NULL AFTER `목걸이_HP`,
# ADD COLUMN `목걸이_특화` SMALLINT NULL AFTER `목걸이_치명`,
# ADD COLUMN `목걸이_신속` SMALLINT NULL AFTER `목걸이_특화`,
# ADD COLUMN `목걸이_제압` SMALLINT NULL AFTER `목걸이_신속`,
# ADD COLUMN `목걸이_인내` SMALLINT NULL AFTER `목걸이_제압`,
# ADD COLUMN `목걸이_숙련` SMALLINT NULL AFTER `목걸이_인내`,
# ADD COLUMN `목걸이_engraving1_name` VARCHAR(8) NULL AFTER `목걸이_숙련`,
# ADD COLUMN `목걸이_engraving1_point` TINYINT NULL AFTER `목걸이_engraving1_name`,
# ADD COLUMN `목걸이_engraving2_name` VARCHAR(8) NULL AFTER `목걸이_engraving1_point`,
# ADD COLUMN `목걸이_engraving2_point` TINYINT NULL AFTER `목걸이_engraving2_name`,
# ADD COLUMN `목걸이_dengraving_name` VARCHAR(8) NULL AFTER `목걸이_engraving2_point`,
# ADD COLUMN `목걸이_dengraving_point` TINYINT NULL AFTER `목걸이_dengraving_name`,
# ADD COLUMN `귀걸이1_grade` VARCHAR(4) NULL AFTER `목걸이_dengraving_point`,
# ADD COLUMN `귀걸이1_name` VARCHAR(16) NULL AFTER `귀걸이1_grade`,
# ADD COLUMN `귀걸이1_quality` TINYINT NULL AFTER `귀걸이1_name`,
# ADD COLUMN `귀걸이1_tier` TINYINT NULL AFTER `귀걸이1_quality`,
# ADD COLUMN `귀걸이1_limitLevel` SMALLINT NULL AFTER `귀걸이1_tier`,
# ADD COLUMN `귀걸이1_availableTrade` TINYINT NULL AFTER `귀걸이1_limitLevel`,
# ADD COLUMN `귀걸이1_SAI` SMALLINT NULL AFTER `귀걸이1_availableTrade`,
# ADD COLUMN `귀걸이1_HP` SMALLINT NULL AFTER `귀걸이1_SAI`,
# ADD COLUMN `귀걸이1_치명` SMALLINT NULL AFTER `귀걸이1_HP`,
# ADD COLUMN `귀걸이1_특화` SMALLINT NULL AFTER `귀걸이1_치명`,
# ADD COLUMN `귀걸이1_신속` SMALLINT NULL AFTER `귀걸이1_특화`,
# ADD COLUMN `귀걸이1_제압` SMALLINT NULL AFTER `귀걸이1_신속`,
# ADD COLUMN `귀걸이1_인내` SMALLINT NULL AFTER `귀걸이1_제압`,
# ADD COLUMN `귀걸이1_숙련` SMALLINT NULL AFTER `귀걸이1_인내`,
# ADD COLUMN `귀걸이1_engraving1_name` VARCHAR(8) NULL AFTER `귀걸이1_숙련`,
# ADD COLUMN `귀걸이1_engraving1_point` TINYINT NULL AFTER `귀걸이1_engraving1_name`,
# ADD COLUMN `귀걸이1_engraving2_name` VARCHAR(8) NULL AFTER `귀걸이1_engraving1_point`,
# ADD COLUMN `귀걸이1_engraving2_point` TINYINT NULL AFTER `귀걸이1_engraving2_name`,
# ADD COLUMN `귀걸이1_dengraving_name` VARCHAR(8) NULL AFTER `귀걸이1_engraving2_point`,
# ADD COLUMN `귀걸이1_dengraving_point` TINYINT NULL AFTER `귀걸이1_dengraving_name`,
# ADD COLUMN `귀걸이2_grade` VARCHAR(4) NULL AFTER `귀걸이1_dengraving_point`,
# ADD COLUMN `귀걸이2_name` VARCHAR(16) NULL AFTER `귀걸이2_grade`,
# ADD COLUMN `귀걸이2_quality` TINYINT NULL AFTER `귀걸이2_name`,
# ADD COLUMN `귀걸이2_tier` TINYINT NULL AFTER `귀걸이2_quality`,
# ADD COLUMN `귀걸이2_limitLevel` SMALLINT NULL AFTER `귀걸이2_tier`,
# ADD COLUMN `귀걸이2_availableTrade` TINYINT NULL AFTER `귀걸이2_limitLevel`,
# ADD COLUMN `귀걸이2_SAI` SMALLINT NULL AFTER `귀걸이2_availableTrade`,
# ADD COLUMN `귀걸이2_HP` SMALLINT NULL AFTER `귀걸이2_SAI`,
# ADD COLUMN `귀걸이2_치명` SMALLINT NULL AFTER `귀걸이2_HP`,
# ADD COLUMN `귀걸이2_특화` SMALLINT NULL AFTER `귀걸이2_치명`,
# ADD COLUMN `귀걸이2_신속` SMALLINT NULL AFTER `귀걸이2_특화`,
# ADD COLUMN `귀걸이2_제압` SMALLINT NULL AFTER `귀걸이2_신속`,
# ADD COLUMN `귀걸이2_인내` SMALLINT NULL AFTER `귀걸이2_제압`,
# ADD COLUMN `귀걸이2_숙련` SMALLINT NULL AFTER `귀걸이2_인내`,
# ADD COLUMN `귀걸이2_engraving1_name` VARCHAR(8) NULL AFTER `귀걸이2_숙련`,
# ADD COLUMN `귀걸이2_engraving1_point` TINYINT NULL AFTER `귀걸이2_engraving1_name`,
# ADD COLUMN `귀걸이2_engraving2_name` VARCHAR(8) NULL AFTER `귀걸이2_engraving1_point`,
# ADD COLUMN `귀걸이2_engraving2_point` TINYINT NULL AFTER `귀걸이2_engraving2_name`,
# ADD COLUMN `귀걸이2_dengraving_name` VARCHAR(8) NULL AFTER `귀걸이2_engraving2_point`,
# ADD COLUMN `귀걸이2_dengraving_point` TINYINT NULL AFTER `귀걸이2_dengraving_name`,
# ADD COLUMN `반지1_grade` VARCHAR(4) NULL AFTER `귀걸이2_dengraving_point`,
# ADD COLUMN `반지1_name` VARCHAR(16) NULL AFTER `반지1_grade`,
# ADD COLUMN `반지1_quality` TINYINT NULL AFTER `반지1_name`,
# ADD COLUMN `반지1_tier` TINYINT NULL AFTER `반지1_quality`,
# ADD COLUMN `반지1_limitLevel` SMALLINT NULL AFTER `반지1_tier`,
# ADD COLUMN `반지1_availableTrade` TINYINT NULL AFTER `반지1_limitLevel`,
# ADD COLUMN `반지1_SAI` SMALLINT NULL AFTER `반지1_availableTrade`,
# ADD COLUMN `반지1_HP` SMALLINT NULL AFTER `반지1_SAI`,
# ADD COLUMN `반지1_치명` SMALLINT NULL AFTER `반지1_HP`,
# ADD COLUMN `반지1_특화` SMALLINT NULL AFTER `반지1_치명`,
# ADD COLUMN `반지1_신속` SMALLINT NULL AFTER `반지1_특화`,
# ADD COLUMN `반지1_제압` SMALLINT NULL AFTER `반지1_신속`,
# ADD COLUMN `반지1_인내` SMALLINT NULL AFTER `반지1_제압`,
# ADD COLUMN `반지1_숙련` SMALLINT NULL AFTER `반지1_인내`,
# ADD COLUMN `반지1_engraving1_name` VARCHAR(8) NULL AFTER `반지1_숙련`,
# ADD COLUMN `반지1_engraving1_point` TINYINT NULL AFTER `반지1_engraving1_name`,
# ADD COLUMN `반지1_engraving2_name` VARCHAR(8) NULL AFTER `반지1_engraving1_point`,
# ADD COLUMN `반지1_engraving2_point` TINYINT NULL AFTER `반지1_engraving2_name`,
# ADD COLUMN `반지1_dengraving_name` VARCHAR(8) NULL AFTER `반지1_engraving2_point`,
# ADD COLUMN `반지1_dengraving_point` TINYINT NULL AFTER `반지1_dengraving_name`,
# ADD COLUMN `반지2_grade` VARCHAR(4) NULL AFTER `반지1_dengraving_point`,
# ADD COLUMN `반지2_name` VARCHAR(16) NULL AFTER `반지2_grade`,
# ADD COLUMN `반지2_quality` TINYINT NULL AFTER `반지2_name`,
# ADD COLUMN `반지2_tier` TINYINT NULL AFTER `반지2_quality`,
# ADD COLUMN `반지2_limitLevel` SMALLINT NULL AFTER `반지2_tier`,
# ADD COLUMN `반지2_availableTrade` TINYINT NULL AFTER `반지2_limitLevel`,
# ADD COLUMN `반지2_SAI` SMALLINT NULL AFTER `반지2_availableTrade`,
# ADD COLUMN `반지2_HP` SMALLINT NULL AFTER `반지2_SAI`,
# ADD COLUMN `반지2_치명` SMALLINT NULL AFTER `반지2_HP`,
# ADD COLUMN `반지2_특화` SMALLINT NULL AFTER `반지2_치명`,
# ADD COLUMN `반지2_신속` SMALLINT NULL AFTER `반지2_특화`,
# ADD COLUMN `반지2_제압` SMALLINT NULL AFTER `반지2_신속`,
# ADD COLUMN `반지2_인내` SMALLINT NULL AFTER `반지2_제압`,
# ADD COLUMN `반지2_숙련` SMALLINT NULL AFTER `반지2_인내`,
# ADD COLUMN `반지2_engraving1_name` VARCHAR(8) NULL AFTER `반지2_숙련`,
# ADD COLUMN `반지2_engraving1_point` TINYINT NULL AFTER `반지2_engraving1_name`,
# ADD COLUMN `반지2_engraving2_name` VARCHAR(8) NULL AFTER `반지2_engraving1_point`,
# ADD COLUMN `반지2_engraving2_point` TINYINT NULL AFTER `반지2_engraving2_name`,
# ADD COLUMN `반지2_dengraving_name` VARCHAR(8) NULL AFTER `반지2_engraving2_point`,
# ADD COLUMN `반지2_dengraving_point` TINYINT NULL AFTER `반지2_dengraving_name`,
# ADD COLUMN `팔찌_grade` VARCHAR(4) NULL AFTER `반지2_dengraving_point`,
# ADD COLUMN `팔찌_name` VARCHAR(16) NULL AFTER `팔찌_grade`,
# ADD COLUMN `팔찌_tier` TINYINT NULL AFTER `팔찌_name`,
# ADD COLUMN `팔찌_effect1` VARCHAR(45) NULL AFTER `팔찌_tier`,
# ADD COLUMN `팔찌_effect2` VARCHAR(45) NULL AFTER `팔찌_effect1`,
# ADD COLUMN `팔찌_effect3` VARCHAR(45) NULL AFTER `팔찌_effect2`,
# ADD COLUMN `팔찌_effect4` VARCHAR(45) NULL AFTER `팔찌_effect3`,
# ADD COLUMN `팔찌_effect5` VARCHAR(45) NULL AFTER `팔찌_effect4`,
# ADD COLUMN `팔찌_canRerollNum` TINYINT NULL AFTER `팔찌_effect5`,
# ADD COLUMN `팔찌_canGivenNum` TINYINT NULL AFTER `팔찌_canRerollNum`,
# ADD COLUMN `AS_grade` VARCHAR(4) NULL AFTER `팔찌_canGivenNum`,
# ADD COLUMN `AS_name` VARCHAR(16) NULL AFTER `AS_grade`,
# ADD COLUMN `AS_tier` TINYINT NULL AFTER `AS_name`,
# ADD COLUMN `AS_HP` MEDIUMINT NULL AFTER `AS_tier`,
# ADD COLUMN `AS_BHP` SMALLINT NULL AFTER `AS_HP`,
# ADD COLUMN `AS_engraving1_name` VARCHAR(12) NULL AFTER `AS_BHP`,
# ADD COLUMN `AS_engraving1_point` TINYINT NULL AFTER `AS_engraving1_name`,
# ADD COLUMN `AS_engraving2_name` VARCHAR(12) NULL AFTER `AS_engraving1_point`,
# ADD COLUMN `AS_engraving2_point` TINYINT NULL AFTER `AS_engraving2_name`,
# ADD COLUMN `AS_dengraving_name` VARCHAR(12) NULL AFTER `AS_engraving2_point`,
# ADD COLUMN `AS_dengraving_point` TINYINT NULL AFTER `AS_dengraving_name`, COMMENT = '	' ;

# %%
# CREATE TABLE `lostark`.`special_equipment_table` (
#   `characterCode` MEDIUMINT NOT NULL,
#   PRIMARY KEY (`characterCode`),
#   UNIQUE INDEX `characterCode_UNIQUE` (`characterCode` ASC) VISIBLE,
#   CONSTRAINT `sequipment_characterCode`
#     FOREIGN KEY (`characterCode`)
#     REFERENCES `lostark`.`profile_table` (`characterCode`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION);

# %%
# 특수 장비는 걍 손으로 써라

# %%
for i in range(1, 100000):
    equipment = equipments.copy()
    accessory = accessories.copy()
    sequipment = sequipments.copy()
    equipment['characterCode'] = df['characterCode'][i]
    accessory['characterCode'] = df['characterCode'][i]
    sequipment['characterCode'] = df['characterCode'][i]
    
    cdf = eval(df['data'][i])
    if cdf == None: continue
        
    earring_count = 0
    ring_count = 0
    
    try:
        for j in range(len(cdf)):
            fd = flatten_dict(cdf[j])
            if '무기' == fd['Type']:
                equipment['무기_grade'] = fd['Grade']
                equipment['무기_name'] = fd['Name'].split(' ', 1)[1]
                if '+' in fd['Name']:
                    equipment['무기_reinforcementStep'] = fd['Name'].split(' ', 1)[0].replace('+', '')
                else:
                    equipment['무기_reinforcementStep'] = 0
                for k, v in fd.items():
                    sv = str(v)
                    sk = str(k)
                    if ('아이템 레벨' in sv) & ('티어' in sv):
                        equipment['무기_itemLevel'] = int(int_pattern.findall(sv.split(' (')[0])[0])
                        equipment['무기_tier'] = int(int_pattern.findall(sv.split(' (')[1])[0])
                    elif ('무기 공격력 +' in sv) & ('이동 속도' not in sv) :
                        equipment['무기_ATK'] = int(int_pattern.findall(sv)[0])
                    elif '추가 피해 +' in sv:
                        equipment['무기_AD(%)'] = float(float_pattern.search(sv).group())
                    elif 'qualityValue' in sk:
                        equipment['무기_quality'] = v
                    elif 'Tooltip_Element_001_value_leftStr0' in sk:
                        equipment['무기_type'] = sv
                    elif ('Tooltip_Element_008_value_Element_001' in sk) & (equipment['무기_setName'] == None)\
                    & ('bPoint' not in sk) & ('contentStr' not in sk) & ('topStr' not in sk):
                        equipment['무기_setName'] = sv.split(' Lv.')[0]
                        equipment['무기_setLevel'] = int(sv.split(' Lv.')[1])
                    elif 'maximum' in sk:
                        equipment['무기_REXP'] = v
                    elif ('에스더 효과' in sv) & ('에스더 효과' != sv) &('할 수 있습니다' not in sv):
                        equipment['무기_estherEffect'] = sv.split('[')[1].replace(']', '')
                    elif '엘라 부여 완료' in sv:
                        equipment['무기_ella'] = True
                    elif sv == '에스더': # 에스더 세트 네임, 레벨 
                        equipment['무기_esther'] = True
                        equipment['무기_ella'] = False # 항상 sv==에스더가 먼저옴 -> 우선 False로 설정
                        cvalues = eval(df[df['characterCode'] == df['characterCode'][i]]['data'].values[0])
                        cfd = flatten_dict(cvalues[1])
                        for ck, cv in cfd.items():
                            scv = str(cv)
                            if '장갑' in scv:
                                set_name = scv.split(' (')[0]
                                set_level = int(int_pattern.findall(scv)[0])
                                equipment['무기_setName'] = set_name
                                equipment['무기_setLevel'] = set_level
                                break

            elif fd['Type'] in ['투구', '어깨', '상의', '하의', '장갑']:
                archemy_count = 0
                etype = fd['Type']
                equipment[f'{etype}_grade'] = fd['Grade']
                equipment[f'{etype}_name'] = fd['Name'].split(' ', 1)[1]
                if '+' in fd['Name']:
                    equipment[f'{etype}_reinforcementStep'] = fd['Name'].split(' ', 1)[0].replace('+', '')
                else:
                    equipment[f'{etype}_reinforcementStep'] = 0

                for k, v in fd.items():
                    sv = str(v)
                    sk = str(k)
                    if ('아이템 레벨' in sv) & ('티어' in sv):
                        equipment[f'{etype}_itemLevel'] = int(int_pattern.findall(sv.split(' (')[0])[0])
                        equipment[f'{etype}_tier'] = int(int_pattern.findall(sv.split(' (')[1])[0])
                    elif (('공용' in sv) | ('질서' in sv) | ('혼돈' in sv) | \
                          ('[견갑]' in sv) | ('[상의]' in sv) | ('[하의]' in sv)) \
                    & ('혼돈 강화' not in  sv):
                        archemy_count += 1
                        archemy = archemy_pattern.findall(sv)[0]
                        equipment[f'{etype}_alchemyName{archemy_count}'] = archemy[0].strip()
                        equipment[f'{etype}_alchemyPoint{archemy_count}'] = int(archemy[1])
                    elif (('힘 +' in sv) | ('민첩 +' in sv) | ('지능 +' in sv)) & ('방어력' in sv):
                        res = int_pattern.findall(sv)
                        equipment[f'{etype}_BDEF'] = int(res[0])
                        equipment[f'{etype}_BMDEF'] = int(res[1])
                        equipment[f'{etype}_SAI'] = int(res[2])
                        equipment[f'{etype}_BHP'] = int(res[3])
                    elif (('힘 +' not in sv) | ('민첩 +' not in sv) | ('지능 +' not in sv))\
                    & (('방어력' in sv) | ('생명 활성력' in sv)) & ('contentStr' not in sk):
                        res = int_pattern.findall(sv)
                        if len(res)>1:
                            equipment[f'{etype}_ADEF'] = int(res[0])
                            equipment[f'{etype}_AMDEF'] = int(res[1])
                            equipment[f'{etype}_AHP'] = int(res[2])
                        else:
                            equipment[f'{etype}_AHPP'] = int(res[0])
                    elif 'maximum' in sk:
                        equipment[f'{etype}_REXP'] = v
                    elif 'qualityValue' in sk:
                        equipment[f'{etype}_quality'] = v
                    elif 'Tooltip_Element_001_value_leftStr0' in sk:
                        equipment[f'{etype}_type'] = sv
                    elif ('Tooltip_Element_008_value_Element_001' in sk) & (equipment[f'{etype}_setName'] == None)\
                    & ('bPoint' not in sk) & ('contentStr' not in sk) & ('topStr' not in sk):
                        equipment[f'{etype}_setName'] = sv.split(' Lv.')[0]
                        equipment[f'{etype}_setLevel'] = int(sv.split(' Lv.')[1])
                
            elif fd['Type'] in ['목걸이', '귀걸이', '반지']:
                engraving_count = 0
                atype = fd['Type']
                if atype == '귀걸이': 
                    earring_count += 1
                    atype += str(earring_count)
                elif atype == '반지': 
                    ring_count += 1
                    atype += str(ring_count)
                accessory[f'{atype}_grade'] = fd['Grade']
                accessory[f'{atype}_name'] = fd['Name']
                for k, v in fd.items():
                    sk = str(k)
                    sv = str(v)
                    if 'qualityValue' in sv:
                        accessory[f'{atype}_quality'] = v 
                    elif '티어' in sv:
                        accessory[f'{atype}_tier'] = int(int_pattern.findall(sv)[0])
                    elif '아이템 레벨' in sv:
                        ssv = sv.split('아이템 레벨')
                        accessory[f'{atype}_limitLevel'] = int(ssv[1])
                        try:
                            res = int_pattern.findall(ssv[0])[0]
                            accessory[f'{atype}_availableTrade'] = int(res)
                        except:
                            accessory[f'{atype}_availableTrade'] = 0
                    elif '체력' in sv:
                        res = int_pattern.findall(sv)
                        accessory[f'{atype}_SAI'] = int(res[0])
                        accessory[f'{atype}_HP'] = int(res[-1])
                    elif (('반지' not in sv) & ('귀걸이' not in sv) & ('목걸이' not in sv)) & \
                    (('치명' in sv) | ('특화' in sv) | ('신속' in sv) | ('제압' in sv) | ('인내' in sv) \
                     | ('숙련' in sv)):
                        svrs = sv.replace('+', '').split(' ')
                        for idx in range(0, len(svrs), 2):
                            accessory[f'{atype}_{svrs[idx]}'] = int(svrs[idx+1])
                    elif '활성도' in sv:
                        svrs = sv.replace('[', '').replace(']', '').replace('+', '').split(' 활성도')
                        if '감소' in svrs[0]:
                            accessory[f'{atype}_dengraving_name'] = svrs[0]
                            accessory[f'{atype}_dengraving_point'] = int(svrs[1])
                        else:
                            engraving_count += 1
                            accessory[f'{atype}_engraving{engraving_count}_name'] = svrs[0]
                            accessory[f'{atype}_engraving{engraving_count}_point'] = int(svrs[1])
                    elif ('군단장' in sv) | ('어비스' in sv) | ('카오스 던전' in sv) | ('필드 보스' in sv) |\
                    ('가디언 토벌' in sv):
                        accessory[f'{atype}_acquirablePlace'] = sv
            elif fd['Type'] =='팔찌':
                accessory['팔찌_grade'] = fd['Grade']
                accessory['팔찌_name'] = fd['Name']
                for k, v in fd.items():
                    sk = str(k)
                    sv = str(v)
                    if '티어' in sv:
                        accessory['팔찌_tier'] = int(int_pattern.findall(sv)[0])
                    elif '효과 부여' in sv:
                        try:
                            svn = int(int_pattern.findall(sv)[0])
                            accessory['팔찌_canRerollNum'] = svn
                        except:
                            accessory['팔찌_canRerollNum'] = 0
                    elif 'Tooltip_Element_004_value_Element_001' in sk:
                        effect_count = 1
                        canGivenNum = 1
                        sv= sv.replace(')', ') ')
                        while '효과 부여 가능' in sv:
                            accessory['팔찌_canGivenNum'] = canGivenNum
                            canGivenNum += 1
                            sv = sv.replace('효과 부여 가능', '', 1)
                        if canGivenNum == 1:
                            accessory['팔찌_canGivenNum'] = 0
                        for v in plus_pattern.findall(sv):
                            v = list(v)
                            v[0] = v[0].replace('회복량', '전투 중 생명력 회복량').replace('마나', '최대 마나')\
                            .replace('공격력', '무기 공격력').replace('생명력', '최대 생명력')
                            if v[0] == '방어력':
                                svidx = sv.find(f'{v[0]} +{v[1]}')
                                v[0] = v[0].replace('방어력', f'{sv[svidx-3:svidx]}방어력')
                            accessory[f'팔찌_effect{effect_count}'] = v
                            effect_count += 1
                            sv = sv.replace(f'{v[0]} +{v[1]}', '')
                        while len(bracelet_pattern.findall(sv)) != 0:
                            accessory[f'팔찌_effect{effect_count}'] = bracelet_pattern.findall(sv)[0][:-2].strip()
                            sv = sv.replace(bracelet_pattern.findall(sv)[0][:-2], '')
                            effect_count += 1
                        if len(sv) > 1:
                            accessory[f'팔찌_effect{effect_count}'] = sv.strip()
            elif fd['Type'] == '어빌리티 스톤':
                engraving_count = 0 
                accessory['AS_grade'] = fd['Grade']
                accessory['AS_name'] = fd['Name']
                if 'IV' in fd['Name']:
                    accessory['AS_setLevel'] = 4
                elif 'III' in fd['Name']:
                    accessory['AS_setLevel'] = 3
                elif 'II' in fd['Name']:
                    accessory['AS_setLevel'] = 2
                elif 'I' in fd['Name']:
                    accessory['AS_setLevel'] = 1
                else:
                    accessory['AS_setLevel'] = 0
                accessory['AS_BHP'] = 0
                for k, v in fd.items():
                    sv = str(v)
                    sk = str(k)
                    if ('티어' in sv) & ('[' not in sv):
                        accessory['AS_tier'] = int(sv[-1])
                    elif sk == 'Tooltip_Element_004_value_Element_001':
                        accessory['AS_HP'] = int(int_pattern.findall(sv)[0])
                    elif sk == 'Tooltip_Element_005_value_Element_001':
                        accessory['AS_BHP'] = int(int_pattern.findall(sv)[0])
                    elif '활성도' in sv:
                        svrs = sv.replace('[', '').replace(']', '').replace('+', '').split(' 활성도')
                        if '감소' in svrs[0]:
                            accessory[f'AS_dengraving_name'] = svrs[0]
                            accessory[f'AS_dengraving_point'] = int(svrs[1])
                        else:
                            engraving_count += 1
                            accessory[f'AS_engraving{engraving_count}_name'] = svrs[0]
                            accessory[f'AS_engraving{engraving_count}_point'] = int(svrs[1])
            elif fd['Type'] in ['나침반', '부적', '문장']:
                sequipment[f'{fd["Type"]}_grade'] = fd['Grade']
                sequipment[f'{fd["Type"]}_name'] = fd['Name']
                        
#         pprint(sequipment)
    except Exception as e:
        print_exception(fd, sk, sv, e)
        break
        
### Insert DB ###
    # avatar table
    try:  
        sql = f"""
            INSERT INTO lostark.equipment_table (
                {''.join(f'{key}, ' for key in equipments.keys())[:-2]})
            VALUES ({''.join('%s, ' for _ in range(len(equipments.keys())))[:-2]});
            """
        values = [equipment['characterCode'], equipment['무기_grade'], equipment['무기_name'], equipment['무기_type'], equipment['무기_quality'], equipment['무기_tier'], equipment['무기_itemLevel'], equipment['무기_ATK'], equipment['무기_AD(%)'], equipment['무기_setName'], equipment['무기_setLevel'], equipment['무기_REXP'], equipment['무기_esther'], equipment['무기_estherEffect'], equipment['무기_ella'], equipment['무기_reinforcementStep'], equipment['투구_grade'], equipment['투구_name'], equipment['투구_type'], equipment['투구_quality'], equipment['투구_tier'], equipment['투구_itemLevel'], equipment['투구_SAI'], equipment['투구_BDEF'], equipment['투구_BMDEF'], equipment['투구_BHP'], equipment['투구_ADEF'], equipment['투구_AMDEF'], equipment['투구_AHP'], equipment['투구_AHPP'], equipment['투구_setName'], equipment['투구_setLevel'], equipment['투구_REXP'], equipment['투구_reinforcementStep'], equipment['투구_alchemyName1'], equipment['투구_alchemyName2'], equipment['투구_alchemyPoint1'], equipment['투구_alchemyPoint2'], equipment['상의_grade'], equipment['상의_name'], equipment['상의_type'], equipment['상의_quality'], equipment['상의_tier'], equipment['상의_itemLevel'], equipment['상의_SAI'], equipment['상의_BDEF'], equipment['상의_BMDEF'], equipment['상의_BHP'], equipment['상의_ADEF'], equipment['상의_AMDEF'], equipment['상의_AHP'], equipment['상의_AHPP'], equipment['상의_setName'], equipment['상의_setLevel'], equipment['상의_REXP'], equipment['상의_reinforcementStep'], equipment['상의_alchemyName1'], equipment['상의_alchemyName2'], equipment['상의_alchemyPoint1'], equipment['상의_alchemyPoint2'], equipment['하의_grade'], equipment['하의_name'], equipment['하의_type'], equipment['하의_quality'], equipment['하의_tier'], equipment['하의_itemLevel'], equipment['하의_SAI'], equipment['하의_BDEF'], equipment['하의_BMDEF'], equipment['하의_BHP'], equipment['하의_ADEF'], equipment['하의_AMDEF'], equipment['하의_AHP'], equipment['하의_AHPP'], equipment['하의_setName'], equipment['하의_setLevel'], equipment['하의_REXP'], equipment['하의_reinforcementStep'], equipment['하의_alchemyName1'], equipment['하의_alchemyName2'], equipment['하의_alchemyPoint1'], equipment['하의_alchemyPoint2'], equipment['어깨_grade'], equipment['어깨_name'], equipment['어깨_type'], equipment['어깨_quality'], equipment['어깨_tier'], equipment['어깨_itemLevel'], equipment['어깨_SAI'], equipment['어깨_BDEF'], equipment['어깨_BMDEF'], equipment['어깨_BHP'], equipment['어깨_ADEF'], equipment['어깨_AMDEF'], equipment['어깨_AHP'], equipment['어깨_AHPP'], equipment['어깨_setName'], equipment['어깨_setLevel'], equipment['어깨_REXP'], equipment['어깨_reinforcementStep'], equipment['어깨_alchemyName1'], equipment['어깨_alchemyName2'], equipment['어깨_alchemyPoint1'], equipment['어깨_alchemyPoint2'], equipment['장갑_grade'], equipment['장갑_name'], equipment['장갑_type'], equipment['장갑_quality'], equipment['장갑_tier'], equipment['장갑_itemLevel'], equipment['장갑_SAI'], equipment['장갑_BDEF'], equipment['장갑_BMDEF'], equipment['장갑_BHP'], equipment['장갑_ADEF'], equipment['장갑_AMDEF'], equipment['장갑_AHP'], equipment['장갑_AHPP'], equipment['장갑_setName'], equipment['장갑_setLevel'], equipment['장갑_REXP'], equipment['장갑_reinforcementStep'], equipment['장갑_alchemyName1'], equipment['장갑_alchemyName2'], equipment['장갑_alchemyPoint1'], equipment['장갑_alchemyPoint2']]
        cursor.execute(sql, values)
        db.commit()
    except Exception as e:
        # Rollback if there is any error
        db.rollback()
        print_exception_db(equipment, e)
        break
        
    try:  
        sql = f"""
            INSERT INTO lostark.accessory_table (
                {''.join(f'{key}, ' for key in accessories.keys())[:-2]})
            VALUES ({''.join('%s, ' for _ in range(len(accessories.keys())))[:-2]});
            """
        values = [accessory['characterCode'], accessory['팔찌_grade'], accessory['팔찌_name'], accessory['팔찌_tier'], accessory['팔찌_effect1'], accessory['팔찌_effect2'], accessory['팔찌_effect3'], accessory['팔찌_effect4'], accessory['팔찌_effect5'], accessory['팔찌_canRerollNum'], accessory['팔찌_canGivenNum'], accessory['AS_grade'], accessory['AS_name'], accessory['AS_tier'], accessory['AS_HP'], accessory['AS_BHP'], accessory['AS_engraving1_name'], accessory['AS_engraving1_point'], accessory['AS_engraving2_name'], accessory['AS_engraving2_point'], accessory['AS_dengraving_name'], accessory['AS_dengraving_point'], accessory['AS_setLevel'], accessory['목걸이_grade'], accessory['목걸이_name'], accessory['목걸이_quality'], accessory['목걸이_tier'], accessory['목걸이_limitLevel'], accessory['목걸이_availableTrade'], accessory['목걸이_SAI'], accessory['목걸이_HP'], accessory['목걸이_치명'], accessory['목걸이_특화'], accessory['목걸이_신속'], accessory['목걸이_제압'], accessory['목걸이_인내'], accessory['목걸이_숙련'], accessory['목걸이_engraving1_name'], accessory['목걸이_engraving1_point'], accessory['목걸이_engraving2_name'], accessory['목걸이_engraving2_point'], accessory['목걸이_dengraving_name'], accessory['목걸이_dengraving_point'], accessory['목걸이_acquirablePlace'], accessory['귀걸이1_grade'], accessory['귀걸이1_name'], accessory['귀걸이1_quality'], accessory['귀걸이1_tier'], accessory['귀걸이1_limitLevel'], accessory['귀걸이1_availableTrade'], accessory['귀걸이1_SAI'], accessory['귀걸이1_HP'], accessory['귀걸이1_치명'], accessory['귀걸이1_특화'], accessory['귀걸이1_신속'], accessory['귀걸이1_제압'], accessory['귀걸이1_인내'], accessory['귀걸이1_숙련'], accessory['귀걸이1_engraving1_name'], accessory['귀걸이1_engraving1_point'], accessory['귀걸이1_engraving2_name'], accessory['귀걸이1_engraving2_point'], accessory['귀걸이1_dengraving_name'], accessory['귀걸이1_dengraving_point'], accessory['귀걸이1_acquirablePlace'], accessory['귀걸이2_grade'], accessory['귀걸이2_name'], accessory['귀걸이2_quality'], accessory['귀걸이2_tier'], accessory['귀걸이2_limitLevel'], accessory['귀걸이2_availableTrade'], accessory['귀걸이2_SAI'], accessory['귀걸이2_HP'], accessory['귀걸이2_치명'], accessory['귀걸이2_특화'], accessory['귀걸이2_신속'], accessory['귀걸이2_제압'], accessory['귀걸이2_인내'], accessory['귀걸이2_숙련'], accessory['귀걸이2_engraving1_name'], accessory['귀걸이2_engraving1_point'], accessory['귀걸이2_engraving2_name'], accessory['귀걸이2_engraving2_point'], accessory['귀걸이2_dengraving_name'], accessory['귀걸이2_dengraving_point'], accessory['귀걸이2_acquirablePlace'], accessory['반지1_grade'], accessory['반지1_name'], accessory['반지1_quality'], accessory['반지1_tier'], accessory['반지1_limitLevel'], accessory['반지1_availableTrade'], accessory['반지1_SAI'], accessory['반지1_HP'], accessory['반지1_치명'], accessory['반지1_특화'], accessory['반지1_신속'], accessory['반지1_제압'], accessory['반지1_인내'], accessory['반지1_숙련'], accessory['반지1_engraving1_name'], accessory['반지1_engraving1_point'], accessory['반지1_engraving2_name'], accessory['반지1_engraving2_point'], accessory['반지1_dengraving_name'], accessory['반지1_dengraving_point'], accessory['반지1_acquirablePlace'], accessory['반지2_grade'], accessory['반지2_name'], accessory['반지2_quality'], accessory['반지2_tier'], accessory['반지2_limitLevel'], accessory['반지2_availableTrade'], accessory['반지2_SAI'], accessory['반지2_HP'], accessory['반지2_치명'], accessory['반지2_특화'], accessory['반지2_신속'], accessory['반지2_제압'], accessory['반지2_인내'], accessory['반지2_숙련'], accessory['반지2_engraving1_name'], accessory['반지2_engraving1_point'], accessory['반지2_engraving2_name'], accessory['반지2_engraving2_point'], accessory['반지2_dengraving_name'], accessory['반지2_dengraving_point'], accessory['반지2_acquirablePlace']]
        cursor.execute(sql, values)
        db.commit()
    except Exception as e:
        # Rollback if there is any error
        db.rollback()
        print_exception_db(accessory, e)
        break
        
    try:  
        sql = f"""
            INSERT INTO lostark.special_equipment_table (
                {''.join(f'{key}, ' for key in sequipments.keys())[:-2]})
            VALUES ({''.join('%s, ' for _ in range(len(sequipments.keys())))[:-2]});
            """
        values = [sequipment['characterCode'], sequipment['나침반_grade'], sequipment['나침반_name'], sequipment['부적_grade'], sequipment['부적_name'], sequipment['문장_grade'], sequipment['문장_name']]
        cursor.execute(sql, values)
        db.commit()
    except Exception as e:
        # Rollback if there is any error
        db.rollback()
        print_exception_db(sequipment, e)
        break
# Out:
# --------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-169-85329909873b> in <module>
#      17     try:
#      18         for j in range(len(cdf)):
# ---> 19             fd = flatten_dict(cdf[j])
#      20             if '무기' == fd['Type']:
#      21                 equipment['무기_grade'] = fd['Grade']
#
# <ipython-input-5-2ca9f8fa9c64> in flatten_dict(d, parent_key, sep)
#       9
#      10         if isinstance(v, dict):
# ---> 11             items.update(flatten_dict(v, new_key, sep))
#      12         else:
#      13             items[new_key] = v
#
# <ipython-input-5-2ca9f8fa9c64> in flatten_dict(d, parent_key, sep)
#       9
#      10         if isinstance(v, dict):
# ---> 11             items.update(flatten_dict(v, new_key, sep))
#      12         else:
#      13             items[new_key] = v
#
# <ipython-input-5-2ca9f8fa9c64> in flatten_dict(d, parent_key, sep)
#       6             v = eval(v)
# ...

# %% [markdown]
# # ArmorySkills

# %%
df = pd.read_csv('./data/ArmorySkills.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
skill_parts = [f'skill{i}' for i in range(1,17)] # 16개 스킬만 고려
dic_keys = ['name', 'level', 'cooltime','tripod1_name', 'tripod1_point', 'tripod2_name', 'tripod2_point',
            'tripod3_name', 'tripod3_point', 'runeName', 'runeGrade','headAttack', 'backAttack', 
            'partBreak', 'stagger', 'counter', '마나', '배터리', '버블', '충격', '기공', '기력', '내공', 
            '경직면역', '피격면역', '상태이상면역']
skills = {
    'characterCode': None,
}
for part in skill_parts:
    for key in dic_keys:
        skills[f'{part}_{key}'] = None
# Out:
# %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
# ...

# %%
# ALTER TABLE `lostark`.`skill_table` 
# ADD COLUMN `skill1_name` VARCHAR(16) NULL AFTER `characterCode`,
# ADD COLUMN `skill1_level` TINYINT NULL AFTER `skill1_name`,
# ADD COLUMN `skill1_cooltime` TINYINT NULL AFTER `skill1_level`,
# ADD COLUMN `skill1_tripod1_name` VARCHAR(16) NULL AFTER `skill1_cooltime`,
# ADD COLUMN `skill1_tripod1_point` TINYINT NULL AFTER `skill1_tripod1_name`,
# ADD COLUMN `skill1_tripod2_name` VARCHAR(16) NULL AFTER `skill1_tripod1_point`,
# ADD COLUMN `skill1_tripod2_point` TINYINT NULL AFTER `skill1_tripod2_name`,
# ADD COLUMN `skill1_tripod3_name` VARCHAR(16) NULL AFTER `skill1_tripod2_point`,
# ADD COLUMN `skill1_tripod3_point` TINYINT NULL AFTER `skill1_tripod3_name`,
# ADD COLUMN `skill1_runeName` VARCHAR(8) NULL AFTER `skill1_tripod3_point`,
# ADD COLUMN `skill1_runeGrade` VARCHAR(4) NULL AFTER `skill1_runeName`,
# ADD COLUMN `skill1_headAttack` TINYINT NULL AFTER `skill1_runeGrade`,
# ADD COLUMN `skill1_backAttack` TINYINT NULL AFTER `skill1_headAttack`,
# ADD COLUMN `skill1_partBreak` TINYINT NULL AFTER `skill1_backAttack`,
# ADD COLUMN `skill1_stagger` VARCHAR(4) NULL AFTER `skill1_partBreak`,
# ADD COLUMN `skill1_counter` TINYINT NULL AFTER `skill1_stagger`,
# ADD COLUMN `skill1_마나` SMALLINT NULL AFTER `skill1_counter`,
# ADD COLUMN `skill1_배터리` SMALLINT NULL AFTER `skill1_마나`,
# ADD COLUMN `skill1_버블` TINYINT NULL AFTER `skill1_배터리`,
# ADD COLUMN `skill1_충격` TINYINT NULL AFTER `skill1_버블`,
# ADD COLUMN `skill1_기력` TINYINT NULL AFTER `skill1_충격`,
# ADD COLUMN `skill1_내공` SMALLINT NULL AFTER `skill1_기력`,
# ADD COLUMN `skill1_경직면역` VARCHAR(45) NULL AFTER `skill1_내공`,
# ADD COLUMN `skill1_피격면역` VARCHAR(45) NULL AFTER `skill1_경직면역`,
# ADD COLUMN `skill1_상태이상면역` VARCHAR(45) NULL AFTER `skill1_피격면역`,
# ADD COLUMN `skill2_name` VARCHAR(16) NULL AFTER `skill1_상태이상면역`,
# ADD COLUMN `skill2_level` TINYINT NULL AFTER `skill2_name`,
# ADD COLUMN `skill2_cooltime` TINYINT NULL AFTER `skill2_level`,
# ADD COLUMN `skill2_tripod1_name` VARCHAR(16) NULL AFTER `skill2_cooltime`,
# ADD COLUMN `skill2_tripod1_point` TINYINT NULL AFTER `skill2_tripod1_name`,
# ADD COLUMN `skill2_tripod2_name` VARCHAR(16) NULL AFTER `skill2_tripod1_point`,
# ADD COLUMN `skill2_tripod2_point` TINYINT NULL AFTER `skill2_tripod2_name`,
# ADD COLUMN `skill2_tripod3_name` VARCHAR(16) NULL AFTER `skill2_tripod2_point`,
# ADD COLUMN `skill2_tripod3_point` TINYINT NULL AFTER `skill2_tripod3_name`,
# ADD COLUMN `skill2_runeName` VARCHAR(8) NULL AFTER `skill2_tripod3_point`,
# ADD COLUMN `skill2_runeGrade` VARCHAR(4) NULL AFTER `skill2_runeName`,
# ADD COLUMN `skill2_headAttack` TINYINT NULL AFTER `skill2_runeGrade`,
# ADD COLUMN `skill2_backAttack` TINYINT NULL AFTER `skill2_headAttack`,
# ADD COLUMN `skill2_partBreak` TINYINT NULL AFTER `skill2_backAttack`,
# ADD COLUMN `skill2_stagger` VARCHAR(4) NULL AFTER `skill2_partBreak`,
# ADD COLUMN `skill2_counter` TINYINT NULL AFTER `skill2_stagger`,
# ADD COLUMN `skill2_마나` SMALLINT NULL AFTER `skill2_counter`,
# ADD COLUMN `skill2_배터리` SMALLINT NULL AFTER `skill2_마나`,
# ADD COLUMN `skill2_버블` TINYINT NULL AFTER `skill2_배터리`,
# ADD COLUMN `skill2_충격` TINYINT NULL AFTER `skill2_버블`,
# ADD COLUMN `skill2_기력` TINYINT NULL AFTER `skill2_충격`,
# ADD COLUMN `skill2_내공` SMALLINT NULL AFTER `skill2_기력`,
# ADD COLUMN `skill2_경직면역` VARCHAR(45) NULL AFTER `skill2_내공`,
# ADD COLUMN `skill2_피격면역` VARCHAR(45) NULL AFTER `skill2_경직면역`,
# ADD COLUMN `skill2_상태이상면역` VARCHAR(45) NULL AFTER `skill2_피격면역`,
# ADD COLUMN `skill3_name` VARCHAR(16) NULL AFTER `skill2_상태이상면역`,
# ADD COLUMN `skill3_level` TINYINT NULL AFTER `skill3_name`,
# ADD COLUMN `skill3_cooltime` TINYINT NULL AFTER `skill3_level`,
# ADD COLUMN `skill3_tripod1_name` VARCHAR(16) NULL AFTER `skill3_cooltime`,
# ADD COLUMN `skill3_tripod1_point` TINYINT NULL AFTER `skill3_tripod1_name`,
# ADD COLUMN `skill3_tripod2_name` VARCHAR(16) NULL AFTER `skill3_tripod1_point`,
# ADD COLUMN `skill3_tripod2_point` TINYINT NULL AFTER `skill3_tripod2_name`,
# ADD COLUMN `skill3_tripod3_name` VARCHAR(16) NULL AFTER `skill3_tripod2_point`,
# ADD COLUMN `skill3_tripod3_point` TINYINT NULL AFTER `skill3_tripod3_name`,
# ADD COLUMN `skill3_runeName` VARCHAR(8) NULL AFTER `skill3_tripod3_point`,
# ADD COLUMN `skill3_runeGrade` VARCHAR(4) NULL AFTER `skill3_runeName`,
# ADD COLUMN `skill3_headAttack` TINYINT NULL AFTER `skill3_runeGrade`,
# ADD COLUMN `skill3_backAttack` TINYINT NULL AFTER `skill3_headAttack`,
# ADD COLUMN `skill3_partBreak` TINYINT NULL AFTER `skill3_backAttack`,
# ADD COLUMN `skill3_stagger` VARCHAR(4) NULL AFTER `skill3_partBreak`,
# ADD COLUMN `skill3_counter` TINYINT NULL AFTER `skill3_stagger`,
# ADD COLUMN `skill3_마나` SMALLINT NULL AFTER `skill3_counter`,
# ADD COLUMN `skill3_배터리` SMALLINT NULL AFTER `skill3_마나`,
# ADD COLUMN `skill3_버블` TINYINT NULL AFTER `skill3_배터리`,
# ADD COLUMN `skill3_충격` TINYINT NULL AFTER `skill3_버블`,
# ADD COLUMN `skill3_기력` TINYINT NULL AFTER `skill3_충격`,
# ADD COLUMN `skill3_내공` SMALLINT NULL AFTER `skill3_기력`,
# ADD COLUMN `skill3_경직면역` VARCHAR(45) NULL AFTER `skill3_내공`,
# ADD COLUMN `skill3_피격면역` VARCHAR(45) NULL AFTER `skill3_경직면역`,
# ADD COLUMN `skill3_상태이상면역` VARCHAR(45) NULL AFTER `skill3_피격면역`,
# ADD COLUMN `skill4_name` VARCHAR(16) NULL AFTER `skill3_상태이상면역`,
# ADD COLUMN `skill4_level` TINYINT NULL AFTER `skill4_name`,
# ADD COLUMN `skill4_cooltime` TINYINT NULL AFTER `skill4_level`,
# ADD COLUMN `skill4_tripod1_name` VARCHAR(16) NULL AFTER `skill4_cooltime`,
# ADD COLUMN `skill4_tripod1_point` TINYINT NULL AFTER `skill4_tripod1_name`,
# ADD COLUMN `skill4_tripod2_name` VARCHAR(16) NULL AFTER `skill4_tripod1_point`,
# ADD COLUMN `skill4_tripod2_point` TINYINT NULL AFTER `skill4_tripod2_name`,
# ADD COLUMN `skill4_tripod3_name` VARCHAR(16) NULL AFTER `skill4_tripod2_point`,
# ADD COLUMN `skill4_tripod3_point` TINYINT NULL AFTER `skill4_tripod3_name`,
# ADD COLUMN `skill4_runeName` VARCHAR(8) NULL AFTER `skill4_tripod3_point`,
# ADD COLUMN `skill4_runeGrade` VARCHAR(4) NULL AFTER `skill4_runeName`,
# ADD COLUMN `skill4_headAttack` TINYINT NULL AFTER `skill4_runeGrade`,
# ADD COLUMN `skill4_backAttack` TINYINT NULL AFTER `skill4_headAttack`,
# ADD COLUMN `skill4_partBreak` TINYINT NULL AFTER `skill4_backAttack`,
# ADD COLUMN `skill4_stagger` VARCHAR(4) NULL AFTER `skill4_partBreak`,
# ADD COLUMN `skill4_counter` TINYINT NULL AFTER `skill4_stagger`,
# ADD COLUMN `skill4_마나` SMALLINT NULL AFTER `skill4_counter`,
# ADD COLUMN `skill4_배터리` SMALLINT NULL AFTER `skill4_마나`,
# ADD COLUMN `skill4_버블` TINYINT NULL AFTER `skill4_배터리`,
# ADD COLUMN `skill4_충격` TINYINT NULL AFTER `skill4_버블`,
# ADD COLUMN `skill4_기력` TINYINT NULL AFTER `skill4_충격`,
# ADD COLUMN `skill4_내공` SMALLINT NULL AFTER `skill4_기력`,
# ADD COLUMN `skill4_경직면역` VARCHAR(45) NULL AFTER `skill4_내공`,
# ADD COLUMN `skill4_피격면역` VARCHAR(45) NULL AFTER `skill4_경직면역`,
# ADD COLUMN `skill4_상태이상면역` VARCHAR(45) NULL AFTER `skill4_피격면역`,
# ADD COLUMN `skill5_name` VARCHAR(16) NULL AFTER `skill4_상태이상면역`,
# ADD COLUMN `skill5_level` TINYINT NULL AFTER `skill5_name`,
# ADD COLUMN `skill5_cooltime` TINYINT NULL AFTER `skill5_level`,
# ADD COLUMN `skill5_tripod1_name` VARCHAR(16) NULL AFTER `skill5_cooltime`,
# ADD COLUMN `skill5_tripod1_point` TINYINT NULL AFTER `skill5_tripod1_name`,
# ADD COLUMN `skill5_tripod2_name` VARCHAR(16) NULL AFTER `skill5_tripod1_point`,
# ADD COLUMN `skill5_tripod2_point` TINYINT NULL AFTER `skill5_tripod2_name`,
# ADD COLUMN `skill5_tripod3_name` VARCHAR(16) NULL AFTER `skill5_tripod2_point`,
# ADD COLUMN `skill5_tripod3_point` TINYINT NULL AFTER `skill5_tripod3_name`,
# ADD COLUMN `skill5_runeName` VARCHAR(8) NULL AFTER `skill5_tripod3_point`,
# ADD COLUMN `skill5_runeGrade` VARCHAR(4) NULL AFTER `skill5_runeName`,
# ADD COLUMN `skill5_headAttack` TINYINT NULL AFTER `skill5_runeGrade`,
# ADD COLUMN `skill5_backAttack` TINYINT NULL AFTER `skill5_headAttack`,
# ADD COLUMN `skill5_partBreak` TINYINT NULL AFTER `skill5_backAttack`,
# ADD COLUMN `skill5_stagger` VARCHAR(4) NULL AFTER `skill5_partBreak`,
# ADD COLUMN `skill5_counter` TINYINT NULL AFTER `skill5_stagger`,
# ADD COLUMN `skill5_마나` SMALLINT NULL AFTER `skill5_counter`,
# ADD COLUMN `skill5_배터리` SMALLINT NULL AFTER `skill5_마나`,
# ADD COLUMN `skill5_버블` TINYINT NULL AFTER `skill5_배터리`,
# ADD COLUMN `skill5_충격` TINYINT NULL AFTER `skill5_버블`,
# ADD COLUMN `skill5_기력` TINYINT NULL AFTER `skill5_충격`,
# ADD COLUMN `skill5_내공` SMALLINT NULL AFTER `skill5_기력`,
# ADD COLUMN `skill5_경직면역` VARCHAR(45) NULL AFTER `skill5_내공`,
# ADD COLUMN `skill5_피격면역` VARCHAR(45) NULL AFTER `skill5_경직면역`,
# ADD COLUMN `skill5_상태이상면역` VARCHAR(45) NULL AFTER `skill5_피격면역`,
# ADD COLUMN `skill6_name` VARCHAR(16) NULL AFTER `skill5_상태이상면역`,
# ADD COLUMN `skill6_level` TINYINT NULL AFTER `skill6_name`,
# ADD COLUMN `skill6_cooltime` TINYINT NULL AFTER `skill6_level`,
# ADD COLUMN `skill6_tripod1_name` VARCHAR(16) NULL AFTER `skill6_cooltime`,
# ADD COLUMN `skill6_tripod1_point` TINYINT NULL AFTER `skill6_tripod1_name`,
# ADD COLUMN `skill6_tripod2_name` VARCHAR(16) NULL AFTER `skill6_tripod1_point`,
# ADD COLUMN `skill6_tripod2_point` TINYINT NULL AFTER `skill6_tripod2_name`,
# ADD COLUMN `skill6_tripod3_name` VARCHAR(16) NULL AFTER `skill6_tripod2_point`,
# ADD COLUMN `skill6_tripod3_point` TINYINT NULL AFTER `skill6_tripod3_name`,
# ADD COLUMN `skill6_runeName` VARCHAR(8) NULL AFTER `skill6_tripod3_point`,
# ADD COLUMN `skill6_runeGrade` VARCHAR(4) NULL AFTER `skill6_runeName`,
# ADD COLUMN `skill6_headAttack` TINYINT NULL AFTER `skill6_runeGrade`,
# ADD COLUMN `skill6_backAttack` TINYINT NULL AFTER `skill6_headAttack`,
# ADD COLUMN `skill6_partBreak` TINYINT NULL AFTER `skill6_backAttack`,
# ADD COLUMN `skill6_stagger` VARCHAR(4) NULL AFTER `skill6_partBreak`,
# ADD COLUMN `skill6_counter` TINYINT NULL AFTER `skill6_stagger`,
# ADD COLUMN `skill6_마나` SMALLINT NULL AFTER `skill6_counter`,
# ADD COLUMN `skill6_배터리` SMALLINT NULL AFTER `skill6_마나`,
# ADD COLUMN `skill6_버블` TINYINT NULL AFTER `skill6_배터리`,
# ADD COLUMN `skill6_충격` TINYINT NULL AFTER `skill6_버블`,
# ADD COLUMN `skill6_기력` TINYINT NULL AFTER `skill6_충격`,
# ADD COLUMN `skill6_내공` SMALLINT NULL AFTER `skill6_기력`,
# ADD COLUMN `skill6_경직면역` VARCHAR(45) NULL AFTER `skill6_내공`,
# ADD COLUMN `skill6_피격면역` VARCHAR(45) NULL AFTER `skill6_경직면역`,
# ADD COLUMN `skill6_상태이상면역` VARCHAR(45) NULL AFTER `skill6_피격면역`,
# ADD COLUMN `skill7_name` VARCHAR(16) NULL AFTER `skill6_상태이상면역`,
# ADD COLUMN `skill7_level` TINYINT NULL AFTER `skill7_name`,
# ADD COLUMN `skill7_cooltime` TINYINT NULL AFTER `skill7_level`,
# ADD COLUMN `skill7_tripod1_name` VARCHAR(16) NULL AFTER `skill7_cooltime`,
# ADD COLUMN `skill7_tripod1_point` TINYINT NULL AFTER `skill7_tripod1_name`,
# ADD COLUMN `skill7_tripod2_name` VARCHAR(16) NULL AFTER `skill7_tripod1_point`,
# ADD COLUMN `skill7_tripod2_point` TINYINT NULL AFTER `skill7_tripod2_name`,
# ADD COLUMN `skill7_tripod3_name` VARCHAR(16) NULL AFTER `skill7_tripod2_point`,
# ADD COLUMN `skill7_tripod3_point` TINYINT NULL AFTER `skill7_tripod3_name`,
# ADD COLUMN `skill7_runeName` VARCHAR(8) NULL AFTER `skill7_tripod3_point`,
# ADD COLUMN `skill7_runeGrade` VARCHAR(4) NULL AFTER `skill7_runeName`,
# ADD COLUMN `skill7_headAttack` TINYINT NULL AFTER `skill7_runeGrade`,
# ADD COLUMN `skill7_backAttack` TINYINT NULL AFTER `skill7_headAttack`,
# ADD COLUMN `skill7_partBreak` TINYINT NULL AFTER `skill7_backAttack`,
# ADD COLUMN `skill7_stagger` VARCHAR(4) NULL AFTER `skill7_partBreak`,
# ADD COLUMN `skill7_counter` TINYINT NULL AFTER `skill7_stagger`,
# ADD COLUMN `skill7_마나` SMALLINT NULL AFTER `skill7_counter`,
# ADD COLUMN `skill7_배터리` SMALLINT NULL AFTER `skill7_마나`,
# ADD COLUMN `skill7_버블` TINYINT NULL AFTER `skill7_배터리`,
# ADD COLUMN `skill7_충격` TINYINT NULL AFTER `skill7_버블`,
# ADD COLUMN `skill7_기력` TINYINT NULL AFTER `skill7_충격`,
# ADD COLUMN `skill7_내공` SMALLINT NULL AFTER `skill7_기력`,
# ADD COLUMN `skill7_경직면역` VARCHAR(45) NULL AFTER `skill7_내공`,
# ADD COLUMN `skill7_피격면역` VARCHAR(45) NULL AFTER `skill7_경직면역`,
# ADD COLUMN `skill7_상태이상면역` VARCHAR(45) NULL AFTER `skill7_피격면역`,
# ADD COLUMN `skill8_name` VARCHAR(16) NULL AFTER `skill7_상태이상면역`,
# ADD COLUMN `skill8_level` TINYINT NULL AFTER `skill8_name`,
# ADD COLUMN `skill8_cooltime` TINYINT NULL AFTER `skill8_level`,
# ADD COLUMN `skill8_tripod1_name` VARCHAR(16) NULL AFTER `skill8_cooltime`,
# ADD COLUMN `skill8_tripod1_point` TINYINT NULL AFTER `skill8_tripod1_name`,
# ADD COLUMN `skill8_tripod2_name` VARCHAR(16) NULL AFTER `skill8_tripod1_point`,
# ADD COLUMN `skill8_tripod2_point` TINYINT NULL AFTER `skill8_tripod2_name`,
# ADD COLUMN `skill8_tripod3_name` VARCHAR(16) NULL AFTER `skill8_tripod2_point`,
# ADD COLUMN `skill8_tripod3_point` TINYINT NULL AFTER `skill8_tripod3_name`,
# ADD COLUMN `skill8_runeName` VARCHAR(8) NULL AFTER `skill8_tripod3_point`,
# ADD COLUMN `skill8_runeGrade` VARCHAR(4) NULL AFTER `skill8_runeName`,
# ADD COLUMN `skill8_headAttack` TINYINT NULL AFTER `skill8_runeGrade`,
# ADD COLUMN `skill8_backAttack` TINYINT NULL AFTER `skill8_headAttack`,
# ADD COLUMN `skill8_partBreak` TINYINT NULL AFTER `skill8_backAttack`,
# ADD COLUMN `skill8_stagger` VARCHAR(4) NULL AFTER `skill8_partBreak`,
# ADD COLUMN `skill8_counter` TINYINT NULL AFTER `skill8_stagger`,
# ADD COLUMN `skill8_마나` SMALLINT NULL AFTER `skill8_counter`,
# ADD COLUMN `skill8_배터리` SMALLINT NULL AFTER `skill8_마나`,
# ADD COLUMN `skill8_버블` TINYINT NULL AFTER `skill8_배터리`,
# ADD COLUMN `skill8_충격` TINYINT NULL AFTER `skill8_버블`,
# ADD COLUMN `skill8_기력` TINYINT NULL AFTER `skill8_충격`,
# ADD COLUMN `skill8_내공` SMALLINT NULL AFTER `skill8_기력`,
# ADD COLUMN `skill8_경직면역` VARCHAR(45) NULL AFTER `skill8_내공`,
# ADD COLUMN `skill8_피격면역` VARCHAR(45) NULL AFTER `skill8_경직면역`,
# ADD COLUMN `skill8_상태이상면역` VARCHAR(45) NULL AFTER `skill8_피격면역`,
# ADD COLUMN `skill9_name` VARCHAR(16) NULL AFTER `skill8_피격면역`,
# ADD COLUMN `skill9_level` TINYINT NULL AFTER `skill9_name`,
# ADD COLUMN `skill9_cooltime` TINYINT NULL AFTER `skill9_level`,
# ADD COLUMN `skill9_tripod1_name` VARCHAR(16) NULL AFTER `skill9_cooltime`,
# ADD COLUMN `skill9_tripod1_point` TINYINT NULL AFTER `skill9_tripod1_name`,
# ADD COLUMN `skill9_tripod2_name` VARCHAR(16) NULL AFTER `skill9_tripod1_point`,
# ADD COLUMN `skill9_tripod2_point` TINYINT NULL AFTER `skill9_tripod2_name`,
# ADD COLUMN `skill9_tripod3_name` VARCHAR(16) NULL AFTER `skill9_tripod2_point`,
# ADD COLUMN `skill9_tripod3_point` TINYINT NULL AFTER `skill9_tripod3_name`,
# ADD COLUMN `skill9_runeName` VARCHAR(8) NULL AFTER `skill9_tripod3_point`,
# ADD COLUMN `skill9_runeGrade` VARCHAR(4) NULL AFTER `skill9_runeName`,
# ADD COLUMN `skill9_headAttack` TINYINT NULL AFTER `skill9_runeGrade`,
# ADD COLUMN `skill9_backAttack` TINYINT NULL AFTER `skill9_headAttack`,
# ADD COLUMN `skill9_partBreak` TINYINT NULL AFTER `skill9_backAttack`,
# ADD COLUMN `skill9_stagger` VARCHAR(4) NULL AFTER `skill9_partBreak`,
# ADD COLUMN `skill9_counter` TINYINT NULL AFTER `skill9_stagger`,
# ADD COLUMN `skill9_마나` SMALLINT NULL AFTER `skill9_counter`,
# ADD COLUMN `skill9_배터리` SMALLINT NULL AFTER `skill9_마나`,
# ADD COLUMN `skill9_버블` TINYINT NULL AFTER `skill9_배터리`,
# ADD COLUMN `skill9_충격` TINYINT NULL AFTER `skill9_버블`,
# ADD COLUMN `skill9_기력` TINYINT NULL AFTER `skill9_충격`,
# ADD COLUMN `skill9_내공` SMALLINT NULL AFTER `skill9_기력`,
# ADD COLUMN `skill9_경직면역` VARCHAR(45) NULL AFTER `skill9_내공`,
# ADD COLUMN `skill9_피격면역` VARCHAR(45) NULL AFTER `skill9_경직면역`,
# ADD COLUMN `skill9_상태이상면역` VARCHAR(45) NULL AFTER `skill9_피격면역`,
# ADD COLUMN `skill10_name` VARCHAR(16) NULL AFTER `skill9_상태이상면역`,
# ADD COLUMN `skill10_level` TINYINT NULL AFTER `skill10_name`,
# ADD COLUMN `skill10_cooltime` TINYINT NULL AFTER `skill10_level`,
# ADD COLUMN `skill10_tripod1_name` VARCHAR(16) NULL AFTER `skill10_cooltime`,
# ADD COLUMN `skill10_tripod1_point` TINYINT NULL AFTER `skill10_tripod1_name`,
# ADD COLUMN `skill10_tripod2_name` VARCHAR(16) NULL AFTER `skill10_tripod1_point`,
# ADD COLUMN `skill10_tripod2_point` TINYINT NULL AFTER `skill10_tripod2_name`,
# ADD COLUMN `skill10_tripod3_name` VARCHAR(16) NULL AFTER `skill10_tripod2_point`,
# ADD COLUMN `skill10_tripod3_point` TINYINT NULL AFTER `skill10_tripod3_name`,
# ADD COLUMN `skill10_runeName` VARCHAR(8) NULL AFTER `skill10_tripod3_point`,
# ADD COLUMN `skill10_runeGrade` VARCHAR(4) NULL AFTER `skill10_runeName`,
# ADD COLUMN `skill10_headAttack` TINYINT NULL AFTER `skill10_runeGrade`,
# ADD COLUMN `skill10_backAttack` TINYINT NULL AFTER `skill10_headAttack`,
# ADD COLUMN `skill10_partBreak` TINYINT NULL AFTER `skill10_backAttack`,
# ADD COLUMN `skill10_stagger` VARCHAR(4) NULL AFTER `skill10_partBreak`,
# ADD COLUMN `skill10_counter` TINYINT NULL AFTER `skill10_stagger`,
# ADD COLUMN `skill10_마나` SMALLINT NULL AFTER `skill10_counter`,
# ADD COLUMN `skill10_배터리` SMALLINT NULL AFTER `skill10_마나`,
# ADD COLUMN `skill10_버블` TINYINT NULL AFTER `skill10_배터리`,
# ADD COLUMN `skill10_충격` TINYINT NULL AFTER `skill10_버블`,
# ADD COLUMN `skill10_기력` TINYINT NULL AFTER `skill10_충격`,
# ADD COLUMN `skill10_내공` SMALLINT NULL AFTER `skill10_기력`,
# ADD COLUMN `skill10_경직면역` VARCHAR(45) NULL AFTER `skill10_내공`,
# ADD COLUMN `skill10_피격면역` VARCHAR(45) NULL AFTER `skill10_경직면역`,
# ADD COLUMN `skill10_상태이상면역` VARCHAR(45) NULL AFTER `skill10_피격면역`;
# ADD COLUMN `skill11_name` VARCHAR(16) NULL AFTER `skill10_상태이상면역`,
# ADD COLUMN `skill11_level` TINYINT NULL AFTER `skill11_name`,
# ADD COLUMN `skill11_cooltime` TINYINT NULL AFTER `skill11_level`,
# ADD COLUMN `skill11_tripod1_name` VARCHAR(16) NULL AFTER `skill11_cooltime`,
# ADD COLUMN `skill11_tripod1_point` TINYINT NULL AFTER `skill11_tripod1_name`,
# ADD COLUMN `skill11_tripod2_name` VARCHAR(16) NULL AFTER `skill11_tripod1_point`,
# ADD COLUMN `skill11_tripod2_point` TINYINT NULL AFTER `skill11_tripod2_name`,
# ADD COLUMN `skill11_tripod3_name` VARCHAR(16) NULL AFTER `skill11_tripod2_point`,
# ADD COLUMN `skill11_tripod3_point` TINYINT NULL AFTER `skill11_tripod3_name`,
# ADD COLUMN `skill11_runeName` VARCHAR(8) NULL AFTER `skill11_tripod3_point`,
# ADD COLUMN `skill11_runeGrade` VARCHAR(4) NULL AFTER `skill11_runeName`,
# ADD COLUMN `skill11_headAttack` TINYINT NULL AFTER `skill11_runeGrade`,
# ADD COLUMN `skill11_backAttack` TINYINT NULL AFTER `skill11_headAttack`,
# ADD COLUMN `skill11_partBreak` TINYINT NULL AFTER `skill11_backAttack`,
# ADD COLUMN `skill11_stagger` VARCHAR(4) NULL AFTER `skill11_partBreak`,
# ADD COLUMN `skill11_counter` TINYINT NULL AFTER `skill11_stagger`,
# ADD COLUMN `skill11_마나` SMALLINT NULL AFTER `skill11_counter`,
# ADD COLUMN `skill11_배터리` SMALLINT NULL AFTER `skill11_마나`,
# ADD COLUMN `skill11_버블` TINYINT NULL AFTER `skill11_배터리`,
# ADD COLUMN `skill11_충격` TINYINT NULL AFTER `skill11_버블`,
# ADD COLUMN `skill11_기력` TINYINT NULL AFTER `skill11_충격`,
# ADD COLUMN `skill11_내공` SMALLINT NULL AFTER `skill11_기력`,
# ADD COLUMN `skill11_경직면역` VARCHAR(45) NULL AFTER `skill11_내공`,
# ADD COLUMN `skill11_피격면역` VARCHAR(45) NULL AFTER `skill11_경직면역`,
# ADD COLUMN `skill11_상태이상면역` VARCHAR(45) NULL AFTER `skill11_피격면역`;
# ADD COLUMN `skill12_name` VARCHAR(16) NULL AFTER `skill11_상태이상면역`,
# ADD COLUMN `skill12_level` TINYINT NULL AFTER `skill12_name`,
# ADD COLUMN `skill12_cooltime` TINYINT NULL AFTER `skill12_level`,
# ADD COLUMN `skill12_tripod1_name` VARCHAR(16) NULL AFTER `skill12_cooltime`,
# ADD COLUMN `skill12_tripod1_point` TINYINT NULL AFTER `skill12_tripod1_name`,
# ADD COLUMN `skill12_tripod2_name` VARCHAR(16) NULL AFTER `skill12_tripod1_point`,
# ADD COLUMN `skill12_tripod2_point` TINYINT NULL AFTER `skill12_tripod2_name`,
# ADD COLUMN `skill12_tripod3_name` VARCHAR(16) NULL AFTER `skill12_tripod2_point`,
# ADD COLUMN `skill12_tripod3_point` TINYINT NULL AFTER `skill12_tripod3_name`,
# ADD COLUMN `skill12_runeName` VARCHAR(8) NULL AFTER `skill12_tripod3_point`,
# ADD COLUMN `skill12_runeGrade` VARCHAR(4) NULL AFTER `skill12_runeName`,
# ADD COLUMN `skill12_headAttack` TINYINT NULL AFTER `skill12_runeGrade`,
# ADD COLUMN `skill12_backAttack` TINYINT NULL AFTER `skill12_headAttack`,
# ADD COLUMN `skill12_partBreak` TINYINT NULL AFTER `skill12_backAttack`,
# ADD COLUMN `skill12_stagger` VARCHAR(4) NULL AFTER `skill12_partBreak`,
# ADD COLUMN `skill12_counter` TINYINT NULL AFTER `skill12_stagger`,
# ADD COLUMN `skill12_마나` SMALLINT NULL AFTER `skill12_counter`,
# ADD COLUMN `skill12_배터리` SMALLINT NULL AFTER `skill12_마나`,
# ADD COLUMN `skill12_버블` TINYINT NULL AFTER `skill12_배터리`,
# ADD COLUMN `skill12_충격` TINYINT NULL AFTER `skill12_버블`,
# ADD COLUMN `skill12_기력` TINYINT NULL AFTER `skill12_충격`,
# ADD COLUMN `skill12_내공` SMALLINT NULL AFTER `skill12_기력`,
# ADD COLUMN `skill12_경직면역` VARCHAR(45) NULL AFTER `skill12_내공`,
# ADD COLUMN `skill12_피격면역` VARCHAR(45) NULL AFTER `skill12_경직면역`,
# ADD COLUMN `skill12_상태이상면역` VARCHAR(45) NULL AFTER `skill12_피격면역`,
# ADD COLUMN `skill13_name` VARCHAR(16) NULL AFTER `skill12_상태이상면역`,
# ADD COLUMN `skill13_level` TINYINT NULL AFTER `skill13_name`,
# ADD COLUMN `skill13_cooltime` TINYINT NULL AFTER `skill13_level`,
# ADD COLUMN `skill13_tripod1_name` VARCHAR(16) NULL AFTER `skill13_cooltime`,
# ADD COLUMN `skill13_tripod1_point` TINYINT NULL AFTER `skill13_tripod1_name`,
# ADD COLUMN `skill13_tripod2_name` VARCHAR(16) NULL AFTER `skill13_tripod1_point`,
# ADD COLUMN `skill13_tripod2_point` TINYINT NULL AFTER `skill13_tripod2_name`,
# ADD COLUMN `skill13_tripod3_name` VARCHAR(16) NULL AFTER `skill13_tripod2_point`,
# ADD COLUMN `skill13_tripod3_point` TINYINT NULL AFTER `skill13_tripod3_name`,
# ADD COLUMN `skill13_runeName` VARCHAR(8) NULL AFTER `skill13_tripod3_point`,
# ADD COLUMN `skill13_runeGrade` VARCHAR(4) NULL AFTER `skill13_runeName`,
# ADD COLUMN `skill13_headAttack` TINYINT NULL AFTER `skill13_runeGrade`,
# ADD COLUMN `skill13_backAttack` TINYINT NULL AFTER `skill13_headAttack`,
# ADD COLUMN `skill13_partBreak` TINYINT NULL AFTER `skill13_backAttack`,
# ADD COLUMN `skill13_stagger` VARCHAR(4) NULL AFTER `skill13_partBreak`,
# ADD COLUMN `skill13_counter` TINYINT NULL AFTER `skill13_stagger`,
# ADD COLUMN `skill13_마나` SMALLINT NULL AFTER `skill13_counter`,
# ADD COLUMN `skill13_배터리` SMALLINT NULL AFTER `skill13_마나`,
# ADD COLUMN `skill13_버블` TINYINT NULL AFTER `skill13_배터리`,
# ADD COLUMN `skill13_충격` TINYINT NULL AFTER `skill13_버블`,
# ADD COLUMN `skill13_기력` TINYINT NULL AFTER `skill13_충격`,
# ADD COLUMN `skill13_내공` SMALLINT NULL AFTER `skill13_기력`,
# ADD COLUMN `skill13_경직면역` VARCHAR(45) NULL AFTER `skill13_내공`,
# ADD COLUMN `skill13_피격면역` VARCHAR(45) NULL AFTER `skill13_경직면역`,
# ADD COLUMN `skill13_상태이상면역` VARCHAR(45) NULL AFTER `skill13_피격면역`,
# ADD COLUMN `skill14_name` VARCHAR(16) NULL AFTER `skill13_상태이상면역`,
# ADD COLUMN `skill14_level` TINYINT NULL AFTER `skill14_name`,
# ADD COLUMN `skill14_cooltime` TINYINT NULL AFTER `skill14_level`,
# ADD COLUMN `skill14_tripod1_name` VARCHAR(16) NULL AFTER `skill14_cooltime`,
# ADD COLUMN `skill14_tripod1_point` TINYINT NULL AFTER `skill14_tripod1_name`,
# ADD COLUMN `skill14_tripod2_name` VARCHAR(16) NULL AFTER `skill14_tripod1_point`,
# ADD COLUMN `skill14_tripod2_point` TINYINT NULL AFTER `skill14_tripod2_name`,
# ADD COLUMN `skill14_tripod3_name` VARCHAR(16) NULL AFTER `skill14_tripod2_point`,
# ADD COLUMN `skill14_tripod3_point` TINYINT NULL AFTER `skill14_tripod3_name`,
# ADD COLUMN `skill14_runeName` VARCHAR(8) NULL AFTER `skill14_tripod3_point`,
# ADD COLUMN `skill14_runeGrade` VARCHAR(4) NULL AFTER `skill14_runeName`,
# ADD COLUMN `skill14_headAttack` TINYINT NULL AFTER `skill14_runeGrade`,
# ADD COLUMN `skill14_backAttack` TINYINT NULL AFTER `skill14_headAttack`,
# ADD COLUMN `skill14_partBreak` TINYINT NULL AFTER `skill14_backAttack`,
# ADD COLUMN `skill14_stagger` VARCHAR(4) NULL AFTER `skill14_partBreak`,
# ADD COLUMN `skill14_counter` TINYINT NULL AFTER `skill14_stagger`,
# ADD COLUMN `skill14_마나` SMALLINT NULL AFTER `skill14_counter`,
# ADD COLUMN `skill14_배터리` SMALLINT NULL AFTER `skill14_마나`,
# ADD COLUMN `skill14_버블` TINYINT NULL AFTER `skill14_배터리`,
# ADD COLUMN `skill14_충격` TINYINT NULL AFTER `skill14_버블`,
# ADD COLUMN `skill14_기력` TINYINT NULL AFTER `skill14_충격`,
# ADD COLUMN `skill14_내공` SMALLINT NULL AFTER `skill14_기력`,
# ADD COLUMN `skill14_경직면역` VARCHAR(45) NULL AFTER `skill14_내공`,
# ADD COLUMN `skill14_피격면역` VARCHAR(45) NULL AFTER `skill14_경직면역`,
# ADD COLUMN `skill14_상태이상면역` VARCHAR(45) NULL AFTER `skill14_피격면역`;
# ADD COLUMN `skill15_name` VARCHAR(16) NULL AFTER `skill14_상태이상면역`,
# ADD COLUMN `skill15_level` TINYINT NULL AFTER `skill15_name`,
# ADD COLUMN `skill15_cooltime` TINYINT NULL AFTER `skill15_level`,
# ADD COLUMN `skill15_tripod1_name` VARCHAR(16) NULL AFTER `skill15_cooltime`,
# ADD COLUMN `skill15_tripod1_point` TINYINT NULL AFTER `skill15_tripod1_name`,
# ADD COLUMN `skill15_tripod2_name` VARCHAR(16) NULL AFTER `skill15_tripod1_point`,
# ADD COLUMN `skill15_tripod2_point` TINYINT NULL AFTER `skill15_tripod2_name`,
# ADD COLUMN `skill15_tripod3_name` VARCHAR(16) NULL AFTER `skill15_tripod2_point`,
# ADD COLUMN `skill15_tripod3_point` TINYINT NULL AFTER `skill15_tripod3_name`,
# ADD COLUMN `skill15_runeName` VARCHAR(8) NULL AFTER `skill15_tripod3_point`,
# ADD COLUMN `skill15_runeGrade` VARCHAR(4) NULL AFTER `skill15_runeName`,
# ADD COLUMN `skill15_headAttack` TINYINT NULL AFTER `skill15_runeGrade`,
# ADD COLUMN `skill15_backAttack` TINYINT NULL AFTER `skill15_headAttack`,
# ADD COLUMN `skill15_partBreak` TINYINT NULL AFTER `skill15_backAttack`,
# ADD COLUMN `skill15_stagger` VARCHAR(4) NULL AFTER `skill15_partBreak`,
# ADD COLUMN `skill15_counter` TINYINT NULL AFTER `skill15_stagger`,
# ADD COLUMN `skill15_마나` SMALLINT NULL AFTER `skill15_counter`,
# ADD COLUMN `skill15_배터리` SMALLINT NULL AFTER `skill15_마나`,
# ADD COLUMN `skill15_버블` TINYINT NULL AFTER `skill15_배터리`,
# ADD COLUMN `skill15_충격` TINYINT NULL AFTER `skill15_버블`,
# ADD COLUMN `skill15_기력` TINYINT NULL AFTER `skill15_충격`,
# ADD COLUMN `skill15_내공` SMALLINT NULL AFTER `skill15_기력`,
# ADD COLUMN `skill15_경직면역` VARCHAR(45) NULL AFTER `skill15_내공`,
# ADD COLUMN `skill15_피격면역` VARCHAR(45) NULL AFTER `skill15_경직면역`,
# ADD COLUMN `skill15_상태이상면역` VARCHAR(45) NULL AFTER `skill15_피격면역`,
# ADD COLUMN `skill16_name` VARCHAR(16) NULL AFTER `skill15_상태이상면역`,
# ADD COLUMN `skill16_level` TINYINT NULL AFTER `skill16_name`,
# ADD COLUMN `skill16_cooltime` TINYINT NULL AFTER `skill16_level`,
# ADD COLUMN `skill16_tripod1_name` VARCHAR(16) NULL AFTER `skill16_cooltime`,
# ADD COLUMN `skill16_tripod1_point` TINYINT NULL AFTER `skill16_tripod1_name`,
# ADD COLUMN `skill16_tripod2_name` VARCHAR(16) NULL AFTER `skill16_tripod1_point`,
# ADD COLUMN `skill16_tripod2_point` TINYINT NULL AFTER `skill16_tripod2_name`,
# ADD COLUMN `skill16_tripod3_name` VARCHAR(16) NULL AFTER `skill16_tripod2_point`,
# ADD COLUMN `skill16_tripod3_point` TINYINT NULL AFTER `skill16_tripod3_name`,
# ADD COLUMN `skill16_runeName` VARCHAR(8) NULL AFTER `skill16_tripod3_point`,
# ADD COLUMN `skill16_runeGrade` VARCHAR(4) NULL AFTER `skill16_runeName`,
# ADD COLUMN `skill16_headAttack` TINYINT NULL AFTER `skill16_runeGrade`,
# ADD COLUMN `skill16_backAttack` TINYINT NULL AFTER `skill16_headAttack`,
# ADD COLUMN `skill16_partBreak` TINYINT NULL AFTER `skill16_backAttack`,
# ADD COLUMN `skill16_stagger` VARCHAR(4) NULL AFTER `skill16_partBreak`,
# ADD COLUMN `skill16_counter` TINYINT NULL AFTER `skill16_stagger`,
# ADD COLUMN `skill16_마나` SMALLINT NULL AFTER `skill16_counter`,
# ADD COLUMN `skill16_배터리` SMALLINT NULL AFTER `skill16_마나`,
# ADD COLUMN `skill16_버블` TINYINT NULL AFTER `skill16_배터리`,
# ADD COLUMN `skill16_충격` TINYINT NULL AFTER `skill16_버블`,
# ADD COLUMN `skill16_기력` TINYINT NULL AFTER `skill16_충격`,
# ADD COLUMN `skill16_내공` SMALLINT NULL AFTER `skill16_기력`,
# ADD COLUMN `skill16_경직면역` VARCHAR(45) NULL AFTER `skill16_내공`,
# ADD COLUMN `skill16_피격면역` VARCHAR(45) NULL AFTER `skill16_경직면역`,
# ADD COLUMN `skill16_상태이상면역` VARCHAR(45) NULL AFTER `skill16_피격면역`;

# %%
sql = f"""
INSERT INTO lostark.skill_table (
    {''.join(f'{key}, ' for key in skills.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(skills.keys())))[:-2]});
"""

# %%
for i in range(10000):
    skill = skills.copy()
    skill['characterCode'] = df['characterCode'][i]
    cdf = eval(df['data'][i])
    if cdf==None: continue
    skill_count = 0
    
    try:
        for j in range(len(cdf)):
            fd = flatten_dict(cdf[j])
            try: 
                # 룬을 끼고 있지 않다면
                fd['Rune']
                exist_rune = False
            except: 
                exist_rune=True
                
            # 스킬레벨 1 이상이거나 룬을 착용했다면 사용하는 스킬로 간주
            if (fd['Level'] > 1) or (exist_rune == True): 
                skill_count += 1
                tripod_count = 0
                skill[f'skill{skill_count}_level'] = fd['Level']
                skill[f'skill{skill_count}_name'] = fd['Name']
                if exist_rune == True:
                    skill[f'skill{skill_count}_runeName'] = fd['Rune_Name']
                    skill[f'skill{skill_count}_runeGrade'] = fd['Rune_Grade']
                for k, v in fd.items():
                    sv = str(v)
                    sk = str(k)
                    if ('_value_leftText' in sk) & ('재사용 대기시간' in sv):
                        skill[f'skill{skill_count}_cooltime'] = int(int_pattern.findall(sv)[0])
                    elif ('Tooltip_Element_' in sk) & ('desc' not in sk) & ('소모' in sv) &\
                    ('않는다' not in sv) & ('증가' not in sv) & ('감소' not in sv) & ('회복' not in sv):
                        sv = sv.replace('|', '')
                        sv = sv.split(', ')
                        resourceName = resource_pattern.findall(sv[0])[0]
                        if len(sv) > 1: # 인파이터: 생성과 소모를 동시에 함
                            resourceName2 = resource_pattern.findall(sv[1])[0]
                            if '모두 소모' in sv[0]:
                                skill[f'skill{skill_count}_{resourceName}'] = -100
                            else:
                                skill[f'skill{skill_count}_{resourceName}'] = -1 * int(int_pattern.findall(sv[0])[0])
                            skill[f'skill{skill_count}_{resourceName2}'] = int(int_pattern.findall(sv[1])[0])
                        else: # 일반 직업
                            skill[f'skill{skill_count}_{resourceName}'] = -1 * int(int_pattern.findall(sv[0])[0])
                    elif ('_value_Element_' in sk) & ('name' in sk) & (sv != ''):
                        tripod_count+=1
                        skill[f'skill{skill_count}_tripod{tripod_count}_name'] = sv
                    elif ('_value_Element_' in sk) & ('tier' in sk) & (sv != ''):
                        skill[f'skill{skill_count}_tripod{tripod_count}_point'] = int(int_pattern.findall(sv)[0])
                    elif ('공격 타입 :' in sv) | ('부위 파괴 :' in sv) | ('무력화 :' in sv) | ('슈퍼아머 :' in sv) |\
                    ('카운터 :' in sv):
                        if ('공격 타입 :' in sv) :
                            skill[f'skill{skill_count}_headAttack'] = '헤드 어택' in sv
                            skill[f'skill{skill_count}_backAttack'] = '백 어택' in sv
                        if ('부위 파괴 :' in sv) :
                            start_idx = sv.find('부위 파괴 : 레벨') + len('부위 파괴 : 레벨')
                            # 띄어쓰기가 제대로 되지않는 경우가 있어 replace
                            number = sv[start_idx:].split()[0].replace('무력화', '').replace('공격', '')\
                            .replace('슈퍼아머', '')
                            skill[f'skill{skill_count}_partBreak'] = int(number)
                        else:
                            skill[f'skill{skill_count}_partBreak'] = 0
                        if ('무력화 :' in sv) :
                            start_idx = sv.find('무력화 : ') + len('무력화 : ')
                            stagger = sv[start_idx:].split()[0].replace('공격', '').replace('카운터', '')\
                            .replace('슈퍼아머', '')
                            skill[f'skill{skill_count}_stagger'] = stagger
                        else: 
                            skill[f'skill{skill_count}_stagger'] = 0
                        skill[f'skill{skill_count}_counter'] = '카운터' in sv
                        skill[f'skill{skill_count}_경직면역'] = '경직 면역' in sv
                        skill[f'skill{skill_count}_피격면역'] = '피격이상 면역' in sv
                        skill[f'skill{skill_count}_상태이상면역'] = '상태이상 면역' in sv
#             pprint(skill)
    except Exception as e:
        print_exception(fd, sk, sv, e)
        break

# %% [markdown]
# # ArmoryGem

# %%
df = pd.read_csv('./data/ArmoryGem.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
gem_parts = [f'gem{i}' for i in range(1, 12)] # 11개의 보석
dic_keys = ['type', 'level', 'grade','skillName', 'tier', 'availableTrade']
gems = {
    'characterCode': None,
}
for part in gem_parts:
    for key in dic_keys:
        gems[f'{part}_{key}'] = None
print(str(list(gems.keys()))[1:-1])
# Out:
# 'characterCode', 'gem1_type', 'gem1_level', 'gem1_grade', 'gem1_skillName', 'gem1_tier', 'gem1_availableTrade', 'gem2_type', 'gem2_level', 'gem2_grade', 'gem2_skillName', 'gem2_tier', 'gem2_availableTrade', 'gem3_type', 'gem3_level', 'gem3_grade', 'gem3_skillName', 'gem3_tier', 'gem3_availableTrade', 'gem4_type', 'gem4_level', 'gem4_grade', 'gem4_skillName', 'gem4_tier', 'gem4_availableTrade', 'gem5_type', 'gem5_level', 'gem5_grade', 'gem5_skillName', 'gem5_tier', 'gem5_availableTrade', 'gem6_type', 'gem6_level', 'gem6_grade', 'gem6_skillName', 'gem6_tier', 'gem6_availableTrade', 'gem7_type', 'gem7_level', 'gem7_grade', 'gem7_skillName', 'gem7_tier', 'gem7_availableTrade', 'gem8_type', 'gem8_level', 'gem8_grade', 'gem8_skillName', 'gem8_tier', 'gem8_availableTrade', 'gem9_type', 'gem9_level', 'gem9_grade', 'gem9_skillName', 'gem9_tier', 'gem9_availableTrade', 'gem10_type', 'gem10_level', 'gem10_grade', 'gem10_skillName', 'gem10_tier', 'gem10_availableTrade', 'gem11_type', 'gem11_leve
# ...

# %%
# ALTER TABLE `lostark`.`gem_table` 
# ADD COLUMN `gem1_availableTrade` TINYINT NULL AFTER `characterCode`,
# ADD COLUMN `gem1_grade` VARCHAR(4) NULL AFTER `gem1_availableTrade`,
# ADD COLUMN `gem1_level` TINYINT NULL AFTER `gem1_grade`,
# ADD COLUMN `gem1_skillName` VARCHAR(20) NULL AFTER `gem1_level`,
# ADD COLUMN `gem1_tier` TINYINT NULL AFTER `gem1_skillName`,
# ADD COLUMN `gem1_type` VARCHAR(4) NULL AFTER `gem1_tier`,
# ADD COLUMN `gem2_availableTrade` TINYINT NULL AFTER `gem1_type`,
# ADD COLUMN `gem2_grade` VARCHAR(4) NULL AFTER `gem2_availableTrade`,
# ADD COLUMN `gem2_level` TINYINT NULL AFTER `gem2_grade`,
# ADD COLUMN `gem2_skillName` VARCHAR(20) NULL AFTER `gem2_level`,
# ADD COLUMN `gem2_tier` TINYINT NULL AFTER `gem2_skillName`,
# ADD COLUMN `gem2_type` VARCHAR(4) NULL AFTER `gem2_tier`,
# ADD COLUMN `gem3_availableTrade` TINYINT NULL AFTER `gem2_type`,
# ADD COLUMN `gem3_grade` VARCHAR(4) NULL AFTER `gem3_availableTrade`,
# ADD COLUMN `gem3_level` TINYINT NULL AFTER `gem3_grade`,
# ADD COLUMN `gem3_skillName` VARCHAR(20) NULL AFTER `gem3_level`,
# ADD COLUMN `gem3_tier` TINYINT NULL AFTER `gem3_skillName`,
# ADD COLUMN `gem3_type` VARCHAR(4) NULL AFTER `gem3_tier`,
# ADD COLUMN `gem4_availableTrade` TINYINT NULL AFTER `gem3_type`,
# ADD COLUMN `gem4_grade` VARCHAR(4) NULL AFTER `gem4_availableTrade`,
# ADD COLUMN `gem4_level` TINYINT NULL AFTER `gem4_grade`,
# ADD COLUMN `gem4_skillName` VARCHAR(20) NULL AFTER `gem4_level`,
# ADD COLUMN `gem4_tier` TINYINT NULL AFTER `gem4_skillName`,
# ADD COLUMN `gem4_type` VARCHAR(4) NULL AFTER `gem4_tier`,
# ADD COLUMN `gem5_availableTrade` TINYINT NULL AFTER `gem4_type`,
# ADD COLUMN `gem5_grade` VARCHAR(4) NULL AFTER `gem5_availableTrade`,
# ADD COLUMN `gem5_level` TINYINT NULL AFTER `gem5_grade`,
# ADD COLUMN `gem5_skillName` VARCHAR(20) NULL AFTER `gem5_level`,
# ADD COLUMN `gem5_tier` TINYINT NULL AFTER `gem5_skillName`,
# ADD COLUMN `gem5_type` VARCHAR(4) NULL AFTER `gem5_tier`,
# ADD COLUMN `gem6_availableTrade` TINYINT NULL AFTER `gem5_type`,
# ADD COLUMN `gem6_grade` VARCHAR(4) NULL AFTER `gem6_availableTrade`,
# ADD COLUMN `gem6_level` TINYINT NULL AFTER `gem6_grade`,
# ADD COLUMN `gem6_skillName` VARCHAR(20) NULL AFTER `gem6_level`,
# ADD COLUMN `gem6_tier` TINYINT NULL AFTER `gem6_skillName`,
# ADD COLUMN `gem6_type` VARCHAR(4) NULL AFTER `gem6_tier`,
# ADD COLUMN `gem7_availableTrade` TINYINT NULL AFTER `gem6_type`,
# ADD COLUMN `gem7_grade` VARCHAR(4) NULL AFTER `gem7_availableTrade`,
# ADD COLUMN `gem7_level` TINYINT NULL AFTER `gem7_grade`,
# ADD COLUMN `gem7_skillName` VARCHAR(20) NULL AFTER `gem7_level`,
# ADD COLUMN `gem7_tier` TINYINT NULL AFTER `gem7_skillName`,
# ADD COLUMN `gem7_type` VARCHAR(4) NULL AFTER `gem7_tier`,
# ADD COLUMN `gem8_availableTrade` TINYINT NULL AFTER `gem7_type`,
# ADD COLUMN `gem8_grade` VARCHAR(4) NULL AFTER `gem8_availableTrade`,
# ADD COLUMN `gem8_level` TINYINT NULL AFTER `gem8_grade`,
# ADD COLUMN `gem8_skillName` VARCHAR(20) NULL AFTER `gem8_level`,
# ADD COLUMN `gem8_tier` TINYINT NULL AFTER `gem8_skillName`,
# ADD COLUMN `gem8_type` VARCHAR(4) NULL AFTER `gem8_tier`,
# ADD COLUMN `gem9_availableTrade` TINYINT NULL AFTER `gem8_type`,
# ADD COLUMN `gem9_grade` VARCHAR(4) NULL AFTER `gem9_availableTrade`,
# ADD COLUMN `gem9_level` TINYINT NULL AFTER `gem9_grade`,
# ADD COLUMN `gem9_skillName` VARCHAR(20) NULL AFTER `gem9_level`,
# ADD COLUMN `gem9_tier` TINYINT NULL AFTER `gem9_skillName`,
# ADD COLUMN `gem9_type` VARCHAR(4) NULL AFTER `gem9_tier`,
# ADD COLUMN `gem10_availableTrade` TINYINT NULL AFTER `gem9_type`,
# ADD COLUMN `gem10_grade` VARCHAR(4) NULL AFTER `gem10_availableTrade`,
# ADD COLUMN `gem10_level` TINYINT NULL AFTER `gem10_grade`,
# ADD COLUMN `gem10_skillName` VARCHAR(20) NULL AFTER `gem10_level`,
# ADD COLUMN `gem10_tier` TINYINT NULL AFTER `gem10_skillName`,
# ADD COLUMN `gem10_type` VARCHAR(4) NULL AFTER `gem10_tier`,
# ADD COLUMN `gem11_availableTrade` TINYINT NULL AFTER `gem10_type`,
# ADD COLUMN `gem11_grade` VARCHAR(4) NULL AFTER `gem11_availableTrade`,
# ADD COLUMN `gem11_level` TINYINT NULL AFTER `gem11_grade`,
# ADD CcharacterOLUMN `gem11_skillName` VARCHAR(20) NULL AFTER `gem11_level`,
# ADD COLUMN `gem11_tier` TINYINT NULL AFTER `gem11_skillName`,
# ADD COLUMN `gem11_type` VARCHAR(4) NULL AFTER `gem11_tier`;

# %%
sql = f"""
INSERT INTO lostark.gem_table (
    {''.join(f'{key}, ' for key in gems.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(gems.keys())))[:-2]});
"""

# %%
for i in range(10000):
    gem = gems.copy()
    gem['characterCode'] = df['characterCode'][i]
    cdf = eval(df['data'][i])
    if cdf==None: continue
    cdf = cdf['Gems']
    gem_count = 0
    try:
        for j in range(len(cdf)):
            gem_count += 1
            fd = flatten_dict(cdf[j])
            gem[f'gem{gem_count}_grade'] = fd['Grade']
            gem[f'gem{gem_count}_level'] = fd['Level']
            for k, v in fd.items():
                sv = str(v)
                if '홍염' in sv:
                    gem[f'gem{gem_count}_type'] = '홍염'
                elif '멸화' in sv:
                    gem[f'gem{gem_count}_type'] = '멸화'
                elif '티어' in sv:
                    gem[f'gem{gem_count}_tier'] = int(int_pattern.findall(sv)[0])
                elif '재사용' in sv:
                    gem[f'gem{gem_count}_skillName'] =  sv.split('재사용')[0]
                elif '피해' in sv:
                    gem[f'gem{gem_count}_skillName'] =  sv.split('피해')[0]
                elif '거래' in sv:
                    gem[f'gem{gem_count}_availableTrade'] = '가능' in sv   
    except Exception as e:
        print_exception(fd, sk, sv, e)
        break
# Out:
# {'characterCode': 0,
#  'gem10_availableTrade': None,
#  'gem10_grade': None,
#  'gem10_level': None,
#  'gem10_skillName': None,
#  'gem10_tier': None,
#  'gem10_type': None,
#  'gem11_availableTrade': None,
#  'gem11_grade': None,
#  'gem11_level': None,
#  'gem11_skillName': None,
#  'gem11_tier': None,
#  'gem11_type': None,
#  'gem1_availableTrade': True,
#  'gem1_grade': '고급',
#  'gem1_level': 1,
#  'gem1_skillName': '[스카우터] 명령 : M143 기관총',
#  'gem1_tier': 3,
#  'gem1_type': '멸화',
#  'gem2_availableTrade': True,
#  'gem2_grade': '고급',
#  'gem2_level': 1,
#  'gem2_skillName': '[스카우터] 명령 : 레이드 미사일',
#  'gem2_tier': 3,
#  'gem2_type': '멸화',
#  'gem3_availableTrade': True,
#  'gem3_grade': '고급',
#  'gem3_level': 2,
#  'gem3_skillName': '[스카우터] 기동 타격',
#  'gem3_tier': 3,
#  'gem3_type': '홍염',
#  'gem4_availableTrade': True,
#  'gem4_grade': '고급',
#  'gem4_level': 2,
#  'gem4_skillName': '[스카우터] 이스케이프',
#  'gem4_tier': 3,
#  'gem4_type': '홍염',
#  'gem5_availableTrade': True,
# ...

# %% [markdown]
# # ArmoryEngraving

# %%
df = pd.read_csv('./data/ArmoryEngraving.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
engraving_parts = [f'engraving{i}' for i in range(1, 16)] # 15개의 각인만 고려
dic_keys = ['name', 'level']
engravings = {
    'characterCode': None,
    'grantName1': None,'grantPoint1':None, 'grantName2':None, 'grantPoint2':None
}
for part in engraving_parts:
    for key in dic_keys:
        engravings[f'{part}_{key}'] = None

# %%
sql = f"""
INSERT INTO lostark.engraving_table (
    {''.join(f'{key}, ' for key in engravings.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(engravings.keys())))[:-2]});
"""

# %%
for i in range(10000):
    engraving = engravings.copy()
    engraving['characterCode'] = df['characterCode'][i]
    cdf = eval(df['data'][i])
    if cdf==None: continue
    engraving_count = 0
    grant_count = 0
    try:
        cdfef = cdf['Effects'] # 활성화 각인
        if cdfef==None:
            pass
        else:
            for j in range(len(cdfef)):
                engraving_count += 1
                fd = flatten_dict(cdfef[j])
                engraving[f'engraving{engraving_count}_name'] = fd['Name'].split(' Lv. ')[0]
                engraving[f'engraving{engraving_count}_level'] = fd['Name'].split(' Lv. ')[-1]
            
        cdfen = cdf['Engravings']
        if cdfen==None: continue
        for j in range(len(cdfen)):
            grant_count += 1
            fd = flatten_dict(cdfen[j])
            engraving[f'grantName{grant_count}'] = fd['Name']
            for k, v in fd.items():
                sv = str(v)
                if '각인 활성' in sv:
                    engraving[f'grantPoint{grant_count}'] = int(int_pattern.findall(sv)[0])

    except Exception as e:
        print_exception(fd, sk, sv, e)
        break

# %% [markdown]
# # ArmoryCard

# %%
df = pd.read_csv('./data/ArmoryCard.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
card_parts = [f'card{i}' for i in range(1, 7)] # 카드 6장
dic_keys = ['name', 'level']
cards = {
    'characterCode': None,
}
for part in card_parts:
    for key in dic_keys:
        cards[f'{part}_{key}'] = None
for i in range(1, 6): # 세트 5개
    cards[f'setName{i}'] = None
    cards[f'setPoint{i}'] = None

# %%
sql = f"""
INSERT INTO lostark.card_table (
    {''.join(f'{key}, ' for key in cards.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(cards.keys())))[:-2]});
"""

# %%
for i in range(10000):
    card = cards.copy()
    card['characterCode'] = df['characterCode'][i]
    cdf = eval(df['data'][i])
    if cdf==None: continue
    card_count = 0
    set_count = 0
    try:
        cdfc = cdf['Cards'] # 장착 카드
        if cdfc == None: continue
        for j in range(len(cdfc)):
            card_count += 1
            fd = flatten_dict(cdfc[j])
            card[f'card{card_count}_name'] = fd['Name']
            card[f'card{card_count}_level'] = fd['AwakeCount']

        cdfe = cdf['Effects'] # 활성화된 세트
        if cdfe==None: continue
        for j in range(len(cdfe)):
            try:
                set_name = cdfe[j]['Items'][-1]['Name'].split(' (')
            except:
                continue
            set_count += 1
            card[f'setName{set_count}'] = set_name[0]
            if len(set_name) > 1: # 세트 각성효과 활성화 되어 있다면
                card[f'setPoint{set_count}'] = int(int_pattern.findall(set_name[1])[0])
            else: # 실제로는 0이 아닐 수 있음, 현 단계에서는 계산 불가(복잡함)
                card[f'setPoint{set_count}'] = 0

    except Exception as e:
        print_exception(fd, sk, sv, e)
        break

# %% [markdown]
# # Collectibles

# %%
df = pd.read_csv('./data/Collectibles.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
# collectibles에는 none 값이 없음
collectibles = {'characterCode': None}

# %%
def return_collectible_key(ct, cdata):
    ck = (ct+"_"+cdata['PointName']+'_point').replace('_이그네아의 징표 :', '').replace('_세계수의 잎', '')\
        .replace('_모험물 :', '').replace('_위대한 미술품', '').replace('_오르페우스의 별', '')\
        .replace(' 섬의 마음', ' 섬').replace(' ', '_')
    return ck

# %%
sql = f"""
INSERT INTO lostark.collectible_table (
    {''.join(f'{key}, ' for key in collectible.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(collectible.keys())))[:-2]});
"""
# Out:
# '\nINSERT INTO lostark.collectible_table (\n    characterCode)\nVALUES (%s);\n'

# %%
for i in range(10000):
    collectible = collectibles.copy()
    collectible['characterCode'] = df['characterCode'][i]
    try:
        for ctype in eval(df['data'][i]):
            ct = ctype['Type']
            for cdata in ctype['CollectiblePoints']:
                ck = return_collectible_key(ct, cdata)
                collectible[ck] = cdata['Point']
            
#         pprint(collectible)
    except Exception as e:
        traceback.print_exc()
        break
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-103-1fa80024c6b3>", line 7, in <module>
#     for cdata in ctype['CollectiblePoints']:
# KeyError: 'CollectiblePoints'

# %% [markdown]
# # ColosseumInfo

# %%
df = pd.read_csv('./data/ColosseumInfo.csv')
df = df.rename(columns={'Unnamed: 0':'characterCode', '0':'data'})

# %%
# CoOpBattle, Competitive, DeathMatch, SeasonName, TeamDeathMatch, TeamElimination
seasons = ['프리시즌']
for i in range(1, len(eval(df['data'][0])['Colosseums'])): seasons.append(f'시즌{i}')
dic_keys = ['CoOpBattle_AceCount','CoOpBattle_DeathCount','CoOpBattle_KillCount','CoOpBattle_LoseCount',
            'CoOpBattle_PlayCount','CoOpBattle_TieCount','CoOpBattle_VictoryCount','Competitive_AceCount',
            'Competitive_DeathCount','Competitive_KillCount','Competitive_LoseCount','Competitive_PlayCount',
            'Competitive_Rank','Competitive_RankLastMmr','Competitive_RankName','Competitive_TieCount',
            'Competitive_VictoryCount','Deathmatch_AceCount','Deathmatch_DeathCount','Deathmatch_KillCount',
            'Deathmatch_LoseCount','Deathmatch_PlayCount','Deathmatch_TieCount','Deathmatch_VictoryCount',
            'TeamDeathmatch_AceCount','TeamDeathmatch_DeathCount','TeamDeathmatch_KillCount',
            'TeamDeathmatch_LoseCount','TeamDeathmatch_PlayCount','TeamDeathmatch_TieCount',
            'TeamDeathmatch_VictoryCount','TeamElimination_AceCount','TeamElimination_AllKillCount',
            'TeamElimination_DeathCount','TeamElimination_FirstPlayCount','TeamElimination_FirstWinCount',
            'TeamElimination_KillCount','TeamElimination_LoseCount','TeamElimination_PlayCount',
            'TeamElimination_SecondPlayCount','TeamElimination_SecondWinCount','TeamElimination_ThirdPlayCount',
            'TeamElimination_ThirdWinCount','TeamElimination_TieCount','TeamElimination_VictoryCount']
colosseums = {'characterCode': None, 'exp':None, 'preRank':None, 'rank':None}
for s in seasons:
    for key in dic_keys:
        colosseums[s+'_'+key] = None

# %%
sql = f"""
INSERT INTO lostark.colosseum_table (
    {''.join(f'{key}, ' for key in colosseums.keys())[:-2]})
VALUES ({''.join('%s, ' for _ in range(len(colosseums.keys())))[:-2]});
"""

# %%
for i in range(10000):
    colosseum = colosseums.copy()
    colosseum['characterCode'] = df['characterCode'][i]
    try:
        cdf = eval(df['data'][i])
        if cdf==None: continue
        colosseum['exp'] = cdf['Exp']
        colosseum['preRank'] = cdf['PreRank']
        colosseum['rank'] = cdf['Rank']
        for cidx in range(len(cdf['Colosseums'])):
            if cidx == 0: season_name ='프리시즌'
            else: season_name = f'시즌{cidx}'
            for k, v in cdf['Colosseums'][cidx].items():
                sk = str(k)
                sv = str(v)
                if (v != None) & ('시즌' not in sv):
                    for ck, cv in v.items():
                        if ck != 'RankIcon':
                            colosseum[season_name+'_'+sk+'_'+ck] = cv
    except Exception as e:
        print_exception(fd, sk, sv, e)
        break
