# %% [markdown]
# 데이터가 날라갔나?...
# 스펙에 영향이 없으니 우선 넘어감 ㅠ

# %%
import sys
sys.path.append('../package')
import lostark as lok
import pandas as pd
import numpy as np
import pprint
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
font_path = "C:/Users/user/Code_Files_Jupyter/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumBarunGothic')

pd.set_option('display.max_columns', None)

# %%
df = lok.get_table_df('colosseum_table')

# %%
df.head(2)
# Out:
#    characterCode  exp  preRank  rank preSeason_CoOpBattle_AceCount  \
# 0              1    0        0     0                          None
# 1              2    0        0     0                          None
#
#   preSeason_CoOpBattle_DeathCount preSeason_CoOpBattle_KillCount  \
# 0                            None                           None
# 1                            None                           None
#
#   preSeason_CoOpBattle_LoseCount preSeason_CoOpBattle_PlayCount  \
# 0                           None                           None
# 1                           None                           None
#
#   preSeason_CoOpBattle_TieCount preSeason_CoOpBattle_VictoryCount  \
# 0                          None                              None
# 1                          None                              None
#
#    preSeason_Competitive_AceCount  preSeason_Competitive_DeathCount  \
# 0                             NaN                               NaN
# ...

# %%
for i in range(0, len(df.columns), 20):
    df.iloc[:, i:i+20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570303 entries, 0 to 570302
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   characterCode                      570303 non-null  int64
#  1   exp                                570303 non-null  int64
#  2   preRank                            570303 non-null  int64
#  3   rank                               570303 non-null  int64
#  4   preSeason_CoOpBattle_AceCount      0 non-null       object
#  5   preSeason_CoOpBattle_DeathCount    0 non-null       object
#  6   preSeason_CoOpBattle_KillCount     0 non-null       object
#  7   preSeason_CoOpBattle_LoseCount     0 non-null       object
#  8   preSeason_CoOpBattle_PlayCount     0 non-null       object
#  9   preSeason_CoOpBattle_TieCount      0 non-null       object
#  10  preSeason_CoOpBattle_VictoryCount  0 non-null       object
# ...

# %%
season = ['season'+str(i) for i in range(1, 8)]
season.insert(0, 'preSeason')

# %%
for s in season:
    column = s+"_CoOpBattle_AceCount"
    data = df[column]
    plt.plot(data)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
column = s+"_CoOpBattle_AceCount"
data = df[column]
data
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 570298    None
# 570299    None
# 570300    None
# 570301    None
# 570302    None
# Name: season7_CoOpBattle_AceCount, Length: 570303, dtype: object
