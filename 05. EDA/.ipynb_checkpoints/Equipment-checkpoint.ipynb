# %%
import sys
sys.path.append('../package')
import lostark as lok
import pandas as pd
import pprint
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
font_path = "C:/Users/user/Code_Files_Jupyter/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumBarunGothic')

pd.set_option('display.max_columns', None)

# %%
df = lok.get_table_df('equipment_table')

# %%
df.head(2)
# Out:
#    characterCode 무기_grade         무기_name    무기_type  무기_quality  무기_tier  \
# 0              1       전설  분출된 격랑의 서브 머신건  전설 서브 머신건       100.0      3.0
# 1              3       영웅       눈부신 황혼의 붓       영웅 붓        53.0      3.0
#
#    무기_itemLevel   무기_ATK 무기_AD(%) 무기_setName  무기_setLevel  무기_REXP  무기_esther  \
# 0        1370.0  18655.0    15.00     분출된 격랑          1.0   4960.0        NaN
# 1        1335.0  17400.0    10.30     눈부신 황혼          1.0   1272.0        NaN
#
#   무기_estherEffect  무기_ella  무기_reinforcementStep 투구_grade       투구_name  \
# 0            None      NaN                   7.0       전설    분출된 격랑의 모자
# 1            None      NaN                   8.0       영웅  따뜻한 저녁의 머리장식
#
#      투구_type  투구_quality  투구_tier  투구_itemLevel   투구_SAI  투구_BDEF  투구_BMDEF  \
# 0  전설 머리 방어구       100.0      3.0        1370.0  10052.0   3012.0    3346.0
# 1  영웅 머리 방어구        64.0      3.0        1325.0   9186.0   2880.0    3200.0
#
# ...

# %%
for i in range(0, len(df.columns), 20):
    df.iloc[:, i:i+20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497282 entries, 0 to 497281
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   characterCode         497282 non-null  int64
#  1   무기_grade              488843 non-null  object
#  2   무기_name               488843 non-null  object
#  3   무기_type               488843 non-null  object
#  4   무기_quality            488843 non-null  float64
#  5   무기_tier               487729 non-null  float64
#  6   무기_itemLevel          487729 non-null  float64
#  7   무기_ATK                471222 non-null  float64
#  8   무기_AD(%)              463614 non-null  object
#  9   무기_setName            367669 non-null  object
#  10  무기_setLevel           367669 non-null  float64
#  11  무기_REXP               451710 non-null  float64
#  12  무기_esther             250 non-null     float64
#  13  무기_estherEffect       209 non-null     object
# ...

# %%
equipments = ['무기', '투구', '어깨', '상의', '하의', '장갑']
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_grade'].value_counts()
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Grade")
        ax[i, j].set_ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(25, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_name'].value_counts()[:10]
        sns.barplot(y=data.index, x=data.values, palette = 'Set2', ax=ax[i, j], orient='h')
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_ylabel("Name")
        ax[i, j].set_xlabel("Frequency")
        ax[i, j].tick_params(axis='y', labelsize=16)
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_type'].value_counts()[:10]
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Type")
        ax[i, j].set_ylabel("Frequency")
plt.show()
# 무기는 슬라이싱함

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_quality']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Quality")
        ax[i, j].set_ylabel("Frequency")
plt.show()
# 품100이 많다?...

# %%
df[df['무기_quality'] == 100]['무기_name'].value_counts()[:30]
# 분출된 -> 아르고스, 오레하 제작 전설 장비
# 차원의 -> 카오스 던전 영웅 장비
# 제작 당시부터 품100인 장비들
# Out:
# 분출된 격랑의 대검        2511
# 분출된 격랑의 총         1901
# 분출된 격랑의 건틀릿       1570
# 차원의 총             1567
# 분출된 격랑의 우산        1499
# 분출된 격랑의 대거        1490
# 차원의 건틀릿           1440
# 차원의 대거            1434
# 분출된 격랑의 롱 스태프     1175
# 분출된 격랑의 검         1066
# 분출된 격랑의 창          991
# 차원의 검              975
# 분출된 격랑의 스태프        961
# 분출된 격랑의 서브 머신건     960
# 차원의 데모닉웨폰          941
# 차원의 창              931
# 분출된 격랑의 데모닉웨폰      924
# 분출된 격랑의 붓          878
# 분출된 격랑의 헤비 건틀릿     868
# 분출된 격랑의 랜스         823
# 차원의 헤비 건틀릿         803
# 차원의 리아네 하프         795
# 차원의 스태프            784
# 분출된 격랑의 전투망치       762
# 분출된 격랑의 기공패        736
# 차원의 대검             706
# 차원의 한손검            679
# 차원의 마법 덱           667
# 분출된 격랑의 리아네 하프     665
# 차원의 서브 머신건         665
# Name: 무기_name, dtype: int64

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[df[f'{equipments[idx]}_grade']=='고대'][f'{equipments[idx]}_quality']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Quality")
        ax[i, j].set_ylabel("Frequency")
plt.show()
# 품100이 많다?...
# 중간중간 60, 70, 80, 90 부분에서만 튀어나온걸 보면 해당 품질이 뜰 경우 멈춘다?

# %%
df[(df['무기_grade']=='고대') & (df['무기_quality'] == 100)]['무기_name'].value_counts()
# 아브렐슈드 제작 -> 세트 업그레이드 장비 그럼에도 품 100이 많다는 것은...
# 유저들이 고품질을 비용을 지불해서라도 찍는다?
# Out:
# 전이된 몽환의 악몽 총         381
# 전이된 몽환의 악몽 롱 스태프     327
# 타락한 마수의 사멸 건틀릿       307
# 타락한 마수의 사멸 검         306
# 타락한 마수의 사멸 헤비 건틀릿    267
#                     ...
# 떠오른 매혹의 눈 마법 덱         1
# 왜곡된 악몽의 궤적 활           1
# 짓눌린 배신의 구속 건틀릿         1
# 사멸의 저주 랜스              1
# 배신의 부름 마법 덱            1
# Name: 무기_name, Length: 376, dtype: int64

# %%
df[(df['장갑_grade']=='고대') & (df['장갑_quality'] == 100)]['장갑_name'].value_counts()
# Out:
# 타락한 마수의 사멸 장갑     1079
# 전이된 몽환의 악몽 장갑      663
# 사로잡힌 광기의 갈망 장갑     661
# 차오른 몽환의 환각 장갑      618
# 가라앉은 욕망의 배신 장갑     445
# 드러난 사멸의 저주 장갑      268
# 피어난 악몽의 공명 장갑      231
# 대면한 갈망의 타락 장갑      215
# 분열한 환각의 절규 장갑      185
# 숨죽인 배신의 부름 장갑      169
# 고요한 광기의 지배 장갑      169
# 마수의 사멸 장갑          164
# 도래한 군단의 구원 장갑      164
# 몽환의 악몽 장갑          114
# 광기의 갈망 장갑          111
# 몽환의 환각 장갑           74
# 욕망의 배신 장갑           71
# 끝없는 구원의 사슬 장갑       59
# 굳건한 지배의 균형 장갑       41
# 광기의 지배 장갑           33
# 군단의 구원 장갑           32
# 정화된 욕망의 매혹 장갑       24
# 떠오른 매혹의 눈 장갑        12
# 환각의 절규 장갑           11
# 욕망의 매혹 장갑            8
# 유인된 사멸의 종언 장갑        7
# 짓눌린 배신의 구속 장갑        6
# 남겨진 환각의 가르침 장갑       5
# 갈망의 타락 장갑            4
# 사멸의 저주 장갑            4
# 왜곡된 악몽의 궤적 장갑        3
# 배신의 부름 장갑            3
# 악몽의 공명 장갑            3
# 구원의 사슬 장갑            3
# 희생된 지배의 굴레 장갑        3
# 쇠락한 갈망의 그을림 장갑       2
# 지배의 균형 장갑            1
# 매혹의 눈 장갑             1
# 억눌린 마수의 파괴 장갑        1
# ...

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_tier'].value_counts()
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Tier")
        ax[i, j].set_ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_itemLevel']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Item Level")
        ax[i, j].set_ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        if equipments[idx] == '무기':
            col = 'ATK'
        else:
            col = 'SAI'
        data = df[f'{equipments[idx]}_{col}']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel(col)
        ax[i, j].set_ylabel("Frequency")
plt.show()
# 무기의 경우 공격력, 방어구는 힘, 민첩, 지능

# %%
armories = ['투구', '어깨', '상의', '하의', '장갑']

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_BDEF']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("BDEF")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_BMDEF']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("BMDEF")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_BHP']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("BHP")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_ADEF']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("ADEF")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_AMDEF']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("AMDEF")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_AHP']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("AHP")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{armories[idx]}_AHPP']
        sns.histplot(data, bins='auto', kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("AHPP")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 30))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_setName'].value_counts()
        sns.barplot(y=data.index, x=data.values, palette = 'Set2', ax=ax[i, j], orient='h')
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_ylabel("Set Name")
        ax[i, j].set_xlabel("Frequency")
        ax[i, j].tick_params(axis='y', labelsize=12)
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_setLevel'].value_counts()
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Set Level")
        ax[i, j].set_ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_REXP']
        sns.histplot(data, bins=50, kde=True, alpha=0.7, color='b', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("REXP")
        ax[i, j].set_ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(25, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = df[f'{equipments[idx]}_reinforcementStep'].value_counts()
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("ReinforcementStep")
        ax[i, j].set_ylabel("Frequency")
plt.show()
# grade별 or itemLevel별 강화 차이

# %%
res = pd.DataFrame()
for arm in armories:
    res[f'{arm}_AN'] = pd.concat((df[f'{arm}_alchemyName1'], df[f'{arm}_alchemyName2']))
    res[f'{arm}_AP'] = pd.concat((df[f'{arm}_alchemyPoint1'], df[f'{arm}_alchemyPoint2']))
res
# Out:
#          투구_AN  투구_AP 어깨_AN  어깨_AP 상의_AN  상의_AP  하의_AN  하의_AP 장갑_AN  장갑_AP
# 0         None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 1         None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 2       무기 공격력    1.0   공격력    1.0   공격력    2.0  추가 피해    4.0    민첩    1.0
# 3         None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 4         None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# ...        ...    ...   ...    ...   ...    ...    ...    ...   ...    ...
# 497277    None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 497278    None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 497279    None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 497280    None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
# 497281    None    NaN  None    NaN  None    NaN   None    NaN  None    NaN
#
# [994564 rows x 10 columns]

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 30))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = res[f'{armories[idx]}_AN'].value_counts()
        sns.barplot(y=data.index, x=data.values, palette = 'Set2', ax=ax[i, j], orient='h')
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_ylabel("Alchemy Name")
        ax[i, j].set_xlabel("Frequency")
        if idx == 4:
            break
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
idx = -1
for i in range(3):
    for j in range(2):
        idx+=1
        data = res[f'{armories[idx]}_AP'].value_counts()
        sns.barplot(x=data.index, y=data.values, palette = 'Set2', ax=ax[i, j])
        ax[i, j].set_title(equipments[idx])
        ax[i, j].set_xlabel("Alchemy Point")
        ax[i, j].set_ylabel("Frequency")
        if idx == 4:
            break
plt.show()
# 연금술은 잘 몰라서..
# 3이 왜 젤 낮지?
